# %% [markdown]
# #Import

# %%
# !nvidia-smi
# !pip install efficientnet-pytorch
# Out:
# Mon Jan  3 15:33:04 2022
# +-----------------------------------------------------------------------------+
# | NVIDIA-SMI 495.44       Driver Version: 460.32.03    CUDA Version: 11.2     |
# |-------------------------------+----------------------+----------------------+
# | GPU  Name        Persistence-M| Bus-Id        Disp.A | Volatile Uncorr. ECC |
# | Fan  Temp  Perf  Pwr:Usage/Cap|         Memory-Usage | GPU-Util  Compute M. |
# |                               |                      |               MIG M. |
# |===============================+======================+======================|
# |   0  Tesla K80           Off  | 00000000:00:04.0 Off |                    0 |
# | N/A   72C    P8    33W / 149W |      0MiB / 11441MiB |      0%      Default |
# |                               |                      |                  N/A |
# +-------------------------------+----------------------+----------------------+
#
# +-----------------------------------------------------------------------------+
# | Processes:                                                                  |
# |  GPU   GI   CI        PID   Type   Process name                  GPU Memory |
# |        ID   ID                                                   Usage      |
# |=============================================================================|
# |  No running processes found                                                 |
# +-----------------------------------------------------------------------------+
# Collecting efficientnet-pytorch
#   Downloading efficientnet_pytorch-0.7.1.tar.gz (21 kB)
# Requirement already satisfied: torch in /usr/local/lib/python3.7/dist-packages (from efficientnet-pytorch) (1.10.0+cu111)
# Requirement already satisfied: typing-extensions in /usr/local/lib/python3.7/dist-packages (from torch->efficientnet-pytorch) (3.10.0.2)
# Building wheels for collected packages: efficientnet-pytorch
#   Building wheel for efficientnet-pytorch (setup.py) ... done
#   Created wheel for efficientnet-pytorch: filename=efficientnet_pytorch-0.7.1-py3-none-any.whl size=16446 sha256=b1b32f20b6ae95db41e96262ff52759c1bac58dab48a10f9632d430acb3ebd8d
#   Stored in directory: /root/.cache/pip/wheels/0e/cc/b2/49e74588263573ff778da58cc99b9c6349b496636a7e165be6
# Successfully built efficientnet-pytorch
# Installing collected packages: efficientnet-pytorch
# Successfully installed efficientnet-pytorch-0.7.1

# %%
import torch
print(torch.__version__)
print(torch.cuda.is_available())
print(torch.cuda.get_device_name(0))
device = torch.device("cuda:0" if torch.cuda.is_available() else "cpu")
print(device)

import scipy.io as sio
from scipy.stats import zscore
import pandas as pd
import torch.nn as nn
import torch.optim as optim
from torch.optim import lr_scheduler
import numpy as np
import torchvision
from torchvision import models, transforms
import matplotlib.pyplot as plt
import torch.nn.functional as F

import os
import shutil

from random import choice, sample, seed, randint, random, gauss
from scipy.io import loadmat
import skimage.morphology as skm
from torch.utils.data import ConcatDataset, DataLoader, Dataset
#from torchvision.datasets import DatasetFolder
import math
from efficientnet_pytorch import EfficientNet

from google.colab import drive
from mpl_toolkits.axes_grid1 import ImageGrid
drive.mount('/content/drive')


#rendere l'esecuzione deterministica 
torch.manual_seed(0)
np.random.seed(0)
torch.backends.cudnn.deterministic = True
torch.backends.cudnn.benchmark = False
# Out:
# 1.10.0+cu111
# True
# Tesla K80
# cuda:0
# Mounted at /content/drive

# %% [markdown]
# # Uzip dati

# %%
# !cp drive/My\ Drive/CampusBioMedico/VolumiDCE_Sub_AllBox_2D.zip  /content/
# !unzip VolumiDCE_Sub_AllBox_2D.zip  -d /content/
# Out:
# Archive:  VolumiDCE_Sub_AllBox_2D.zip
#    creating: /content/VolumiDCE_Sub_AllBox_2D/
#    creating: /content/VolumiDCE_Sub_AllBox_2D/0_cavo/
#   inflating: /content/VolumiDCE_Sub_AllBox_2D/0_cavo/100_Campolattano_a_1036_17.mat
#   inflating: /content/VolumiDCE_Sub_AllBox_2D/0_cavo/100_Campolattano_a_172_2.mat
#   inflating: /content/VolumiDCE_Sub_AllBox_2D/0_cavo/100_Campolattano_a_258_3.mat
#   inflating: /content/VolumiDCE_Sub_AllBox_2D/0_cavo/100_Campolattano_a_293_27.mat
#   inflating: /content/VolumiDCE_Sub_AllBox_2D/0_cavo/100_Campolattano_a_396_26.mat
#   inflating: /content/VolumiDCE_Sub_AllBox_2D/0_cavo/100_Campolattano_a_404_5.mat
#   inflating: /content/VolumiDCE_Sub_AllBox_2D/0_cavo/100_Campolattano_a_412_4.mat
#   inflating: /content/VolumiDCE_Sub_AllBox_2D/0_cavo/100_Campolattano_a_42_1.mat
#   inflating: /content/VolumiDCE_Sub_AllBox_2D/0_cavo/100_Campolattano_a_431_25.mat
#   inflating: /content/VolumiDCE_Sub_AllBox_2D/0_cavo/100_Campolattano_a_490_24.mat
#   inflating: /content/VolumiDCE_Sub_AllBox_2D/0_cavo/100_Campolattano_a_516_6.mat
#   inflating: /content/VolumiDCE_Sub_AllBox_2D/0_cavo/100_Campolattano_a_597_7.mat
#   inflating: /content/VolumiDCE_Sub_AllBox_2D/0_cavo/100_Campolattano_a_607_8.mat
#   inflating: /content/VolumiDCE_Sub_AllBox_2D/0_cavo/100_Campolattano_a_635_9.mat
#   inflating: /content/VolumiDCE_Sub_AllBox_2D/0_cavo/100_Campolattano_a_677_23.mat
#   inflating: /content/VolumiDCE_Sub_AllBox_2D/0_cavo/100_Campolattano_a_682_22.mat
#   inflating: /content/VolumiDCE_Sub_AllBox_2D/0_cavo/100_Campolattano_a_70_28.mat
#   inflating: /content/VolumiDCE_Sub_AllBox_2D/0_cavo/100_Campolattano_a_740_21.mat
#   inflating: /content/VolumiDCE_Sub_AllBox_2D/0_cavo/100_Campolattano_a_800_10.mat
#   inflating: /content/VolumiDCE_Sub_AllBox_2D/0_cavo/100_Campolattano_a_823_11.mat
#   inflating: /content/VolumiDCE_Sub_AllBox_2D/0_cavo/100_Campolattano_a_868_15.mat
#   inflating: /content/VolumiDCE_Sub_AllBox_2D/0_cavo/100_Campolattano_a_873_13.mat
#   inflating: /content/VolumiDCE_Sub_AllBox_2D/0_cavo/100_Campolattano_a_878_20.mat
#   inflating: /content/VolumiDCE_Sub_AllBox_2D/0_cavo/100_Campolattano_a_880_16.mat
#   inflating: /content/VolumiDCE_Sub_AllBox_2D/0_cavo/100_Campolattano_a_900_12.mat
#   inflating: /content/VolumiDCE_Sub_AllBox_2D/0_cavo/100_Campolattano_a_911_19.mat
#   inflating: /content/VolumiDCE_Sub_AllBox_2D/0_cavo/100_Campolattano_a_935_14.mat
#   inflating: /content/VolumiDCE_Sub_AllBox_2D/0_cavo/100_Campolattano_a_981_18.mat
#   inflating: /content/VolumiDCE_Sub_AllBox_2D/0_cavo/103_Colatei_b_114_6.mat
#   inflating: /content/VolumiDCE_Sub_AllBox_2D/0_cavo/103_Colatei_b_125_7.mat
#   inflating: /content/VolumiDCE_Sub_AllBox_2D/0_cavo/103_Colatei_b_127_16.mat
#   inflating: /content/VolumiDCE_Sub_AllBox_2D/0_cavo/103_Colatei_b_13_3.mat
#   inflating: /content/VolumiDCE_Sub_AllBox_2D/0_cavo/103_Colatei_b_156_8.mat
#   inflating: /content/VolumiDCE_Sub_AllBox_2D/0_cavo/103_Colatei_b_158_15.mat
#   inflating: /content/VolumiDCE_Sub_AllBox_2D/0_cavo/103_Colatei_b_16_22.mat
#   inflating: /content/VolumiDCE_Sub_AllBox_2D/0_cavo/103_Colatei_b_1_1.mat
#   inflating: /content/VolumiDCE_Sub_AllBox_2D/0_cavo/103_Colatei_b_202_14.mat
#   inflating: /content/VolumiDCE_Sub_AllBox_2D/0_cavo/103_Colatei_b_209_9.mat
#   inflating: /content/VolumiDCE_Sub_AllBox_2D/0_cavo/103_Colatei_b_21_20.mat
#   inflating: /content/VolumiDCE_Sub_AllBox_2D/0_cavo/103_Colatei_b_229_10.mat
#   inflating: /content/VolumiDCE_Sub_AllBox_2D/0_cavo/103_Colatei_b_229_13.mat
#   inflating: /content/VolumiDCE_Sub_AllBox_2D/0_cavo/103_Colatei_b_240_11.mat
#   inflating: /content/VolumiDCE_Sub_AllBox_2D/0_cavo/103_Colatei_b_240_12.mat
#   inflating: /content/VolumiDCE_Sub_AllBox_2D/0_cavo/103_Colatei_b_28_19.mat
#   inflating: /content/VolumiDCE_Sub_AllBox_2D/0_cavo/103_Colatei_b_29_4.mat
#   inflating: /content/VolumiDCE_Sub_AllBox_2D/0_cavo/103_Colatei_b_3_23.mat
#   inflating: /content/VolumiDCE_Sub_AllBox_2D/0_cavo/103_Colatei_b_41_18.mat
#   inflating: /content/VolumiDCE_Sub_AllBox_2D/0_cavo/103_Colatei_b_5_2.mat
#   inflating: /content/VolumiDCE_Sub_AllBox_2D/0_cavo/103_Colatei_b_62_5.mat
#   inflating: /content/VolumiDCE_Sub_AllBox_2D/0_cavo/103_Colatei_b_7_21.mat
#   inflating: /content/VolumiDCE_Sub_AllBox_2D/0_cavo/103_Colatei_b_83_17.mat
#   inflating: /content/VolumiDCE_Sub_AllBox_2D/0_cavo/104_Consolino_a_100_26.mat
#   inflating: /content/VolumiDCE_Sub_AllBox_2D/0_cavo/104_Consolino_a_113_5.mat
#   inflating: /content/VolumiDCE_Sub_AllBox_2D/0_cavo/104_Consolino_a_116_25.mat
#   inflating: /content/VolumiDCE_Sub_AllBox_2D/0_cavo/104_Consolino_a_125_6.mat
#   inflating: /content/VolumiDCE_Sub_AllBox_2D/0_cavo/104_Consolino_a_128_16.mat
#   inflating: /content/VolumiDCE_Sub_AllBox_2D/0_cavo/104_Consolino_a_129_15.mat
#   inflating: /content/VolumiDCE_Sub_AllBox_2D/0_cavo/104_Consolino_a_135_9.mat
#   inflating: /content/VolumiDCE_Sub_AllBox_2D/0_cavo/104_Consolino_a_136_23.mat
#   inflating: /content/VolumiDCE_Sub_AllBox_2D/0_cavo/104_Consolino_a_136_24.mat
#   inflating: /content/VolumiDCE_Sub_AllBox_2D/0_cavo/104_Consolino_a_141_8.mat
#   inflating: /content/VolumiDCE_Sub_AllBox_2D/0_cavo/104_Consolino_a_147_17.mat
#   inflating: /content/VolumiDCE_Sub_AllBox_2D/0_cavo/104_Consolino_a_150_13.mat
#   inflating: /content/VolumiDCE_Sub_AllBox_2D/0_cavo/104_Consolino_a_151_7.mat
#   inflating: /content/VolumiDCE_Sub_AllBox_2D/0_cavo/104_Consolino_a_158_14.mat
#   inflating: /content/VolumiDCE_Sub_AllBox_2D/0_cavo/104_Consolino_a_159_12.mat
#   inflating: /content/VolumiDCE_Sub_AllBox_2D/0_cavo/104_Consolino_a_161_22.mat
#   inflating: /content/VolumiDCE_Sub_AllBox_2D/0_cavo/104_Consolino_a_174_11.mat
#   inflating: /content/VolumiDCE_Sub_AllBox_2D/0_cavo/104_Consolino_a_191_20.mat
#   inflating: /content/VolumiDCE_Sub_AllBox_2D/0_cavo/104_Consolino_a_196_18.mat
#   inflating: /content/VolumiDCE_Sub_AllBox_2D/0_cavo/104_Consolino_a_197_10.mat
#   inflating: /content/VolumiDCE_Sub_AllBox_2D/0_cavo/104_Consolino_a_200_21.mat
#   inflating: /content/VolumiDCE_Sub_AllBox_2D/0_cavo/104_Consolino_a_215_19.mat
#   inflating: /content/VolumiDCE_Sub_AllBox_2D/0_cavo/104_Consolino_a_32_1.mat
#   inflating: /content/VolumiDCE_Sub_AllBox_2D/0_cavo/104_Consolino_a_39_28.mat
#   inflating: /content/VolumiDCE_Sub_AllBox_2D/0_cavo/104_Consolino_a_85_3.mat
#   inflating: /content/VolumiDCE_Sub_AllBox_2D/0_cavo/104_Consolino_a_86_27.mat
#   inflating: /content/VolumiDCE_Sub_AllBox_2D/0_cavo/104_Consolino_a_90_2.mat
#   inflating: /content/VolumiDCE_Sub_AllBox_2D/0_cavo/104_Consolino_a_90_4.mat
#   inflating: /content/VolumiDCE_Sub_AllBox_2D/0_cavo/105-106_Conti_a_102_12.mat
#   inflating: /content/VolumiDCE_Sub_AllBox_2D/0_cavo/105-106_Conti_a_10_1.mat
#   inflating: /content/VolumiDCE_Sub_AllBox_2D/0_cavo/105-106_Conti_a_131_11.mat
#   inflating: /content/VolumiDCE_Sub_AllBox_2D/0_cavo/105-106_Conti_a_135_4.mat
#   inflating: /content/VolumiDCE_Sub_AllBox_2D/0_cavo/105-106_Conti_a_14_16.mat
#   inflating: /content/VolumiDCE_Sub_AllBox_2D/0_cavo/105-106_Conti_a_184_5.mat
#   inflating: /content/VolumiDCE_Sub_AllBox_2D/0_cavo/105-106_Conti_a_259_10.mat
#   inflating: /content/VolumiDCE_Sub_AllBox_2D/0_cavo/105-106_Conti_a_272_9.mat
#   inflating: /content/VolumiDCE_Sub_AllBox_2D/0_cavo/105-106_Conti_a_283_7.mat
#   inflating: /content/VolumiDCE_Sub_AllBox_2D/0_cavo/105-106_Conti_a_284_8.mat
#   inflating: /content/VolumiDCE_Sub_AllBox_2D/0_cavo/105-106_Conti_a_288_6.mat
#   inflating: /content/VolumiDCE_Sub_AllBox_2D/0_cavo/105-106_Conti_a_30_15.mat
#   inflating: /content/VolumiDCE_Sub_AllBox_2D/0_cavo/105-106_Conti_a_49_14.mat
#   inflating: /content/VolumiDCE_Sub_AllBox_2D/0_cavo/105-106_Conti_a_55_2.mat
#   inflating: /content/VolumiDCE_Sub_AllBox_2D/0_cavo/105-106_Conti_a_72_13.mat
#   inflating: /content/VolumiDCE_Sub_AllBox_2D/0_cavo/105-106_Conti_a_96_3.mat
#   inflating: /content/VolumiDCE_Sub_AllBox_2D/0_cavo/107_DAntono_a_117_2.mat
#   inflating: /content/VolumiDCE_Sub_AllBox_2D/0_cavo/107_DAntono_a_179_7.mat
#   inflating: /content/VolumiDCE_Sub_AllBox_2D/0_cavo/107_DAntono_a_206_3.mat
#   inflating: /content/VolumiDCE_Sub_AllBox_2D/0_cavo/107_DAntono_a_216_4.mat
#   inflating: /content/VolumiDCE_Sub_AllBox_2D/0_cavo/107_DAntono_a_219_6.mat
#   inflating: /content/VolumiDCE_Sub_AllBox_2D/0_cavo/107_DAntono_a_244_5.mat
#   inflating: /content/VolumiDCE_Sub_AllBox_2D/0_cavo/107_DAntono_a_39_1.mat
#   inflating: /content/VolumiDCE_Sub_AllBox_2D/0_cavo/107_DAntono_a_48_8.mat
#   inflating: /content/VolumiDCE_Sub_AllBox_2D/0_cavo/108_DeFilippis_b_12_1.mat
#   inflating: /content/VolumiDCE_Sub_AllBox_2D/0_cavo/108_DeFilippis_b_133_10.mat
#   inflating: /content/VolumiDCE_Sub_AllBox_2D/0_cavo/108_DeFilippis_b_176_3.mat
#   inflating: /content/VolumiDCE_Sub_AllBox_2D/0_cavo/108_DeFilippis_b_21_11.mat
#   inflating: /content/VolumiDCE_Sub_AllBox_2D/0_cavo/108_DeFilippis_b_243_4.mat
#   inflating: /content/VolumiDCE_Sub_AllBox_2D/0_cavo/108_DeFilippis_b_278_9.mat
#   inflating: /content/VolumiDCE_Sub_AllBox_2D/0_cavo/108_DeFilippis_b_336_5.mat
#   inflating: /content/VolumiDCE_Sub_AllBox_2D/0_cavo/108_DeFilippis_b_337_8.mat
#   inflating: /content/VolumiDCE_Sub_AllBox_2D/0_cavo/108_DeFilippis_b_348_6.mat
#   inflating: /content/VolumiDCE_Sub_AllBox_2D/0_cavo/108_DeFilippis_b_403_7.mat
#   inflating: /content/VolumiDCE_Sub_AllBox_2D/0_cavo/108_DeFilippis_b_97_2.mat
#   inflating: /content/VolumiDCE_Sub_AllBox_2D/0_cavo/109_DelMonte_b_130_23.mat
#   inflating: /content/VolumiDCE_Sub_AllBox_2D/0_cavo/109_DelMonte_b_137_22.mat
#   inflating: /content/VolumiDCE_Sub_AllBox_2D/0_cavo/109_DelMonte_b_146_24.mat
#   inflating: /content/VolumiDCE_Sub_AllBox_2D/0_cavo/109_DelMonte_b_159_29.mat
#   inflating: /content/VolumiDCE_Sub_AllBox_2D/0_cavo/109_DelMonte_b_165_26.mat
#   inflating: /content/VolumiDCE_Sub_AllBox_2D/0_cavo/109_DelMonte_b_178_2.mat
#   inflating: /content/VolumiDCE_Sub_AllBox_2D/0_cavo/109_DelMonte_b_182_25.mat
#   inflating: /content/VolumiDCE_Sub_AllBox_2D/0_cavo/109_DelMonte_b_210_21.mat
#   inflating: /content/VolumiDCE_Sub_AllBox_2D/0_cavo/109_DelMonte_b_253_12.mat
#   inflating: /content/VolumiDCE_Sub_AllBox_2D/0_cavo/109_DelMonte_b_282_11.mat
#   inflating: /content/VolumiDCE_Sub_AllBox_2D/0_cavo/109_DelMonte_b_305_20.mat
#   inflating: /content/VolumiDCE_Sub_AllBox_2D/0_cavo/109_DelMonte_b_386_13.mat
#   inflating: /content/VolumiDCE_Sub_AllBox_2D/0_cavo/109_DelMonte_b_436_7.mat
#   inflating: /content/VolumiDCE_Sub_AllBox_2D/0_cavo/109_DelMonte_b_516_9.mat
#   inflating: /content/VolumiDCE_Sub_AllBox_2D/0_cavo/109_DelMonte_b_528_10.mat
#   inflating: /content/VolumiDCE_Sub_AllBox_2D/0_cavo/109_DelMonte_b_563_15.mat
#   inflating: /content/VolumiDCE_Sub_AllBox_2D/0_cavo/109_DelMonte_b_602_16.mat
#   inflating: /content/VolumiDCE_Sub_AllBox_2D/0_cavo/109_DelMonte_b_618_19.mat
#   inflating: /content/VolumiDCE_Sub_AllBox_2D/0_cavo/109_DelMonte_b_61_28.mat
#   inflating: /content/VolumiDCE_Sub_AllBox_2D/0_cavo/109_DelMonte_b_674_4.mat
#   inflating: /content/VolumiDCE_Sub_AllBox_2D/0_cavo/109_DelMonte_b_690_14.mat
#   inflating: /content/VolumiDCE_Sub_AllBox_2D/0_cavo/109_DelMonte_b_696_17.mat
#   inflating: /content/VolumiDCE_Sub_AllBox_2D/0_cavo/109_DelMonte_b_738_18.mat
#   inflating: /content/VolumiDCE_Sub_AllBox_2D/0_cavo/109_DelMonte_b_775_8.mat
#   inflating: /content/VolumiDCE_Sub_AllBox_2D/0_cavo/109_DelMonte_b_784_5.mat
#   inflating: /content/VolumiDCE_Sub_AllBox_2D/0_cavo/109_DelMonte_b_86_1.mat
#   inflating: /content/VolumiDCE_Sub_AllBox_2D/0_cavo/109_DelMonte_b_86_27.mat
#   inflating: /content/VolumiDCE_Sub_AllBox_2D/0_cavo/109_DelMonte_b_872_3.mat
#   inflating: /content/VolumiDCE_Sub_AllBox_2D/0_cavo/109_DelMonte_b_961_6.mat
#   inflating: /content/VolumiDCE_Sub_AllBox_2D/0_cavo/10_Cappellacci_a_105_15.mat
#   inflating: /content/VolumiDCE_Sub_AllBox_2D/0_cavo/10_Cappellacci_a_107_13.mat
#   inflating: /content/VolumiDCE_Sub_AllBox_2D/0_cavo/10_Cappellacci_a_113_34.mat
#   inflating: /content/VolumiDCE_Sub_AllBox_2D/0_cavo/10_Cappellacci_a_116_10.mat
#   inflating: /content/VolumiDCE_Sub_AllBox_2D/0_cavo/10_Cappellacci_a_134_36.mat
#   inflating: /content/VolumiDCE_Sub_AllBox_2D/0_cavo/10_Cappellacci_a_142_39.mat
#   inflating: /content/VolumiDCE_Sub_AllBox_2D/0_cavo/10_Cappellacci_a_144_18.mat
#   inflating: /content/VolumiDCE_Sub_AllBox_2D/0_cavo/10_Cappellacci_a_166_23.mat
#   inflating: /content/VolumiDCE_Sub_AllBox_2D/0_cavo/10_Cappellacci_a_201_2.mat
#   inflating: /content/VolumiDCE_Sub_AllBox_2D/0_cavo/10_Cappellacci_a_207_16.mat
#   inflating: /content/VolumiDCE_Sub_AllBox_2D/0_cavo/10_Cappellacci_a_20_32.mat
#   inflating: /content/VolumiDCE_Sub_AllBox_2D/0_cavo/10_Cappellacci_a_211_3.mat
#   inflating: /content/VolumiDCE_Sub_AllBox_2D/0_cavo/10_Cappellacci_a_229_11.mat
#   inflating: /content/VolumiDCE_Sub_AllBox_2D/0_cavo/10_Cappellacci_a_244_12.mat
#   inflating: /content/VolumiDCE_Sub_AllBox_2D/0_cavo/10_Cappellacci_a_244_9.mat
#   inflating: /content/VolumiDCE_Sub_AllBox_2D/0_cavo/10_Cappellacci_a_25_25.mat
#   inflating: /content/VolumiDCE_Sub_AllBox_2D/0_cavo/10_Cappellacci_a_270_17.mat
#   inflating: /content/VolumiDCE_Sub_AllBox_2D/0_cavo/10_Cappellacci_a_278_19.mat
#   inflating: /content/VolumiDCE_Sub_AllBox_2D/0_cavo/10_Cappellacci_a_278_22.mat
#   inflating: /content/VolumiDCE_Sub_AllBox_2D/0_cavo/10_Cappellacci_a_288_35.mat
#   inflating: /content/VolumiDCE_Sub_AllBox_2D/0_cavo/10_Cappellacci_a_29_26.mat
#   inflating: /content/VolumiDCE_Sub_AllBox_2D/0_cavo/10_Cappellacci_a_318_8.mat
#   inflating: /content/VolumiDCE_Sub_AllBox_2D/0_cavo/10_Cappellacci_a_333_20.mat
#   inflating: /content/VolumiDCE_Sub_AllBox_2D/0_cavo/10_Cappellacci_a_340_21.mat
#   inflating: /content/VolumiDCE_Sub_AllBox_2D/0_cavo/10_Cappellacci_a_40_1.mat
#   inflating: /content/VolumiDCE_Sub_AllBox_2D/0_cavo/10_Cappellacci_a_40_38.mat
#   inflating: /content/VolumiDCE_Sub_AllBox_2D/0_cavo/10_Cappellacci_a_42_28.mat
#   inflating: /content/VolumiDCE_Sub_AllBox_2D/0_cavo/10_Cappellacci_a_43_31.mat
#   inflating: /content/VolumiDCE_Sub_AllBox_2D/0_cavo/10_Cappellacci_a_46_30.mat
#   inflating: /content/VolumiDCE_Sub_AllBox_2D/0_cavo/10_Cappellacci_a_46_40.mat
#   inflating: /content/VolumiDCE_Sub_AllBox_2D/0_cavo/10_Cappellacci_a_490_7.mat
#   inflating: /content/VolumiDCE_Sub_AllBox_2D/0_cavo/10_Cappellacci_a_49_29.mat
#   inflating: /content/VolumiDCE_Sub_AllBox_2D/0_cavo/10_Cappellacci_a_52_37.mat
#   inflating: /content/VolumiDCE_Sub_AllBox_2D/0_cavo/10_Cappellacci_a_546_4.mat
#   inflating: /content/VolumiDCE_Sub_AllBox_2D/0_cavo/10_Cappellacci_a_60_14.mat
#   inflating: /content/VolumiDCE_Sub_AllBox_2D/0_cavo/10_Cappellacci_a_61_24.mat
#   inflating: /content/VolumiDCE_Sub_AllBox_2D/0_cavo/10_Cappellacci_a_689_6.mat
#   inflating: /content/VolumiDCE_Sub_AllBox_2D/0_cavo/10_Cappellacci_a_76_33.mat
#   inflating: /content/VolumiDCE_Sub_AllBox_2D/0_cavo/10_Cappellacci_a_785_5.mat
#   inflating: /content/VolumiDCE_Sub_AllBox_2D/0_cavo/10_Cappellacci_a_96_27.mat
#   inflating: /content/VolumiDCE_Sub_AllBox_2D/0_cavo/110_DellAquila_a_122_11.mat
#   inflating: /content/VolumiDCE_Sub_AllBox_2D/0_cavo/110_DellAquila_a_139_3.mat
#   inflating: /content/VolumiDCE_Sub_AllBox_2D/0_cavo/110_DellAquila_a_142_10.mat
#   inflating: /content/VolumiDCE_Sub_AllBox_2D/0_cavo/110_DellAquila_a_142_4.mat
#   inflating: /content/VolumiDCE_Sub_AllBox_2D/0_cavo/110_DellAquila_a_180_5.mat
#   inflating: /content/VolumiDCE_Sub_AllBox_2D/0_cavo/110_DellAquila_a_182_6.mat
#   inflating: /content/VolumiDCE_Sub_AllBox_2D/0_cavo/110_DellAquila_a_196_8.mat
#   inflating: /content/VolumiDCE_Sub_AllBox_2D/0_cavo/110_DellAquila_a_199_7.mat
#   inflating: /content/VolumiDCE_Sub_AllBox_2D/0_cavo/110_DellAquila_a_206_9.mat
#   inflating: /content/VolumiDCE_Sub_AllBox_2D/0_cavo/110_DellAquila_a_30_1.mat
#   inflating: /content/VolumiDCE_Sub_AllBox_2D/0_cavo/110_DellAquila_a_53_12.mat
#   inflating: /content/VolumiDCE_Sub_AllBox_2D/0_cavo/110_DellAquila_a_98_2.mat
#   inflating: /content/VolumiDCE_Sub_AllBox_2D/0_cavo/111_DiGiammartino_b_126_4.mat
#   inflating: /content/VolumiDCE_Sub_AllBox_2D/0_cavo/111_DiGiammartino_b_129_3.mat
#   inflating: /content/VolumiDCE_Sub_AllBox_2D/0_cavo/111_DiGiammartino_b_133_6.mat
#   inflating: /content/VolumiDCE_Sub_AllBox_2D/0_cavo/111_DiGiammartino_b_133_7.mat
#   inflating: /content/VolumiDCE_Sub_AllBox_2D/0_cavo/111_DiGiammartino_b_46_1.mat
#   inflating: /content/VolumiDCE_Sub_AllBox_2D/0_cavo/111_DiGiammartino_b_62_8.mat
#   inflating: /content/VolumiDCE_Sub_AllBox_2D/0_cavo/111_DiGiammartino_b_86_2.mat
#   inflating: /content/VolumiDCE_Sub_AllBox_2D/0_cavo/111_DiGiammartino_b_96_5.mat
#   inflating: /content/VolumiDCE_Sub_AllBox_2D/0_cavo/112_Donzelli_b_142_14.mat
#   inflating: /content/VolumiDCE_Sub_AllBox_2D/0_cavo/112_Donzelli_b_190_3.mat
#   inflating: /content/VolumiDCE_Sub_AllBox_2D/0_cavo/112_Donzelli_b_220_13.mat
#   inflating: /content/VolumiDCE_Sub_AllBox_2D/0_cavo/112_Donzelli_b_222_12.mat
#   inflating: /content/VolumiDCE_Sub_AllBox_2D/0_cavo/112_Donzelli_b_263_4.mat
#   inflating: /content/VolumiDCE_Sub_AllBox_2D/0_cavo/112_Donzelli_b_277_11.mat
#   inflating: /content/VolumiDCE_Sub_AllBox_2D/0_cavo/112_Donzelli_b_277_5.mat
#   inflating: /content/VolumiDCE_Sub_AllBox_2D/0_cavo/112_Donzelli_b_351_8.mat
#   inflating: /content/VolumiDCE_Sub_AllBox_2D/0_cavo/112_Donzelli_b_351_9.mat
#   inflating: /content/VolumiDCE_Sub_AllBox_2D/0_cavo/112_Donzelli_b_35_1.mat
#   inflating: /content/VolumiDCE_Sub_AllBox_2D/0_cavo/112_Donzelli_b_39_2.mat
#   inflating: /content/VolumiDCE_Sub_AllBox_2D/0_cavo/112_Donzelli_b_401_10.mat
#   inflating: /content/VolumiDCE_Sub_AllBox_2D/0_cavo/112_Donzelli_b_410_6.mat
#   inflating: /content/VolumiDCE_Sub_AllBox_2D/0_cavo/112_Donzelli_b_422_7.mat
#   inflating: /content/VolumiDCE_Sub_AllBox_2D/0_cavo/112_Donzelli_b_95_15.mat
#   inflating: /content/VolumiDCE_Sub_AllBox_2D/0_cavo/113_Evangelisti_a_15_16.mat
#   inflating: /content/VolumiDCE_Sub_AllBox_2D/0_cavo/113_Evangelisti_a_173_12.mat
#   inflating: /content/VolumiDCE_Sub_AllBox_2D/0_cavo/113_Evangelisti_a_175_13.mat
#   inflating: /content/VolumiDCE_Sub_AllBox_2D/0_cavo/113_Evangelisti_a_17_2.mat
#   inflating: /content/VolumiDCE_Sub_AllBox_2D/0_cavo/113_Evangelisti_a_214_11.mat
#   inflating: /content/VolumiDCE_Sub_AllBox_2D/0_cavo/113_Evangelisti_a_230_5.mat
#   inflating: /content/VolumiDCE_Sub_AllBox_2D/0_cavo/113_Evangelisti_a_233_7.mat
#   inflating: /content/VolumiDCE_Sub_AllBox_2D/0_cavo/113_Evangelisti_a_246_8.mat
#   inflating: /content/VolumiDCE_Sub_AllBox_2D/0_cavo/113_Evangelisti_a_256_6.mat
#   inflating: /content/VolumiDCE_Sub_AllBox_2D/0_cavo/113_Evangelisti_a_298_10.mat
#   inflating: /content/VolumiDCE_Sub_AllBox_2D/0_cavo/113_Evangelisti_a_308_4.mat
#   inflating: /content/VolumiDCE_Sub_AllBox_2D/0_cavo/113_Evangelisti_a_323_9.mat
#   inflating: /content/VolumiDCE_Sub_AllBox_2D/0_cavo/113_Evangelisti_a_3_1.mat
#   inflating: /content/VolumiDCE_Sub_AllBox_2D/0_cavo/113_Evangelisti_a_69_14.mat
#   inflating: /content/VolumiDCE_Sub_AllBox_2D/0_cavo/113_Evangelisti_a_69_15.mat
#   inflating: /content/VolumiDCE_Sub_AllBox_2D/0_cavo/113_Evangelisti_a_87_3.mat
#   inflating: /content/VolumiDCE_Sub_AllBox_2D/0_cavo/114_Falconi_b_1046_28.mat
#   inflating: /content/VolumiDCE_Sub_AllBox_2D/0_cavo/114_Falconi_b_104_4.mat
#   inflating: /content/VolumiDCE_Sub_AllBox_2D/0_cavo/114_Falconi_b_1133_23.mat
#   inflating: /content/VolumiDCE_Sub_AllBox_2D/0_cavo/114_Falconi_b_1166_26.mat
#   inflating: /content/VolumiDCE_Sub_AllBox_2D/0_cavo/114_Falconi_b_1180_27.mat
#   inflating: /content/VolumiDCE_Sub_AllBox_2D/0_cavo/114_Falconi_b_1203_17.mat
#   inflating: /content/VolumiDCE_Sub_AllBox_2D/0_cavo/114_Falconi_b_1253_20.mat
#   inflating: /content/VolumiDCE_Sub_AllBox_2D/0_cavo/114_Falconi_b_1276_18.mat
#   inflating: /content/VolumiDCE_Sub_AllBox_2D/0_cavo/114_Falconi_b_1321_25.mat
#   inflating: /content/VolumiDCE_Sub_AllBox_2D/0_cavo/114_Falconi_b_1339_24.mat
#   inflating: /content/VolumiDCE_Sub_AllBox_2D/0_cavo/114_Falconi_b_1356_22.mat
#   inflating: /content/VolumiDCE_Sub_AllBox_2D/0_cavo/114_Falconi_b_1359_21.mat
#   inflating: /content/VolumiDCE_Sub_AllBox_2D/0_cavo/114_Falconi_b_1735_19.mat
#   inflating: /content/VolumiDCE_Sub_AllBox_2D/0_cavo/114_Falconi_b_174_6.mat
#   inflating: /content/VolumiDCE_Sub_AllBox_2D/0_cavo/114_Falconi_b_208_33.mat
#   inflating: /content/VolumiDCE_Sub_AllBox_2D/0_cavo/114_Falconi_b_244_8.mat
#   inflating: /content/VolumiDCE_Sub_AllBox_2D/0_cavo/114_Falconi_b_267_5.mat
#   inflating: /content/VolumiDCE_Sub_AllBox_2D/0_cavo/114_Falconi_b_2_1.mat
#   inflating: /content/VolumiDCE_Sub_AllBox_2D/0_cavo/114_Falconi_b_308_32.mat
#   inflating: /content/VolumiDCE_Sub_AllBox_2D/0_cavo/114_Falconi_b_324_7.mat
#   inflating: /content/VolumiDCE_Sub_AllBox_2D/0_cavo/114_Falconi_b_348_9.mat
#   inflating: /content/VolumiDCE_Sub_AllBox_2D/0_cavo/114_Falconi_b_359_11.mat
#   inflating: /content/VolumiDCE_Sub_AllBox_2D/0_cavo/114_Falconi_b_3_2.mat
#   inflating: /content/VolumiDCE_Sub_AllBox_2D/0_cavo/114_Falconi_b_411_10.mat
#   inflating: /content/VolumiDCE_Sub_AllBox_2D/0_cavo/114_Falconi_b_485_13.mat
#   inflating: /content/VolumiDCE_Sub_AllBox_2D/0_cavo/114_Falconi_b_4_3.mat
#   inflating: /content/VolumiDCE_Sub_AllBox_2D/0_cavo/114_Falconi_b_547_31.mat
#   inflating: /content/VolumiDCE_Sub_AllBox_2D/0_cavo/114_Falconi_b_557_12.mat
#   inflating: /content/VolumiDCE_Sub_AllBox_2D/0_cavo/114_Falconi_b_56_34.mat
#   inflating: /content/VolumiDCE_Sub_AllBox_2D/0_cavo/114_Falconi_b_741_30.mat
#   inflating: /content/VolumiDCE_Sub_AllBox_2D/0_cavo/114_Falconi_b_742_29.mat
#   inflating: /content/VolumiDCE_Sub_AllBox_2D/0_cavo/114_Falconi_b_895_14.mat
#   inflating: /content/VolumiDCE_Sub_AllBox_2D/0_cavo/114_Falconi_b_950_15.mat
#   inflating: /content/VolumiDCE_Sub_AllBox_2D/0_cavo/114_Falconi_b_967_16.mat
#   inflating: /content/VolumiDCE_Sub_AllBox_2D/0_cavo/117_Feroci_b_149_3.mat
#   inflating: /content/VolumiDCE_Sub_AllBox_2D/0_cavo/117_Feroci_b_183_9.mat
#   inflating: /content/VolumiDCE_Sub_AllBox_2D/0_cavo/117_Feroci_b_202_4.mat
#   inflating: /content/VolumiDCE_Sub_AllBox_2D/0_cavo/117_Feroci_b_203_8.mat
#   inflating: /content/VolumiDCE_Sub_AllBox_2D/0_cavo/117_Feroci_b_224_5.mat
#   inflating: /content/VolumiDCE_Sub_AllBox_2D/0_cavo/117_Feroci_b_250_7.mat
#   inflating: /content/VolumiDCE_Sub_AllBox_2D/0_cavo/117_Feroci_b_272_6.mat
#   inflating: /content/VolumiDCE_Sub_AllBox_2D/0_cavo/117_Feroci_b_31_11.mat
#   inflating: /content/VolumiDCE_Sub_AllBox_2D/0_cavo/117_Feroci_b_50_10.mat
#   inflating: /content/VolumiDCE_Sub_AllBox_2D/0_cavo/117_Feroci_b_65_2.mat
#   inflating: /content/VolumiDCE_Sub_AllBox_2D/0_cavo/117_Feroci_b_7_1.mat
#   inflating: /content/VolumiDCE_Sub_AllBox_2D/0_cavo/119-120_Fiorentini_a_111_5.mat
#   inflating: /content/VolumiDCE_Sub_AllBox_2D/0_cavo/119-120_Fiorentini_a_118_2.mat
#   inflating: /content/VolumiDCE_Sub_AllBox_2D/0_cavo/119-120_Fiorentini_a_35_8.mat
#   inflating: /content/VolumiDCE_Sub_AllBox_2D/0_cavo/119-120_Fiorentini_a_58_7.mat
#   inflating: /content/VolumiDCE_Sub_AllBox_2D/0_cavo/119-120_Fiorentini_a_62_1.mat
#   inflating: /content/VolumiDCE_Sub_AllBox_2D/0_cavo/119-120_Fiorentini_a_84_6.mat
#   inflating: /content/VolumiDCE_Sub_AllBox_2D/0_cavo/119-120_Fiorentini_a_99_3.mat
#   inflating: /content/VolumiDCE_Sub_AllBox_2D/0_cavo/119-120_Fiorentini_a_99_4.mat
#   inflating: /content/VolumiDCE_Sub_AllBox_2D/0_cavo/11_Monculli_b_117_2.mat
#   inflating: /content/VolumiDCE_Sub_AllBox_2D/0_cavo/11_Monculli_b_140_4.mat
#   inflating: /content/VolumiDCE_Sub_AllBox_2D/0_cavo/11_Monculli_b_151_3.mat
#   inflating: /content/VolumiDCE_Sub_AllBox_2D/0_cavo/11_Monculli_b_172_5.mat
#   inflating: /content/VolumiDCE_Sub_AllBox_2D/0_cavo/11_Monculli_b_19_6.mat
#   inflating: /content/VolumiDCE_Sub_AllBox_2D/0_cavo/11_Monculli_b_26_1.mat
#   inflating: /content/VolumiDCE_Sub_AllBox_2D/0_cavo/121_Fiori_a_106_11.mat
#   inflating: /content/VolumiDCE_Sub_AllBox_2D/0_cavo/121_Fiori_a_11_13.mat
#   inflating: /content/VolumiDCE_Sub_AllBox_2D/0_cavo/121_Fiori_a_169_9.mat
#   inflating: /content/VolumiDCE_Sub_AllBox_2D/0_cavo/121_Fiori_a_179_8.mat
#   inflating: /content/VolumiDCE_Sub_AllBox_2D/0_cavo/121_Fiori_a_188_10.mat
#   inflating: /content/VolumiDCE_Sub_AllBox_2D/0_cavo/121_Fiori_a_188_3.mat
#   inflating: /content/VolumiDCE_Sub_AllBox_2D/0_cavo/121_Fiori_a_212_7.mat
#   inflating: /content/VolumiDCE_Sub_AllBox_2D/0_cavo/121_Fiori_a_219_6.mat
#   inflating: /content/VolumiDCE_Sub_AllBox_2D/0_cavo/121_Fiori_a_220_4.mat
#   inflating: /content/VolumiDCE_Sub_AllBox_2D/0_cavo/121_Fiori_a_240_5.mat
#   inflating: /content/VolumiDCE_Sub_AllBox_2D/0_cavo/121_Fiori_a_39_1.mat
#   inflating: /content/VolumiDCE_Sub_AllBox_2D/0_cavo/121_Fiori_a_48_12.mat
#   inflating: /content/VolumiDCE_Sub_AllBox_2D/0_cavo/121_Fiori_a_95_2.mat
#   inflating: /content/VolumiDCE_Sub_AllBox_2D/0_cavo/122_Francellini_b_109_24.mat
#   inflating: /content/VolumiDCE_Sub_AllBox_2D/0_cavo/122_Francellini_b_161_23.mat
#   inflating: /content/VolumiDCE_Sub_AllBox_2D/0_cavo/122_Francellini_b_172_4.mat
#   inflating: /content/VolumiDCE_Sub_AllBox_2D/0_cavo/122_Francellini_b_192_6.mat
#   inflating: /content/VolumiDCE_Sub_AllBox_2D/0_cavo/122_Francellini_b_216_7.mat
#   inflating: /content/VolumiDCE_Sub_AllBox_2D/0_cavo/122_Francellini_b_235_5.mat
#   inflating: /content/VolumiDCE_Sub_AllBox_2D/0_cavo/122_Francellini_b_254_8.mat
#   inflating: /content/VolumiDCE_Sub_AllBox_2D/0_cavo/122_Francellini_b_254_9.mat
#   inflating: /content/VolumiDCE_Sub_AllBox_2D/0_cavo/122_Francellini_b_259_10.mat
#   inflating: /content/VolumiDCE_Sub_AllBox_2D/0_cavo/122_Francellini_b_264_22.mat
#   inflating: /content/VolumiDCE_Sub_AllBox_2D/0_cavo/122_Francellini_b_287_21.mat
#   inflating: /content/VolumiDCE_Sub_AllBox_2D/0_cavo/122_Francellini_b_33_1.mat
#   inflating: /content/VolumiDCE_Sub_AllBox_2D/0_cavo/122_Francellini_b_340_12.mat
#   inflating: /content/VolumiDCE_Sub_AllBox_2D/0_cavo/122_Francellini_b_347_13.mat
#   inflating: /content/VolumiDCE_Sub_AllBox_2D/0_cavo/122_Francellini_b_348_11.mat
#   inflating: /content/VolumiDCE_Sub_AllBox_2D/0_cavo/122_Francellini_b_384_18.mat
#   inflating: /content/VolumiDCE_Sub_AllBox_2D/0_cavo/122_Francellini_b_384_19.mat
#   inflating: /content/VolumiDCE_Sub_AllBox_2D/0_cavo/122_Francellini_b_384_20.mat
#   inflating: /content/VolumiDCE_Sub_AllBox_2D/0_cavo/122_Francellini_b_390_17.mat
#   inflating: /content/VolumiDCE_Sub_AllBox_2D/0_cavo/122_Francellini_b_400_14.mat
#   inflating: /content/VolumiDCE_Sub_AllBox_2D/0_cavo/122_Francellini_b_457_15.mat
#   inflating: /content/VolumiDCE_Sub_AllBox_2D/0_cavo/122_Francellini_b_457_16.mat
#   inflating: /content/VolumiDCE_Sub_AllBox_2D/0_cavo/122_Francellini_b_47_2.mat
#   inflating: /content/VolumiDCE_Sub_AllBox_2D/0_cavo/122_Francellini_b_49_3.mat
#   inflating: /content/VolumiDCE_Sub_AllBox_2D/0_cavo/123_Fusco_a_133_4.mat
#   inflating: /content/VolumiDCE_Sub_AllBox_2D/0_cavo/123_Fusco_a_172_18.mat
#   inflating: /content/VolumiDCE_Sub_AllBox_2D/0_cavo/123_Fusco_a_204_3.mat
#   inflating: /content/VolumiDCE_Sub_AllBox_2D/0_cavo/123_Fusco_a_234_5.mat
#   inflating: /content/VolumiDCE_Sub_AllBox_2D/0_cavo/123_Fusco_a_234_6.mat
#   inflating: /content/VolumiDCE_Sub_AllBox_2D/0_cavo/123_Fusco_a_247_10.mat
#   inflating: /content/VolumiDCE_Sub_AllBox_2D/0_cavo/123_Fusco_a_272_11.mat
#   inflating: /content/VolumiDCE_Sub_AllBox_2D/0_cavo/123_Fusco_a_279_17.mat
#   inflating: /content/VolumiDCE_Sub_AllBox_2D/0_cavo/123_Fusco_a_306_8.mat
#   inflating: /content/VolumiDCE_Sub_AllBox_2D/0_cavo/123_Fusco_a_311_7.mat
#   inflating: /content/VolumiDCE_Sub_AllBox_2D/0_cavo/123_Fusco_a_341_12.mat
#   inflating: /content/VolumiDCE_Sub_AllBox_2D/0_cavo/123_Fusco_a_343_9.mat
#   inflating: /content/VolumiDCE_Sub_AllBox_2D/0_cavo/123_Fusco_a_355_14.mat
#   inflating: /content/VolumiDCE_Sub_AllBox_2D/0_cavo/123_Fusco_a_358_13.mat
#   inflating: /content/VolumiDCE_Sub_AllBox_2D/0_cavo/123_Fusco_a_35_1.mat
#   inflating: /content/VolumiDCE_Sub_AllBox_2D/0_cavo/123_Fusco_a_360_15.mat
#   inflating: /content/VolumiDCE_Sub_AllBox_2D/0_cavo/123_Fusco_a_393_16.mat
#   inflating: /content/VolumiDCE_Sub_AllBox_2D/0_cavo/123_Fusco_a_86_19.mat
#   inflating: /content/VolumiDCE_Sub_AllBox_2D/0_cavo/123_Fusco_a_92_2.mat
#   inflating: /content/VolumiDCE_Sub_AllBox_2D/0_cavo/124_Gagliardi_b_124_45.mat
#   inflating: /content/VolumiDCE_Sub_AllBox_2D/0_cavo/124_Gagliardi_b_137_18.mat
#   inflating: /content/VolumiDCE_Sub_AllBox_2D/0_cavo/124_Gagliardi_b_140_20.mat
#   inflating: /content/VolumiDCE_Sub_AllBox_2D/0_cavo/124_Gagliardi_b_141_4.mat
#   inflating: /content/VolumiDCE_Sub_AllBox_2D/0_cavo/124_Gagliardi_b_141_5.mat
#   inflating: /content/VolumiDCE_Sub_AllBox_2D/0_cavo/124_Gagliardi_b_159_7.mat
#   inflating: /content/VolumiDCE_Sub_AllBox_2D/0_cavo/124_Gagliardi_b_164_8.mat
#   inflating: /content/VolumiDCE_Sub_AllBox_2D/0_cavo/124_Gagliardi_b_167_37.mat
#   inflating: /content/VolumiDCE_Sub_AllBox_2D/0_cavo/124_Gagliardi_b_167_42.mat
#   inflating: /content/VolumiDCE_Sub_AllBox_2D/0_cavo/124_Gagliardi_b_177_9.mat
#   inflating: /content/VolumiDCE_Sub_AllBox_2D/0_cavo/124_Gagliardi_b_184_6.mat
#   inflating: /content/VolumiDCE_Sub_AllBox_2D/0_cavo/124_Gagliardi_b_202_11.mat
#   inflating: /content/VolumiDCE_Sub_AllBox_2D/0_cavo/124_Gagliardi_b_205_41.mat
#   inflating: /content/VolumiDCE_Sub_AllBox_2D/0_cavo/124_Gagliardi_b_208_17.mat
#   inflating: /content/VolumiDCE_Sub_AllBox_2D/0_cavo/124_Gagliardi_b_211_36.mat
#   inflating: /content/VolumiDCE_Sub_AllBox_2D/0_cavo/124_Gagliardi_b_221_10.mat
#   inflating: /content/VolumiDCE_Sub_AllBox_2D/0_cavo/124_Gagliardi_b_221_38.mat
#   inflating: /content/VolumiDCE_Sub_AllBox_2D/0_cavo/124_Gagliardi_b_226_39.mat
#   inflating: /content/VolumiDCE_Sub_AllBox_2D/0_cavo/124_Gagliardi_b_236_12.mat
#   inflating: /content/VolumiDCE_Sub_AllBox_2D/0_cavo/124_Gagliardi_b_23_1.mat
#   inflating: /content/VolumiDCE_Sub_AllBox_2D/0_cavo/124_Gagliardi_b_24_47.mat
#   inflating: /content/VolumiDCE_Sub_AllBox_2D/0_cavo/124_Gagliardi_b_250_21.mat
#   inflating: /content/VolumiDCE_Sub_AllBox_2D/0_cavo/124_Gagliardi_b_251_15.mat
#   inflating: /content/VolumiDCE_Sub_AllBox_2D/0_cavo/124_Gagliardi_b_256_14.mat
#   inflating: /content/VolumiDCE_Sub_AllBox_2D/0_cavo/124_Gagliardi_b_259_16.mat
#   inflating: /content/VolumiDCE_Sub_AllBox_2D/0_cavo/124_Gagliardi_b_260_43.mat
#   inflating: /content/VolumiDCE_Sub_AllBox_2D/0_cavo/124_Gagliardi_b_262_40.mat
#   inflating: /content/VolumiDCE_Sub_AllBox_2D/0_cavo/124_Gagliardi_b_26_2.mat
#   inflating: /content/VolumiDCE_Sub_AllBox_2D/0_cavo/124_Gagliardi_b_289_13.mat
#   inflating: /content/VolumiDCE_Sub_AllBox_2D/0_cavo/124_Gagliardi_b_311_34.mat
#   inflating: /content/VolumiDCE_Sub_AllBox_2D/0_cavo/124_Gagliardi_b_361_31.mat
#   inflating: /content/VolumiDCE_Sub_AllBox_2D/0_cavo/124_Gagliardi_b_380_32.mat
#   inflating: /content/VolumiDCE_Sub_AllBox_2D/0_cavo/124_Gagliardi_b_403_22.mat
#   inflating: /content/VolumiDCE_Sub_AllBox_2D/0_cavo/124_Gagliardi_b_404_23.mat
#   inflating: /content/VolumiDCE_Sub_AllBox_2D/0_cavo/124_Gagliardi_b_407_33.mat
#   inflating: /content/VolumiDCE_Sub_AllBox_2D/0_cavo/124_Gagliardi_b_416_29.mat
#   inflating: /content/VolumiDCE_Sub_AllBox_2D/0_cavo/124_Gagliardi_b_429_27.mat
#   inflating: /content/VolumiDCE_Sub_AllBox_2D/0_cavo/124_Gagliardi_b_429_35.mat
#   inflating: /content/VolumiDCE_Sub_AllBox_2D/0_cavo/124_Gagliardi_b_475_30.mat
#   inflating: /content/VolumiDCE_Sub_AllBox_2D/0_cavo/124_Gagliardi_b_492_24.mat
#   inflating: /content/VolumiDCE_Sub_AllBox_2D/0_cavo/124_Gagliardi_b_502_25.mat
#   inflating: /content/VolumiDCE_Sub_AllBox_2D/0_cavo/124_Gagliardi_b_570_28.mat
#   inflating: /content/VolumiDCE_Sub_AllBox_2D/0_cavo/124_Gagliardi_b_715_26.mat
#   inflating: /content/VolumiDCE_Sub_AllBox_2D/0_cavo/124_Gagliardi_b_72_3.mat
#   inflating: /content/VolumiDCE_Sub_AllBox_2D/0_cavo/124_Gagliardi_b_87_19.mat
#   inflating: /content/VolumiDCE_Sub_AllBox_2D/0_cavo/124_Gagliardi_b_89_44.mat
#   inflating: /content/VolumiDCE_Sub_AllBox_2D/0_cavo/124_Gagliardi_b_95_46.mat
#   inflating: /content/VolumiDCE_Sub_AllBox_2D/0_cavo/127_Granati_a_129_2.mat
#   inflating: /content/VolumiDCE_Sub_AllBox_2D/0_cavo/127_Granati_a_203_18.mat
#   inflating: /content/VolumiDCE_Sub_AllBox_2D/0_cavo/127_Granati_a_219_3.mat
#   inflating: /content/VolumiDCE_Sub_AllBox_2D/0_cavo/127_Granati_a_254_4.mat
#   inflating: /content/VolumiDCE_Sub_AllBox_2D/0_cavo/127_Granati_a_292_17.mat
#   inflating: /content/VolumiDCE_Sub_AllBox_2D/0_cavo/127_Granati_a_306_16.mat
#   inflating: /content/VolumiDCE_Sub_AllBox_2D/0_cavo/127_Granati_a_412_15.mat
#   inflating: /content/VolumiDCE_Sub_AllBox_2D/0_cavo/127_Granati_a_437_5.mat
#   inflating: /content/VolumiDCE_Sub_AllBox_2D/0_cavo/127_Granati_a_477_13.mat
#   inflating: /content/VolumiDCE_Sub_AllBox_2D/0_cavo/127_Granati_a_483_14.mat
#   inflating: /content/VolumiDCE_Sub_AllBox_2D/0_cavo/127_Granati_a_503_11.mat
#   inflating: /content/VolumiDCE_Sub_AllBox_2D/0_cavo/127_Granati_a_50_20.mat
#   inflating: /content/VolumiDCE_Sub_AllBox_2D/0_cavo/127_Granati_a_549_7.mat
#   inflating: /content/VolumiDCE_Sub_AllBox_2D/0_cavo/127_Granati_a_54_1.mat
#   inflating: /content/VolumiDCE_Sub_AllBox_2D/0_cavo/127_Granati_a_554_10.mat
#   inflating: /content/VolumiDCE_Sub_AllBox_2D/0_cavo/127_Granati_a_607_12.mat
#   inflating: /content/VolumiDCE_Sub_AllBox_2D/0_cavo/127_Granati_a_609_9.mat
#   inflating: /content/VolumiDCE_Sub_AllBox_2D/0_cavo/127_Granati_a_625_8.mat
#   inflating: /content/VolumiDCE_Sub_AllBox_2D/0_cavo/127_Granati_a_62_19.mat
#   inflating: /content/VolumiDCE_Sub_AllBox_2D/0_cavo/127_Granati_a_669_6.mat
#   inflating: /content/VolumiDCE_Sub_AllBox_2D/0_cavo/128_Gregori_a_140_4.mat
#   inflating: /content/VolumiDCE_Sub_AllBox_2D/0_cavo/128_Gregori_a_164_12.mat
#   inflating: /content/VolumiDCE_Sub_AllBox_2D/0_cavo/128_Gregori_a_20_1.mat
#   inflating: /content/VolumiDCE_Sub_AllBox_2D/0_cavo/128_Gregori_a_214_5.mat
#   inflating: /content/VolumiDCE_Sub_AllBox_2D/0_cavo/128_Gregori_a_240_11.mat
#   inflating: /content/VolumiDCE_Sub_AllBox_2D/0_cavo/128_Gregori_a_24_16.mat
#   inflating: /content/VolumiDCE_Sub_AllBox_2D/0_cavo/128_Gregori_a_268_10.mat
#   inflating: /content/VolumiDCE_Sub_AllBox_2D/0_cavo/128_Gregori_a_279_9.mat
#   inflating: /content/VolumiDCE_Sub_AllBox_2D/0_cavo/128_Gregori_a_321_6.mat
#   inflating: /content/VolumiDCE_Sub_AllBox_2D/0_cavo/128_Gregori_a_356_7.mat
#   inflating: /content/VolumiDCE_Sub_AllBox_2D/0_cavo/128_Gregori_a_356_8.mat
#   inflating: /content/VolumiDCE_Sub_AllBox_2D/0_cavo/128_Gregori_a_41_2.mat
#   inflating: /content/VolumiDCE_Sub_AllBox_2D/0_cavo/128_Gregori_a_45_15.mat
#   inflating: /content/VolumiDCE_Sub_AllBox_2D/0_cavo/128_Gregori_a_64_14.mat
#   inflating: /content/VolumiDCE_Sub_AllBox_2D/0_cavo/128_Gregori_a_68_13.mat
#   inflating: /content/VolumiDCE_Sub_AllBox_2D/0_cavo/128_Gregori_a_76_3.mat
#   inflating: /content/VolumiDCE_Sub_AllBox_2D/0_cavo/129_Gueli_b_116_7.mat
#   inflating: /content/VolumiDCE_Sub_AllBox_2D/0_cavo/129_Gueli_b_34_9.mat
#   inflating: /content/VolumiDCE_Sub_AllBox_2D/0_cavo/129_Gueli_b_48_1.mat
#   inflating: /content/VolumiDCE_Sub_AllBox_2D/0_cavo/129_Gueli_b_54_2.mat
#   inflating: /content/VolumiDCE_Sub_AllBox_2D/0_cavo/129_Gueli_b_55_8.mat
#   inflating: /content/VolumiDCE_Sub_AllBox_2D/0_cavo/129_Gueli_b_6_10.mat
#   inflating: /content/VolumiDCE_Sub_AllBox_2D/0_cavo/129_Gueli_b_71_3.mat
#   inflating: /content/VolumiDCE_Sub_AllBox_2D/0_cavo/129_Gueli_b_71_4.mat
#   inflating: /content/VolumiDCE_Sub_AllBox_2D/0_cavo/129_Gueli_b_83_6.mat
#   inflating: /content/VolumiDCE_Sub_AllBox_2D/0_cavo/129_Gueli_b_92_5.mat
#   inflating: /content/VolumiDCE_Sub_AllBox_2D/0_cavo/13-14_Cecchetti_a_102_2.mat
#   inflating: /content/VolumiDCE_Sub_AllBox_2D/0_cavo/13-14_Cecchetti_a_128_16.mat
#   inflating: /content/VolumiDCE_Sub_AllBox_2D/0_cavo/13-14_Cecchetti_a_182_3.mat
#   inflating: /content/VolumiDCE_Sub_AllBox_2D/0_cavo/13-14_Cecchetti_a_250_15.mat
#   inflating: /content/VolumiDCE_Sub_AllBox_2D/0_cavo/13-14_Cecchetti_a_291_4.mat
#   inflating: /content/VolumiDCE_Sub_AllBox_2D/0_cavo/13-14_Cecchetti_a_315_5.mat
#   inflating: /content/VolumiDCE_Sub_AllBox_2D/0_cavo/13-14_Cecchetti_a_33_17.mat
#   inflating: /content/VolumiDCE_Sub_AllBox_2D/0_cavo/13-14_Cecchetti_a_354_14.mat
#   inflating: /content/VolumiDCE_Sub_AllBox_2D/0_cavo/13-14_Cecchetti_a_409_6.mat
#   inflating: /content/VolumiDCE_Sub_AllBox_2D/0_cavo/13-14_Cecchetti_a_435_13.mat
#   inflating: /content/VolumiDCE_Sub_AllBox_2D/0_cavo/13-14_Cecchetti_a_459_12.mat
#   inflating: /content/VolumiDCE_Sub_AllBox_2D/0_cavo/13-14_Cecchetti_a_464_7.mat
#   inflating: /content/VolumiDCE_Sub_AllBox_2D/0_cavo/13-14_Cecchetti_a_531_9.mat
#   inflating: /content/VolumiDCE_Sub_AllBox_2D/0_cavo/13-14_Cecchetti_a_533_8.mat
#   inflating: /content/VolumiDCE_Sub_AllBox_2D/0_cavo/13-14_Cecchetti_a_541_11.mat
#   inflating: /content/VolumiDCE_Sub_AllBox_2D/0_cavo/13-14_Cecchetti_a_556_10.mat
#   inflating: /content/VolumiDCE_Sub_AllBox_2D/0_cavo/13-14_Cecchetti_a_55_1.mat
#   inflating: /content/VolumiDCE_Sub_AllBox_2D/0_cavo/13-14_Cecchetti_b_130_3.mat
#   inflating: /content/VolumiDCE_Sub_AllBox_2D/0_cavo/13-14_Cecchetti_b_157_4.mat
#   inflating: /content/VolumiDCE_Sub_AllBox_2D/0_cavo/13-14_Cecchetti_b_159_8.mat
#   inflating: /content/VolumiDCE_Sub_AllBox_2D/0_cavo/13-14_Cecchetti_b_178_6.mat
#   inflating: /content/VolumiDCE_Sub_AllBox_2D/0_cavo/13-14_Cecchetti_b_184_5.mat
#   inflating: /content/VolumiDCE_Sub_AllBox_2D/0_cavo/13-14_Cecchetti_b_190_7.mat
#   inflating: /content/VolumiDCE_Sub_AllBox_2D/0_cavo/13-14_Cecchetti_b_48_1.mat
#   inflating: /content/VolumiDCE_Sub_AllBox_2D/0_cavo/13-14_Cecchetti_b_49_10.mat
#   inflating: /content/VolumiDCE_Sub_AllBox_2D/0_cavo/13-14_Cecchetti_b_89_9.mat
#   inflating: /content/VolumiDCE_Sub_AllBox_2D/0_cavo/13-14_Cecchetti_b_92_2.mat
#   inflating: /content/VolumiDCE_Sub_AllBox_2D/0_cavo/130_HAILEMARIAM_b_1109_21.mat
#   inflating: /content/VolumiDCE_Sub_AllBox_2D/0_cavo/130_HAILEMARIAM_b_124_31.mat
#   inflating: /content/VolumiDCE_Sub_AllBox_2D/0_cavo/130_HAILEMARIAM_b_1406_18.mat
#   inflating: /content/VolumiDCE_Sub_AllBox_2D/0_cavo/130_HAILEMARIAM_b_142_32.mat
#   inflating: /content/VolumiDCE_Sub_AllBox_2D/0_cavo/130_HAILEMARIAM_b_145_30.mat
#  extracting: /content/VolumiDCE_Sub_AllBox_2D/0_cavo/130_HAILEMARIAM_b_1493_19.mat
#  extracting: /content/VolumiDCE_Sub_AllBox_2D/0_cavo/130_HAILEMARIAM_b_1521_20.mat
#   inflating: /content/VolumiDCE_Sub_AllBox_2D/0_cavo/130_HAILEMARIAM_b_17_1.mat
#   inflating: /content/VolumiDCE_Sub_AllBox_2D/0_cavo/130_HAILEMARIAM_b_180_6.mat
#   inflating: /content/VolumiDCE_Sub_AllBox_2D/0_cavo/130_HAILEMARIAM_b_186_5.mat
#   inflating: /content/VolumiDCE_Sub_AllBox_2D/0_cavo/130_HAILEMARIAM_b_21_2.mat
#   inflating: /content/VolumiDCE_Sub_AllBox_2D/0_cavo/130_HAILEMARIAM_b_224_7.mat
#   inflating: /content/VolumiDCE_Sub_AllBox_2D/0_cavo/130_HAILEMARIAM_b_236_29.mat
#   inflating: /content/VolumiDCE_Sub_AllBox_2D/0_cavo/130_HAILEMARIAM_b_246_8.mat
#   inflating: /content/VolumiDCE_Sub_AllBox_2D/0_cavo/130_HAILEMARIAM_b_338_9.mat
#   inflating: /content/VolumiDCE_Sub_AllBox_2D/0_cavo/130_HAILEMARIAM_b_33_3.mat
#   inflating: /content/VolumiDCE_Sub_AllBox_2D/0_cavo/130_HAILEMARIAM_b_344_10.mat
#   inflating: /content/VolumiDCE_Sub_AllBox_2D/0_cavo/130_HAILEMARIAM_b_528_13.mat
#   inflating: /content/VolumiDCE_Sub_AllBox_2D/0_cavo/130_HAILEMARIAM_b_528_14.mat
#   inflating: /content/VolumiDCE_Sub_AllBox_2D/0_cavo/130_HAILEMARIAM_b_52_35.mat
#   inflating: /content/VolumiDCE_Sub_AllBox_2D/0_cavo/130_HAILEMARIAM_b_571_12.mat
#   inflating: /content/VolumiDCE_Sub_AllBox_2D/0_cavo/130_HAILEMARIAM_b_60_4.mat
#   inflating: /content/VolumiDCE_Sub_AllBox_2D/0_cavo/130_HAILEMARIAM_b_686_26.mat
#   inflating: /content/VolumiDCE_Sub_AllBox_2D/0_cavo/130_HAILEMARIAM_b_705_17.mat
#   inflating: /content/VolumiDCE_Sub_AllBox_2D/0_cavo/130_HAILEMARIAM_b_707_24.mat
#   inflating: /content/VolumiDCE_Sub_AllBox_2D/0_cavo/130_HAILEMARIAM_b_713_15.mat
#   inflating: /content/VolumiDCE_Sub_AllBox_2D/0_cavo/130_HAILEMARIAM_b_751_28.mat
#   inflating: /content/VolumiDCE_Sub_AllBox_2D/0_cavo/130_HAILEMARIAM_b_755_23.mat
#   inflating: /content/VolumiDCE_Sub_AllBox_2D/0_cavo/130_HAILEMARIAM_b_784_25.mat
#   inflating: /content/VolumiDCE_Sub_AllBox_2D/0_cavo/130_HAILEMARIAM_b_842_27.mat
#   inflating: /content/VolumiDCE_Sub_AllBox_2D/0_cavo/130_HAILEMARIAM_b_91_33.mat
#   inflating: /content/VolumiDCE_Sub_AllBox_2D/0_cavo/130_HAILEMARIAM_b_91_34.mat
#   inflating: /content/VolumiDCE_Sub_AllBox_2D/0_cavo/130_HAILEMARIAM_b_966_11.mat
#   inflating: /content/VolumiDCE_Sub_AllBox_2D/0_cavo/130_HAILEMARIAM_b_984_16.mat
#   inflating: /content/VolumiDCE_Sub_AllBox_2D/0_cavo/130_HAILEMARIAM_b_990_22.mat
#   inflating: /content/VolumiDCE_Sub_AllBox_2D/0_cavo/131_Iorio_a_107_15.mat
#   inflating: /content/VolumiDCE_Sub_AllBox_2D/0_cavo/131_Iorio_a_115_12.mat
#   inflating: /content/VolumiDCE_Sub_AllBox_2D/0_cavo/131_Iorio_a_115_13.mat
#   inflating: /content/VolumiDCE_Sub_AllBox_2D/0_cavo/131_Iorio_a_122_18.mat
#   inflating: /content/VolumiDCE_Sub_AllBox_2D/0_cavo/131_Iorio_a_134_17.mat
#   inflating: /content/VolumiDCE_Sub_AllBox_2D/0_cavo/131_Iorio_a_137_7.mat
#   inflating: /content/VolumiDCE_Sub_AllBox_2D/0_cavo/131_Iorio_a_151_3.mat
#   inflating: /content/VolumiDCE_Sub_AllBox_2D/0_cavo/131_Iorio_a_151_4.mat
#   inflating: /content/VolumiDCE_Sub_AllBox_2D/0_cavo/131_Iorio_a_170_5.mat
#   inflating: /content/VolumiDCE_Sub_AllBox_2D/0_cavo/131_Iorio_a_170_6.mat
#   inflating: /content/VolumiDCE_Sub_AllBox_2D/0_cavo/131_Iorio_a_174_11.mat
#   inflating: /content/VolumiDCE_Sub_AllBox_2D/0_cavo/131_Iorio_a_181_10.mat
#   inflating: /content/VolumiDCE_Sub_AllBox_2D/0_cavo/131_Iorio_a_201_14.mat
#   inflating: /content/VolumiDCE_Sub_AllBox_2D/0_cavo/131_Iorio_a_216_8.mat
#   inflating: /content/VolumiDCE_Sub_AllBox_2D/0_cavo/131_Iorio_a_218_16.mat
#   inflating: /content/VolumiDCE_Sub_AllBox_2D/0_cavo/131_Iorio_a_266_9.mat
#   inflating: /content/VolumiDCE_Sub_AllBox_2D/0_cavo/131_Iorio_a_31_20.mat
#   inflating: /content/VolumiDCE_Sub_AllBox_2D/0_cavo/131_Iorio_a_32_1.mat
#   inflating: /content/VolumiDCE_Sub_AllBox_2D/0_cavo/131_Iorio_a_52_19.mat
#   inflating: /content/VolumiDCE_Sub_AllBox_2D/0_cavo/131_Iorio_a_57_2.mat
#   inflating: /content/VolumiDCE_Sub_AllBox_2D/0_cavo/131_Iorio_a_5_21.mat
#   inflating: /content/VolumiDCE_Sub_AllBox_2D/0_cavo/133_LaNoce_b_114_3.mat
#   inflating: /content/VolumiDCE_Sub_AllBox_2D/0_cavo/133_LaNoce_b_123_4.mat
#   inflating: /content/VolumiDCE_Sub_AllBox_2D/0_cavo/133_LaNoce_b_146_5.mat
#   inflating: /content/VolumiDCE_Sub_AllBox_2D/0_cavo/133_LaNoce_b_154_7.mat
#   inflating: /content/VolumiDCE_Sub_AllBox_2D/0_cavo/133_LaNoce_b_156_6.mat
#   inflating: /content/VolumiDCE_Sub_AllBox_2D/0_cavo/133_LaNoce_b_161_9.mat
#   inflating: /content/VolumiDCE_Sub_AllBox_2D/0_cavo/133_LaNoce_b_181_8.mat
#   inflating: /content/VolumiDCE_Sub_AllBox_2D/0_cavo/133_LaNoce_b_28_1.mat
#   inflating: /content/VolumiDCE_Sub_AllBox_2D/0_cavo/133_LaNoce_b_35_11.mat
#   inflating: /content/VolumiDCE_Sub_AllBox_2D/0_cavo/133_LaNoce_b_61_2.mat
#   inflating: /content/VolumiDCE_Sub_AllBox_2D/0_cavo/133_LaNoce_b_80_10.mat
#   inflating: /content/VolumiDCE_Sub_AllBox_2D/0_cavo/135_Langiano_a_1031_14.mat
#   inflating: /content/VolumiDCE_Sub_AllBox_2D/0_cavo/135_Langiano_a_1041_10.mat
#   inflating: /content/VolumiDCE_Sub_AllBox_2D/0_cavo/135_Langiano_a_1054_18.mat
#   inflating: /content/VolumiDCE_Sub_AllBox_2D/0_cavo/135_Langiano_a_1085_13.mat
#   inflating: /content/VolumiDCE_Sub_AllBox_2D/0_cavo/135_Langiano_a_1086_16.mat
#   inflating: /content/VolumiDCE_Sub_AllBox_2D/0_cavo/135_Langiano_a_1089_11.mat
#   inflating: /content/VolumiDCE_Sub_AllBox_2D/0_cavo/135_Langiano_a_1089_15.mat
#   inflating: /content/VolumiDCE_Sub_AllBox_2D/0_cavo/135_Langiano_a_1146_17.mat
#   inflating: /content/VolumiDCE_Sub_AllBox_2D/0_cavo/135_Langiano_a_128_25.mat
#   inflating: /content/VolumiDCE_Sub_AllBox_2D/0_cavo/135_Langiano_a_13_27.mat
#   inflating: /content/VolumiDCE_Sub_AllBox_2D/0_cavo/135_Langiano_a_207_3.mat
#   inflating: /content/VolumiDCE_Sub_AllBox_2D/0_cavo/135_Langiano_a_30_1.mat
#   inflating: /content/VolumiDCE_Sub_AllBox_2D/0_cavo/135_Langiano_a_30_26.mat
#   inflating: /content/VolumiDCE_Sub_AllBox_2D/0_cavo/135_Langiano_a_349_4.mat
#   inflating: /content/VolumiDCE_Sub_AllBox_2D/0_cavo/135_Langiano_a_386_5.mat
#   inflating: /content/VolumiDCE_Sub_AllBox_2D/0_cavo/135_Langiano_a_498_23.mat
#   inflating: /content/VolumiDCE_Sub_AllBox_2D/0_cavo/135_Langiano_a_508_24.mat
#   inflating: /content/VolumiDCE_Sub_AllBox_2D/0_cavo/135_Langiano_a_561_22.mat
#   inflating: /content/VolumiDCE_Sub_AllBox_2D/0_cavo/135_Langiano_a_577_6.mat
#   inflating: /content/VolumiDCE_Sub_AllBox_2D/0_cavo/135_Langiano_a_638_21.mat
#   inflating: /content/VolumiDCE_Sub_AllBox_2D/0_cavo/135_Langiano_a_797_7.mat
#   inflating: /content/VolumiDCE_Sub_AllBox_2D/0_cavo/135_Langiano_a_816_8.mat
#   inflating: /content/VolumiDCE_Sub_AllBox_2D/0_cavo/135_Langiano_a_823_20.mat
#   inflating: /content/VolumiDCE_Sub_AllBox_2D/0_cavo/135_Langiano_a_883_9.mat
#   inflating: /content/VolumiDCE_Sub_AllBox_2D/0_cavo/135_Langiano_a_954_12.mat
#   inflating: /content/VolumiDCE_Sub_AllBox_2D/0_cavo/135_Langiano_a_95_2.mat
#   inflating: /content/VolumiDCE_Sub_AllBox_2D/0_cavo/135_Langiano_a_982_19.mat
#   inflating: /content/VolumiDCE_Sub_AllBox_2D/0_cavo/136_Leoni_b_108_3.mat
#   inflating: /content/VolumiDCE_Sub_AllBox_2D/0_cavo/136_Leoni_b_125_17.mat
#   inflating: /content/VolumiDCE_Sub_AllBox_2D/0_cavo/136_Leoni_b_127_2.mat
#   inflating: /content/VolumiDCE_Sub_AllBox_2D/0_cavo/136_Leoni_b_141_11.mat
#   inflating: /content/VolumiDCE_Sub_AllBox_2D/0_cavo/136_Leoni_b_144_14.mat
#   inflating: /content/VolumiDCE_Sub_AllBox_2D/0_cavo/136_Leoni_b_144_15.mat
#   inflating: /content/VolumiDCE_Sub_AllBox_2D/0_cavo/136_Leoni_b_145_12.mat
#   inflating: /content/VolumiDCE_Sub_AllBox_2D/0_cavo/136_Leoni_b_146_10.mat
#   inflating: /content/VolumiDCE_Sub_AllBox_2D/0_cavo/136_Leoni_b_148_13.mat
#   inflating: /content/VolumiDCE_Sub_AllBox_2D/0_cavo/136_Leoni_b_148_16.mat
#   inflating: /content/VolumiDCE_Sub_AllBox_2D/0_cavo/136_Leoni_b_173_5.mat
#   inflating: /content/VolumiDCE_Sub_AllBox_2D/0_cavo/136_Leoni_b_221_8.mat
#   inflating: /content/VolumiDCE_Sub_AllBox_2D/0_cavo/136_Leoni_b_228_9.mat
#   inflating: /content/VolumiDCE_Sub_AllBox_2D/0_cavo/136_Leoni_b_234_4.mat
#   inflating: /content/VolumiDCE_Sub_AllBox_2D/0_cavo/136_Leoni_b_23_1.mat
#   inflating: /content/VolumiDCE_Sub_AllBox_2D/0_cavo/136_Leoni_b_290_6.mat
#   inflating: /content/VolumiDCE_Sub_AllBox_2D/0_cavo/136_Leoni_b_354_7.mat
#   inflating: /content/VolumiDCE_Sub_AllBox_2D/0_cavo/136_Leoni_b_70_20.mat
#   inflating: /content/VolumiDCE_Sub_AllBox_2D/0_cavo/136_Leoni_b_75_19.mat
#   inflating: /content/VolumiDCE_Sub_AllBox_2D/0_cavo/136_Leoni_b_92_18.mat
#   inflating: /content/VolumiDCE_Sub_AllBox_2D/0_cavo/137_Macaluso_b_107_9.mat
#   inflating: /content/VolumiDCE_Sub_AllBox_2D/0_cavo/137_Macaluso_b_113_4.mat
#   inflating: /content/VolumiDCE_Sub_AllBox_2D/0_cavo/137_Macaluso_b_116_8.mat
#   inflating: /content/VolumiDCE_Sub_AllBox_2D/0_cavo/137_Macaluso_b_125_7.mat
#   inflating: /content/VolumiDCE_Sub_AllBox_2D/0_cavo/137_Macaluso_b_127_5.mat
#   inflating: /content/VolumiDCE_Sub_AllBox_2D/0_cavo/137_Macaluso_b_130_3.mat
#   inflating: /content/VolumiDCE_Sub_AllBox_2D/0_cavo/137_Macaluso_b_160_6.mat
#   inflating: /content/VolumiDCE_Sub_AllBox_2D/0_cavo/137_Macaluso_b_65_1.mat
# ...
#   inflating: /content/VolumiDCE_Sub_AllBox_2D/1_cavo/67_Cauteruccio_a_847_53.mat
#   inflating: /content/VolumiDCE_Sub_AllBox_2D/1_cavo/67_Cauteruccio_a_856_18.mat
#   inflating: /content/VolumiDCE_Sub_AllBox_2D/1_cavo/67_Cauteruccio_a_891_56.mat
#   inflating: /content/VolumiDCE_Sub_AllBox_2D/1_cavo/67_Cauteruccio_a_965_32.mat
#   inflating: /content/VolumiDCE_Sub_AllBox_2D/1_cavo/68_Leonardo_a_100_17.mat
#   inflating: /content/VolumiDCE_Sub_AllBox_2D/1_cavo/68_Leonardo_a_110_1.mat
#   inflating: /content/VolumiDCE_Sub_AllBox_2D/1_cavo/68_Leonardo_a_166_16.mat
#   inflating: /content/VolumiDCE_Sub_AllBox_2D/1_cavo/68_Leonardo_a_172_2.mat
#   inflating: /content/VolumiDCE_Sub_AllBox_2D/1_cavo/68_Leonardo_a_206_3.mat
#   inflating: /content/VolumiDCE_Sub_AllBox_2D/1_cavo/68_Leonardo_a_219_15.mat
#   inflating: /content/VolumiDCE_Sub_AllBox_2D/1_cavo/68_Leonardo_a_24_19.mat
#   inflating: /content/VolumiDCE_Sub_AllBox_2D/1_cavo/68_Leonardo_a_255_14.mat
#   inflating: /content/VolumiDCE_Sub_AllBox_2D/1_cavo/68_Leonardo_a_278_4.mat
#   inflating: /content/VolumiDCE_Sub_AllBox_2D/1_cavo/68_Leonardo_a_306_5.mat
#   inflating: /content/VolumiDCE_Sub_AllBox_2D/1_cavo/68_Leonardo_a_317_13.mat
#   inflating: /content/VolumiDCE_Sub_AllBox_2D/1_cavo/68_Leonardo_a_355_6.mat
#   inflating: /content/VolumiDCE_Sub_AllBox_2D/1_cavo/68_Leonardo_a_373_12.mat
#   inflating: /content/VolumiDCE_Sub_AllBox_2D/1_cavo/68_Leonardo_a_374_8.mat
#   inflating: /content/VolumiDCE_Sub_AllBox_2D/1_cavo/68_Leonardo_a_380_7.mat
#   inflating: /content/VolumiDCE_Sub_AllBox_2D/1_cavo/68_Leonardo_a_382_11.mat
#   inflating: /content/VolumiDCE_Sub_AllBox_2D/1_cavo/68_Leonardo_a_395_10.mat
#   inflating: /content/VolumiDCE_Sub_AllBox_2D/1_cavo/68_Leonardo_a_401_9.mat
#   inflating: /content/VolumiDCE_Sub_AllBox_2D/1_cavo/68_Leonardo_a_65_18.mat
#   inflating: /content/VolumiDCE_Sub_AllBox_2D/1_cavo/71_Marinaro_b_101_1.mat
#   inflating: /content/VolumiDCE_Sub_AllBox_2D/1_cavo/71_Marinaro_b_126_2.mat
#   inflating: /content/VolumiDCE_Sub_AllBox_2D/1_cavo/71_Marinaro_b_177_14.mat
#   inflating: /content/VolumiDCE_Sub_AllBox_2D/1_cavo/71_Marinaro_b_197_13.mat
#   inflating: /content/VolumiDCE_Sub_AllBox_2D/1_cavo/71_Marinaro_b_216_11.mat
#   inflating: /content/VolumiDCE_Sub_AllBox_2D/1_cavo/71_Marinaro_b_230_12.mat
#   inflating: /content/VolumiDCE_Sub_AllBox_2D/1_cavo/71_Marinaro_b_254_9.mat
#   inflating: /content/VolumiDCE_Sub_AllBox_2D/1_cavo/71_Marinaro_b_275_10.mat
#   inflating: /content/VolumiDCE_Sub_AllBox_2D/1_cavo/71_Marinaro_b_280_8.mat
#   inflating: /content/VolumiDCE_Sub_AllBox_2D/1_cavo/71_Marinaro_b_327_7.mat
#   inflating: /content/VolumiDCE_Sub_AllBox_2D/1_cavo/71_Marinaro_b_336_6.mat
#   inflating: /content/VolumiDCE_Sub_AllBox_2D/1_cavo/71_Marinaro_b_352_3.mat
#   inflating: /content/VolumiDCE_Sub_AllBox_2D/1_cavo/71_Marinaro_b_378_5.mat
#   inflating: /content/VolumiDCE_Sub_AllBox_2D/1_cavo/71_Marinaro_b_388_4.mat
#   inflating: /content/VolumiDCE_Sub_AllBox_2D/1_cavo/71_Marinaro_b_58_15.mat
#   inflating: /content/VolumiDCE_Sub_AllBox_2D/1_cavo/75_Lilli_a_132_4.mat
#   inflating: /content/VolumiDCE_Sub_AllBox_2D/1_cavo/75_Lilli_a_141_13.mat
#   inflating: /content/VolumiDCE_Sub_AllBox_2D/1_cavo/75_Lilli_a_173_5.mat
#   inflating: /content/VolumiDCE_Sub_AllBox_2D/1_cavo/75_Lilli_a_21_1.mat
#   inflating: /content/VolumiDCE_Sub_AllBox_2D/1_cavo/75_Lilli_a_245_12.mat
#   inflating: /content/VolumiDCE_Sub_AllBox_2D/1_cavo/75_Lilli_a_271_11.mat
#   inflating: /content/VolumiDCE_Sub_AllBox_2D/1_cavo/75_Lilli_a_318_6.mat
#   inflating: /content/VolumiDCE_Sub_AllBox_2D/1_cavo/75_Lilli_a_366_9.mat
#   inflating: /content/VolumiDCE_Sub_AllBox_2D/1_cavo/75_Lilli_a_371_10.mat
#   inflating: /content/VolumiDCE_Sub_AllBox_2D/1_cavo/75_Lilli_a_376_8.mat
#   inflating: /content/VolumiDCE_Sub_AllBox_2D/1_cavo/75_Lilli_a_408_7.mat
#   inflating: /content/VolumiDCE_Sub_AllBox_2D/1_cavo/75_Lilli_a_45_2.mat
#   inflating: /content/VolumiDCE_Sub_AllBox_2D/1_cavo/75_Lilli_a_60_14.mat
#   inflating: /content/VolumiDCE_Sub_AllBox_2D/1_cavo/75_Lilli_a_98_3.mat
#   inflating: /content/VolumiDCE_Sub_AllBox_2D/1_cavo/76_Bruni_b_108_36.mat
#   inflating: /content/VolumiDCE_Sub_AllBox_2D/1_cavo/76_Bruni_b_1142_34.mat
#   inflating: /content/VolumiDCE_Sub_AllBox_2D/1_cavo/76_Bruni_b_1176_7.mat
#   inflating: /content/VolumiDCE_Sub_AllBox_2D/1_cavo/76_Bruni_b_1359_33.mat
#   inflating: /content/VolumiDCE_Sub_AllBox_2D/1_cavo/76_Bruni_b_1469_9.mat
#   inflating: /content/VolumiDCE_Sub_AllBox_2D/1_cavo/76_Bruni_b_1474_32.mat
#   inflating: /content/VolumiDCE_Sub_AllBox_2D/1_cavo/76_Bruni_b_1486_8.mat
#   inflating: /content/VolumiDCE_Sub_AllBox_2D/1_cavo/76_Bruni_b_1534_10.mat
#   inflating: /content/VolumiDCE_Sub_AllBox_2D/1_cavo/76_Bruni_b_1561_11.mat
#   inflating: /content/VolumiDCE_Sub_AllBox_2D/1_cavo/76_Bruni_b_1660_31.mat
#   inflating: /content/VolumiDCE_Sub_AllBox_2D/1_cavo/76_Bruni_b_1745_12.mat
#   inflating: /content/VolumiDCE_Sub_AllBox_2D/1_cavo/76_Bruni_b_1803_13.mat
#   inflating: /content/VolumiDCE_Sub_AllBox_2D/1_cavo/76_Bruni_b_1883_14.mat
#   inflating: /content/VolumiDCE_Sub_AllBox_2D/1_cavo/76_Bruni_b_2116_15.mat
#   inflating: /content/VolumiDCE_Sub_AllBox_2D/1_cavo/76_Bruni_b_2202_16.mat
#   inflating: /content/VolumiDCE_Sub_AllBox_2D/1_cavo/76_Bruni_b_2270_30.mat
#   inflating: /content/VolumiDCE_Sub_AllBox_2D/1_cavo/76_Bruni_b_2346_26.mat
#   inflating: /content/VolumiDCE_Sub_AllBox_2D/1_cavo/76_Bruni_b_2396_29.mat
#   inflating: /content/VolumiDCE_Sub_AllBox_2D/1_cavo/76_Bruni_b_23_1.mat
#   inflating: /content/VolumiDCE_Sub_AllBox_2D/1_cavo/76_Bruni_b_2589_28.mat
#   inflating: /content/VolumiDCE_Sub_AllBox_2D/1_cavo/76_Bruni_b_2603_27.mat
#   inflating: /content/VolumiDCE_Sub_AllBox_2D/1_cavo/76_Bruni_b_2623_19.mat
#   inflating: /content/VolumiDCE_Sub_AllBox_2D/1_cavo/76_Bruni_b_2632_18.mat
#   inflating: /content/VolumiDCE_Sub_AllBox_2D/1_cavo/76_Bruni_b_2708_25.mat
#   inflating: /content/VolumiDCE_Sub_AllBox_2D/1_cavo/76_Bruni_b_2714_17.mat
#   inflating: /content/VolumiDCE_Sub_AllBox_2D/1_cavo/76_Bruni_b_2798_20.mat
#   inflating: /content/VolumiDCE_Sub_AllBox_2D/1_cavo/76_Bruni_b_2969_21.mat
#   inflating: /content/VolumiDCE_Sub_AllBox_2D/1_cavo/76_Bruni_b_3090_24.mat
#   inflating: /content/VolumiDCE_Sub_AllBox_2D/1_cavo/76_Bruni_b_3223_23.mat
#   inflating: /content/VolumiDCE_Sub_AllBox_2D/1_cavo/76_Bruni_b_3268_22.mat
#   inflating: /content/VolumiDCE_Sub_AllBox_2D/1_cavo/76_Bruni_b_594_3.mat
#   inflating: /content/VolumiDCE_Sub_AllBox_2D/1_cavo/76_Bruni_b_659_4.mat
#   inflating: /content/VolumiDCE_Sub_AllBox_2D/1_cavo/76_Bruni_b_68_2.mat
#   inflating: /content/VolumiDCE_Sub_AllBox_2D/1_cavo/76_Bruni_b_690_35.mat
#   inflating: /content/VolumiDCE_Sub_AllBox_2D/1_cavo/76_Bruni_b_77_37.mat
#   inflating: /content/VolumiDCE_Sub_AllBox_2D/1_cavo/76_Bruni_b_785_5.mat
#   inflating: /content/VolumiDCE_Sub_AllBox_2D/1_cavo/76_Bruni_b_841_6.mat
#   inflating: /content/VolumiDCE_Sub_AllBox_2D/1_cavo/78_SantoniFR_b_128_15.mat
#   inflating: /content/VolumiDCE_Sub_AllBox_2D/1_cavo/78_SantoniFR_b_149_14.mat
#   inflating: /content/VolumiDCE_Sub_AllBox_2D/1_cavo/78_SantoniFR_b_14_17.mat
#   inflating: /content/VolumiDCE_Sub_AllBox_2D/1_cavo/78_SantoniFR_b_152_13.mat
#   inflating: /content/VolumiDCE_Sub_AllBox_2D/1_cavo/78_SantoniFR_b_174_4.mat
#   inflating: /content/VolumiDCE_Sub_AllBox_2D/1_cavo/78_SantoniFR_b_201_12.mat
#   inflating: /content/VolumiDCE_Sub_AllBox_2D/1_cavo/78_SantoniFR_b_214_5.mat
#   inflating: /content/VolumiDCE_Sub_AllBox_2D/1_cavo/78_SantoniFR_b_26_1.mat
#   inflating: /content/VolumiDCE_Sub_AllBox_2D/1_cavo/78_SantoniFR_b_289_11.mat
#   inflating: /content/VolumiDCE_Sub_AllBox_2D/1_cavo/78_SantoniFR_b_295_6.mat
#   inflating: /content/VolumiDCE_Sub_AllBox_2D/1_cavo/78_SantoniFR_b_305_7.mat
#   inflating: /content/VolumiDCE_Sub_AllBox_2D/1_cavo/78_SantoniFR_b_328_8.mat
#   inflating: /content/VolumiDCE_Sub_AllBox_2D/1_cavo/78_SantoniFR_b_341_10.mat
#   inflating: /content/VolumiDCE_Sub_AllBox_2D/1_cavo/78_SantoniFR_b_344_9.mat
#   inflating: /content/VolumiDCE_Sub_AllBox_2D/1_cavo/78_SantoniFR_b_50_2.mat
#   inflating: /content/VolumiDCE_Sub_AllBox_2D/1_cavo/78_SantoniFR_b_80_16.mat
#   inflating: /content/VolumiDCE_Sub_AllBox_2D/1_cavo/78_SantoniFR_b_96_3.mat
#   inflating: /content/VolumiDCE_Sub_AllBox_2D/1_cavo/84_Nardi_b_111_7.mat
#   inflating: /content/VolumiDCE_Sub_AllBox_2D/1_cavo/84_Nardi_b_114_2.mat
#   inflating: /content/VolumiDCE_Sub_AllBox_2D/1_cavo/84_Nardi_b_142_3.mat
#   inflating: /content/VolumiDCE_Sub_AllBox_2D/1_cavo/84_Nardi_b_192_4.mat
#   inflating: /content/VolumiDCE_Sub_AllBox_2D/1_cavo/84_Nardi_b_260_6.mat
#   inflating: /content/VolumiDCE_Sub_AllBox_2D/1_cavo/84_Nardi_b_261_5.mat
#   inflating: /content/VolumiDCE_Sub_AllBox_2D/1_cavo/84_Nardi_b_30_9.mat
#   inflating: /content/VolumiDCE_Sub_AllBox_2D/1_cavo/84_Nardi_b_45_1.mat
#   inflating: /content/VolumiDCE_Sub_AllBox_2D/1_cavo/84_Nardi_b_62_8.mat
#   inflating: /content/VolumiDCE_Sub_AllBox_2D/1_cavo/85_Solimini_a_102_26.mat
#   inflating: /content/VolumiDCE_Sub_AllBox_2D/1_cavo/85_Solimini_a_118_1.mat
#   inflating: /content/VolumiDCE_Sub_AllBox_2D/1_cavo/85_Solimini_a_12_23.mat
#   inflating: /content/VolumiDCE_Sub_AllBox_2D/1_cavo/85_Solimini_a_139_49.mat
#   inflating: /content/VolumiDCE_Sub_AllBox_2D/1_cavo/85_Solimini_a_147_27.mat
#   inflating: /content/VolumiDCE_Sub_AllBox_2D/1_cavo/85_Solimini_a_162_48.mat
#   inflating: /content/VolumiDCE_Sub_AllBox_2D/1_cavo/85_Solimini_a_184_29.mat
#   inflating: /content/VolumiDCE_Sub_AllBox_2D/1_cavo/85_Solimini_a_185_28.mat
#   inflating: /content/VolumiDCE_Sub_AllBox_2D/1_cavo/85_Solimini_a_18_24.mat
#   inflating: /content/VolumiDCE_Sub_AllBox_2D/1_cavo/85_Solimini_a_200_2.mat
#   inflating: /content/VolumiDCE_Sub_AllBox_2D/1_cavo/85_Solimini_a_223_30.mat
#   inflating: /content/VolumiDCE_Sub_AllBox_2D/1_cavo/85_Solimini_a_22_22.mat
#   inflating: /content/VolumiDCE_Sub_AllBox_2D/1_cavo/85_Solimini_a_235_36.mat
#   inflating: /content/VolumiDCE_Sub_AllBox_2D/1_cavo/85_Solimini_a_236_19.mat
#   inflating: /content/VolumiDCE_Sub_AllBox_2D/1_cavo/85_Solimini_a_241_18.mat
#   inflating: /content/VolumiDCE_Sub_AllBox_2D/1_cavo/85_Solimini_a_247_37.mat
#   inflating: /content/VolumiDCE_Sub_AllBox_2D/1_cavo/85_Solimini_a_255_31.mat
#   inflating: /content/VolumiDCE_Sub_AllBox_2D/1_cavo/85_Solimini_a_277_33.mat
#   inflating: /content/VolumiDCE_Sub_AllBox_2D/1_cavo/85_Solimini_a_278_35.mat
#   inflating: /content/VolumiDCE_Sub_AllBox_2D/1_cavo/85_Solimini_a_286_32.mat
#   inflating: /content/VolumiDCE_Sub_AllBox_2D/1_cavo/85_Solimini_a_294_47.mat
#   inflating: /content/VolumiDCE_Sub_AllBox_2D/1_cavo/85_Solimini_a_29_51.mat
#   inflating: /content/VolumiDCE_Sub_AllBox_2D/1_cavo/85_Solimini_a_301_34.mat
#   inflating: /content/VolumiDCE_Sub_AllBox_2D/1_cavo/85_Solimini_a_305_3.mat
#   inflating: /content/VolumiDCE_Sub_AllBox_2D/1_cavo/85_Solimini_a_317_16.mat
#   inflating: /content/VolumiDCE_Sub_AllBox_2D/1_cavo/85_Solimini_a_331_38.mat
#   inflating: /content/VolumiDCE_Sub_AllBox_2D/1_cavo/85_Solimini_a_336_17.mat
#   inflating: /content/VolumiDCE_Sub_AllBox_2D/1_cavo/85_Solimini_a_383_46.mat
#   inflating: /content/VolumiDCE_Sub_AllBox_2D/1_cavo/85_Solimini_a_38_21.mat
#   inflating: /content/VolumiDCE_Sub_AllBox_2D/1_cavo/85_Solimini_a_401_15.mat
#   inflating: /content/VolumiDCE_Sub_AllBox_2D/1_cavo/85_Solimini_a_406_39.mat
#   inflating: /content/VolumiDCE_Sub_AllBox_2D/1_cavo/85_Solimini_a_443_45.mat
#   inflating: /content/VolumiDCE_Sub_AllBox_2D/1_cavo/85_Solimini_a_470_13.mat
#   inflating: /content/VolumiDCE_Sub_AllBox_2D/1_cavo/85_Solimini_a_474_14.mat
#   inflating: /content/VolumiDCE_Sub_AllBox_2D/1_cavo/85_Solimini_a_481_4.mat
#   inflating: /content/VolumiDCE_Sub_AllBox_2D/1_cavo/85_Solimini_a_487_44.mat
#   inflating: /content/VolumiDCE_Sub_AllBox_2D/1_cavo/85_Solimini_a_514_43.mat
#   inflating: /content/VolumiDCE_Sub_AllBox_2D/1_cavo/85_Solimini_a_519_40.mat
#   inflating: /content/VolumiDCE_Sub_AllBox_2D/1_cavo/85_Solimini_a_521_42.mat
#   inflating: /content/VolumiDCE_Sub_AllBox_2D/1_cavo/85_Solimini_a_527_12.mat
#   inflating: /content/VolumiDCE_Sub_AllBox_2D/1_cavo/85_Solimini_a_530_41.mat
#   inflating: /content/VolumiDCE_Sub_AllBox_2D/1_cavo/85_Solimini_a_531_7.mat
#   inflating: /content/VolumiDCE_Sub_AllBox_2D/1_cavo/85_Solimini_a_545_6.mat
#   inflating: /content/VolumiDCE_Sub_AllBox_2D/1_cavo/85_Solimini_a_554_5.mat
#   inflating: /content/VolumiDCE_Sub_AllBox_2D/1_cavo/85_Solimini_a_558_8.mat
#   inflating: /content/VolumiDCE_Sub_AllBox_2D/1_cavo/85_Solimini_a_665_11.mat
#   inflating: /content/VolumiDCE_Sub_AllBox_2D/1_cavo/85_Solimini_a_729_10.mat
#   inflating: /content/VolumiDCE_Sub_AllBox_2D/1_cavo/85_Solimini_a_743_9.mat
#   inflating: /content/VolumiDCE_Sub_AllBox_2D/1_cavo/85_Solimini_a_82_50.mat
#   inflating: /content/VolumiDCE_Sub_AllBox_2D/1_cavo/85_Solimini_a_85_25.mat
#   inflating: /content/VolumiDCE_Sub_AllBox_2D/1_cavo/85_Solimini_a_87_20.mat
#   inflating: /content/VolumiDCE_Sub_AllBox_2D/1_cavo/90_Aloisi_a_109_11.mat
#   inflating: /content/VolumiDCE_Sub_AllBox_2D/1_cavo/90_Aloisi_a_120_12.mat
#   inflating: /content/VolumiDCE_Sub_AllBox_2D/1_cavo/90_Aloisi_a_13_1.mat
#   inflating: /content/VolumiDCE_Sub_AllBox_2D/1_cavo/90_Aloisi_a_13_7.mat
#   inflating: /content/VolumiDCE_Sub_AllBox_2D/1_cavo/90_Aloisi_a_14_5.mat
#   inflating: /content/VolumiDCE_Sub_AllBox_2D/1_cavo/90_Aloisi_a_14_6.mat
#   inflating: /content/VolumiDCE_Sub_AllBox_2D/1_cavo/90_Aloisi_a_15_2.mat
#   inflating: /content/VolumiDCE_Sub_AllBox_2D/1_cavo/90_Aloisi_a_15_20.mat
#   inflating: /content/VolumiDCE_Sub_AllBox_2D/1_cavo/90_Aloisi_a_15_28.mat
#   inflating: /content/VolumiDCE_Sub_AllBox_2D/1_cavo/90_Aloisi_a_17_19.mat
#   inflating: /content/VolumiDCE_Sub_AllBox_2D/1_cavo/90_Aloisi_a_17_3.mat
#   inflating: /content/VolumiDCE_Sub_AllBox_2D/1_cavo/90_Aloisi_a_18_21.mat
#   inflating: /content/VolumiDCE_Sub_AllBox_2D/1_cavo/90_Aloisi_a_25_17.mat
#   inflating: /content/VolumiDCE_Sub_AllBox_2D/1_cavo/90_Aloisi_a_34_8.mat
#   inflating: /content/VolumiDCE_Sub_AllBox_2D/1_cavo/90_Aloisi_a_35_22.mat
#   inflating: /content/VolumiDCE_Sub_AllBox_2D/1_cavo/90_Aloisi_a_36_16.mat
#   inflating: /content/VolumiDCE_Sub_AllBox_2D/1_cavo/90_Aloisi_a_37_18.mat
#   inflating: /content/VolumiDCE_Sub_AllBox_2D/1_cavo/90_Aloisi_a_3_29.mat
#   inflating: /content/VolumiDCE_Sub_AllBox_2D/1_cavo/90_Aloisi_a_3_4.mat
#   inflating: /content/VolumiDCE_Sub_AllBox_2D/1_cavo/90_Aloisi_a_41_27.mat
#   inflating: /content/VolumiDCE_Sub_AllBox_2D/1_cavo/90_Aloisi_a_51_24.mat
#   inflating: /content/VolumiDCE_Sub_AllBox_2D/1_cavo/90_Aloisi_a_51_25.mat
#   inflating: /content/VolumiDCE_Sub_AllBox_2D/1_cavo/90_Aloisi_a_52_23.mat
#   inflating: /content/VolumiDCE_Sub_AllBox_2D/1_cavo/90_Aloisi_a_53_26.mat
#   inflating: /content/VolumiDCE_Sub_AllBox_2D/1_cavo/90_Aloisi_a_54_15.mat
#   inflating: /content/VolumiDCE_Sub_AllBox_2D/1_cavo/90_Aloisi_a_67_9.mat
#   inflating: /content/VolumiDCE_Sub_AllBox_2D/1_cavo/90_Aloisi_a_87_14.mat
#   inflating: /content/VolumiDCE_Sub_AllBox_2D/1_cavo/90_Aloisi_a_89_10.mat
#   inflating: /content/VolumiDCE_Sub_AllBox_2D/1_cavo/90_Aloisi_a_95_13.mat
#   inflating: /content/VolumiDCE_Sub_AllBox_2D/1_cavo/91_Altamura_b_101_5.mat
#   inflating: /content/VolumiDCE_Sub_AllBox_2D/1_cavo/91_Altamura_b_101_6.mat
#   inflating: /content/VolumiDCE_Sub_AllBox_2D/1_cavo/91_Altamura_b_101_9.mat
#   inflating: /content/VolumiDCE_Sub_AllBox_2D/1_cavo/91_Altamura_b_111_4.mat
#   inflating: /content/VolumiDCE_Sub_AllBox_2D/1_cavo/91_Altamura_b_126_7.mat
#   inflating: /content/VolumiDCE_Sub_AllBox_2D/1_cavo/91_Altamura_b_130_2.mat
#   inflating: /content/VolumiDCE_Sub_AllBox_2D/1_cavo/91_Altamura_b_131_3.mat
#   inflating: /content/VolumiDCE_Sub_AllBox_2D/1_cavo/91_Altamura_b_138_8.mat
#   inflating: /content/VolumiDCE_Sub_AllBox_2D/1_cavo/91_Altamura_b_28_1.mat

# %% [markdown]
# #Utility Function

# %%
#-------------------------------------------------------------------------------> Normalizzazione durante la lettura
def normalizeZscore(x, ax): #->ok
  #z score intra paziente
  #da usare quando non considero la maschera
  xz = zscore(x, axis=ax)
  return xz

def multiply_mask(y, m): #->ok
  y_new = y*np.repeat(m[:,:,np.newaxis], 4, axis =2)
  return y_new

def rangeNormalization(x, supLim, infLim): #->ok
  #normalizzazione nel range
  x_norm = ( (x - np.min(x)) / (np.max(x)- np.min(x)) )*(supLim - infLim) + infLim
  assert np.min(x_norm) >= infLim
  assert np.max(x_norm) <= supLim
  return x_norm

def np_imadjust(x, q1,q2): #->ok
  #applico un ehancement
  assert q1<q2
  assert q1+q2 == 1
  qq = np.quantile(x, [q1, q2])
  new = np.clip(x, qq[0], qq[1])
  return new


def getFilesForSubset(basepath, list_classes, include_patient):
  ListFiles=[]
  for c in list_classes:
    listofFiles = os.listdir(basepath + '/' + c)
    for file in listofFiles:
      if include_patient(basepath + '/' + c + '/' + file):
        ListFiles.append((basepath + '/' + c + '/' + file, list_classes.index(c)))
  return ListFiles

def getListOffiles(basepath, list_classes, classe, include_patient):
  ListFiles=[]
  listofFiles = os.listdir(basepath + '/' + classe)
  for file in listofFiles:
    if include_patient(basepath + '/' + classe + '/' + file):
      ListFiles.append((basepath + '/' + classe + '/' + file, list_classes.index(classe)))
  return ListFiles, len(ListFiles)


class FocalLoss(nn.modules.loss._WeightedLoss):
  def __init__(self, weight=None, gamma=2,reduction='mean'):
    super(FocalLoss, self).__init__(weight,reduction=reduction)
    self.gamma = gamma
    self.weight = weight
    self.reduction = reduction

  def forward(self, input, target):
    ce_loss = F.cross_entropy(input, target,reduction='none',weight=self.weight)
    pt = torch.exp(-ce_loss)
    focal_loss = ((1 - pt) ** self.gamma * ce_loss)
    if self.reduction == 'mean':
      focal_loss = focal_loss.mean()
    else:
      focal_loss = focal_loss.sum()
    return focal_loss

#-------------------------------------------------------------------------------> Data Augmentation
class Random_Rotation(torch.nn.Module):
  def __init__(self, p=0.5, n=1):
    self.p = p                      
    self.n = n                                  
    super().__init__()         

  def forward(self, img):
    if random() < self.p:
      img = torch.rot90(img,self.n,dims=[1,2])
    return img
    
  def __repr__(self):
    return self.__class__.__name__ + '(p={}, n={})'.format(self.p, self.n)
        
  
#------------------------------ Bilanciamento
class BalanceConcatDataset(ConcatDataset):  
    def __init__(self, datasets):
        # bilancia il numero di campioni nei vari dataset per replicazione
        l = max([len(dataset) for dataset in datasets])
        for dataset in datasets:
            while len(dataset) < l:
                dataset.samples += sample(dataset.samples, min(len(dataset), l - len(dataset)))
        super(BalanceConcatDataset, self).__init__(datasets)
              
#-------------------------------------> Media e STD  -> numpy
def np_computeMeanAndStd_all(train_files):  #-> generale
  channel_sum, channel_sqared_sum = 0.0,0.0
  num_batches = 0
  
  for f,l in train_files:
    data = readVolume(f)
    ss = np.array(data.shape)
    channel_sum += np.sum(data)
    channel_sqared_sum  += np.sum(data**2)
    num_batches += ss.prod()  #devo fare il prodotto delle dimensioni
  
  #print(num_batches)
  mean =channel_sum/num_batches
  std = (channel_sqared_sum/num_batches - mean**2)**0.5
  return mean, std


def np_computeMeanAndStd_channnel(train_files):
  channel_sum, channel_sqared_sum = 0.0,0.0
  num_batches = 0
  
  for f,l in train_files:
    data = readVolume(f)
    ss = np.array(data.shape)
    channel_sum += np.sum(data, axis=tuple(range(0,ss.shape[0]-1)))
    channel_sqared_sum  += np.sum(data**2, axis=tuple(range(0,ss.shape[0]-1)))
    num_batches += ss[:ss.shape[0]-1].prod()
  
  mean =channel_sum/num_batches
  std = (channel_sqared_sum/num_batches - mean**2)**0.5
  return mean, std
 
#-------------------------------------> Media e STD  -> torch
def torch_computeMeanAndStd_all(train_files): #-> generale
  channel_sum, channel_sqared_sum = 0.0,0.0
  num_batches = 0
  
  for f,l in train_files:
    data = readVolume(f)
    data = torch.from_numpy(data)
    ss = torch.tensor(data.shape)
    channel_sum += torch.sum(data)
    channel_sqared_sum  += torch.sum(data**2)
    num_batches += ss.prod()
  
  #print(num_batches)
  mean =channel_sum/num_batches
  std = (channel_sqared_sum/num_batches - mean**2)**0.5
  return mean, std
 
def torch_computeMeanAndStd_channnel(train_files):
  channel_sum, channel_sqared_sum = 0.0,0.0
  num_batches = 0
  
  for f,l in train_files:
    data = readVolume(f)
    data = torch.from_numpy(data)
    ss = torch.tensor(data.shape)
    channel_sum += torch.sum(data, dim=list(range(0, len(ss)-1)) )
    channel_sqared_sum  += torch.sum(data**2,  dim=list(range(0, len(ss)-1)))
    num_batches += ss[0:len(ss)-1].prod()
  
  #print(num_batches)
  mean =channel_sum/num_batches
  std = (channel_sqared_sum/num_batches - mean**2)**0.5
  return mean, std
    
##-------------------------------------------------------------------------------> Training functions
def train_loop_validation(model_conv, 
                          trainset, Val, test, 
                          start, num_epoch, 
                          loader_opts, 
                          criterionCNN, optimizer_conv, 
                          best_acc, best_loss, best_epoca,
                          outputPath):
  
  for epochs in range(start, num_epoch + 1):
    
    TrainLoader = DataLoader(trainset, shuffle=True, **loader_opts)
    
    modelLoss_train = 0.0
    modelAcc_train = 0.0
    totalSize = 0

    model_conv.train() 
    totPred = torch.empty(0)
    totLabels = torch.empty(0)

    #-----------------------------------------------------------------------------> TRAIN      
    for inputs, labels in TrainLoader:
      inputs = inputs.type(torch.FloatTensor).cuda()
      labels = labels.cuda()

      optimizer_conv.zero_grad()
      model_conv.zero_grad()
       
      y = model_conv(inputs)
      outp, preds = torch.max(y, 1)   
      lossCNN = criterionCNN(y, labels) #media per batch
       
      lossCNN.backward()
      optimizer_conv.step()
       
      totPred = torch.cat((totPred, preds.cpu()))
      totLabels = torch.cat((totLabels, labels.cpu()))
       
      modelLoss_train += lossCNN.item() * inputs.size(0)
      totalSize += inputs.size(0)
      modelAcc_train += torch.sum(preds == labels.data).item()
      
    
    modelLoss_epoch_train = modelLoss_train/totalSize
    modelAcc_epoch_train  = modelAcc_train/totalSize
    
    totPred = totPred.numpy()
    totLabels = totLabels.numpy()
    acc = np.sum((totPred == totLabels).astype(int))/totalSize
    
    x = totLabels[np.where(totLabels == 1)]
    y = totPred[np.where(totLabels == 1)]
    acc_1_T = np.sum((x == y).astype(int))/x.shape[0]
    
    x = totLabels[np.where(totLabels == 0)]
    y = totPred[np.where(totLabels == 0)]
    acc_0_T = np.sum((x == y).astype(int))/y.shape[0]
    
    with open(outputPath + 'lossTrain.txt', "a") as file_object:
      file_object.write(str(modelLoss_epoch_train) +'\n')
    with open(outputPath + 'AccTrain.txt', "a") as file_object:
      file_object.write(str(modelAcc_epoch_train)+'\n')
      
    torch.save(model_conv.state_dict(), outputPath + 'train_weights.pth')
      
    #-----------------------------------------------------------------------------> VALIDATION    

    model_conv.eval()

    totalSize_val = 0
    modelLoss_val = 0.0
    modelAcc_val = 0.0

    totPred_val = torch.empty(0)
    totLabels_val = torch.empty(0)
                    
    ValLoader = DataLoader(Val, shuffle=True, **loader_opts)
    for inputs, labels in ValLoader:
      inputs = inputs.type(torch.FloatTensor).cuda()
      labels = labels.cuda()

      y = model_conv(inputs)
      outp, preds = torch.max(y, 1)
      lossCNN = criterionCNN(y, labels)

      totPred_val = torch.cat((totPred_val, preds.cpu()))
      totLabels_val = torch.cat((totLabels_val, labels.cpu()))

      modelLoss_val += lossCNN.item() * inputs.size(0)  #Non pesata -> semplice media
      totalSize_val += inputs.size(0)
      modelAcc_val += torch.sum(preds == labels.data).item()
    
        
    modelLoss_epoch_val = modelLoss_val/totalSize_val
    modelAcc_epoch_val = modelAcc_val/totalSize_val

    totPred_val = totPred_val.numpy()
    totLabels_val = totLabels_val.numpy()
    acc_val = np.sum((totPred_val == totLabels_val).astype(int))/totalSize_val
    
    x = totLabels_val[np.where(totLabels_val == 1)]
    y = totPred_val[np.where(totLabels_val == 1)]
    acc_1_V = np.sum((x == y).astype(int))/x.shape[0]
    
    x = totLabels_val[np.where(totLabels_val == 0)]
    y = totPred_val[np.where(totLabels_val == 0)]
    acc_0_v = np.sum((x == y).astype(int))/y.shape[0]
    
      
    with open(outputPath + 'lossVal.txt', "a") as file_object:
      file_object.write(str(modelLoss_epoch_val) +'\n')
    
    with open(outputPath + 'AccVal.txt', "a") as file_object:
      file_object.write(str(modelAcc_epoch_val)+'\n')
    
    with open(outputPath + 'AccVal_0.txt', "a") as file_object:
      file_object.write(str(acc_0_v)+'\n')
      
    with open(outputPath + 'AccVal_1.txt', "a") as file_object:
      file_object.write(str(acc_1_V)+'\n')

    print('[Epoch %d][TRAIN on %d [Loss: %.4f - ACC_T: %.4f - ACC_0: %.4f - ACC_1: %.4f ]][VAL on %d [Loss: %.4f - ACC_T: %.4f - ACC_0: %.4f - ACC_1: %.4f]]' 
          %(epochs, totalSize, modelLoss_epoch_train, modelAcc_epoch_train, acc_0_T, acc_1_T,
            totalSize_val, modelLoss_epoch_val, 
            modelAcc_epoch_val, acc_0_v, acc_1_V))
    
    if epochs == 1 or (modelLoss_epoch_val <= best_loss) :
      
      print('     .... Saving best weights ....')
      best_acc = modelAcc_epoch_val
      best_loss = modelLoss_epoch_val
      best_epoca = epochs
      
      #salvataggio dei migliori pesi sul validation
      torch.save(model_conv.state_dict(), outputPath + 'best_model_weights.pth')

      #vedi il test come va
      tot_size_test = 0
      model_loss_test = 0.0
      modelAcc_acc_test = 0.0
      totPred_test = torch.empty(0)
      totLabels_test = torch.empty(0)  

      TestLoader = DataLoader(test, shuffle=True, **loader_opts)
      
      for  inputs, labels in TestLoader:
        inputs = inputs.type(torch.FloatTensor).cuda()
        labels = labels.cuda()
        
        y = model_conv(inputs)
        outp, preds = torch.max(y, 1)
        lossCNN = criterionCNN(y, labels)

        totPred_test = torch.cat((totPred_test, preds.cpu()))
        totLabels_test = torch.cat((totLabels_test, labels.cpu()))

        model_loss_test += lossCNN.item() * inputs.size(0)  #Non pesata -> semplice media
        tot_size_test += inputs.size(0)
        modelAcc_acc_test += torch.sum(preds == labels.data).item()
        
      modelLoss_epoch_test = model_loss_test/tot_size_test
      modelAcc_epoch_test = modelAcc_acc_test/tot_size_test
      
      totPred_test = totPred_test.numpy()
      totLabels_test = totLabels_test.numpy()
      acc_val = np.sum((totPred_test == totLabels_test).astype(int))/tot_size_test
      
      x = totLabels_test[np.where(totLabels_test == 1)]
      y = totPred_test[np.where(totLabels_test == 1)]
      acc_1_test = np.sum((x == y).astype(int))/x.shape[0]
      
      x = totLabels_test[np.where(totLabels_test == 0)]
      y = totPred_test[np.where(totLabels_test == 0)]
      acc_0_test = np.sum((x == y).astype(int))/y.shape[0]     
      

      print('      [TEST on %d [Loss: %.4f - ACC_T: %.4f - ACC_0: %.4f - ACC_1: %.4f ]]' 
            %(tot_size_test, modelLoss_epoch_test, modelAcc_epoch_test, acc_0_test, acc_1_test))

    
    sio.savemat(outputPath + 'check_point.mat', {'best_acc': best_acc, 
                                                 'best_loss': best_loss,
                                                 'best_epoca': best_epoca,
                                                 'last_epoch': epochs})   
  return model_conv

## #-------------------------------------------------------------------------------> Predict function
def prediction_on_Test(model_conv, test, transform):
  func = nn.Softmax(dim=1)
  predicted = pd.DataFrame()
  testFiles = test.samples

  for path, label_true in testFiles:
    inputs = readVolume(path)

    if transform is not None:
      inputs = transform(inputs)

    inputs = inputs.type(torch.FloatTensor).unsqueeze(0).cuda()
    
    parti = path.split('/')[-1].split('_')
    
    y = model_conv(inputs)
    outp, preds = torch.max(y, 1)
    y = func(y) 
    
    for i in range(0, inputs.shape[0]):
      predicted = predicted.append({'filename': path.split('/')[-1],
                                    'patient': parti[0]+'_'+parti[1],
                                    'patient_lato': parti[0]+'_'+parti[1]+'_'+parti[2],
                                    'idx_lesione': int(parti[4].split('.')[0]),
                                    'dim_lesione': int(parti[3]),
                                    'prob0': y[i,0].item(),
                                    'prob1': y[i,1].item(),
                                    'predicted': preds[i].item(),
                                    'true_class': label_true,
                                    }, ignore_index=True)
  return predicted
## #------------------------------------------------------------------------------->Retrain function
def train_loop(model_conv,
               trainset, test, 
               startEpoch, 
               num_epoch, loader_opts,
               criterionCNN, optimizer_conv, outputPath, 
               weightName, chekpointName):
  
  for epochs in range(startEpoch, num_epoch + 1):

    TrainLoader = DataLoader(trainset, shuffle=True, **loader_opts)
    modelLoss_train = 0.0
    modelAcc_train = 0.0
    totalSize = 0

    model_conv.train() 
    totPred = torch.empty(0)
    totLabels = torch.empty(0)
    #-----------------------------------------------------------------------------> TRAIN      
    for inputs, labels in TrainLoader:
      inputs = inputs.type(torch.FloatTensor).cuda()
      labels = labels.cuda()
    
      optimizer_conv.zero_grad()
      model_conv.zero_grad()
       
      y = model_conv(inputs)
      outp, preds = torch.max(y, 1)   
      lossCNN = criterionCNN(y, labels) #media per batch
       
      lossCNN.backward()
      optimizer_conv.step()
       
      totPred = torch.cat((totPred, preds.cpu()))
      totLabels = torch.cat((totLabels, labels.cpu()))
       
      modelLoss_train += lossCNN.item() * inputs.size(0)
      totalSize += inputs.size(0)
      modelAcc_train += torch.sum(preds == labels.data).item()
      
    modelLoss_epoch_train = modelLoss_train/totalSize
    modelAcc_epoch_train  = modelAcc_train/totalSize
    
    totPred = totPred.numpy()
    totLabels = totLabels.numpy()
    acc = np.sum((totPred == totLabels).astype(int))/totalSize
    
    x = totLabels[np.where(totLabels == 1)]
    y = totPred[np.where(totLabels == 1)]
    acc_1_T = np.sum((x == y).astype(int))/x.shape[0]
    
    x = totLabels[np.where(totLabels == 0)]
    y = totPred[np.where(totLabels == 0)]
    acc_0_T = np.sum((x == y).astype(int))/y.shape[0]

    torch.save(model_conv.state_dict(), outputPath + weightName)
    sio.savemat(outputPath + chekpointName, {'last_epoch': epochs}) 
      
    #-----------------------------------------------------------------------------> VALIDATION    
    model_conv.eval()
    tot_size_test = 0
    model_loss_test = 0.0
    modelAcc_acc_test = 0.0
    totPred_test = torch.empty(0)
    totLabels_test = torch.empty(0)  
    
    TestLoader = DataLoader(test, shuffle=True, **loader_opts)
    
    for  inputs, labels in TestLoader:
      inputs = inputs.type(torch.FloatTensor).cuda()
      labels = labels.cuda()

      y = model_conv(inputs)
      outp, preds = torch.max(y, 1)
      lossCNN = criterionCNN(y, labels)

      totPred_test = torch.cat((totPred_test, preds.cpu()))
      totLabels_test = torch.cat((totLabels_test, labels.cpu()))

      model_loss_test += lossCNN.item() * inputs.size(0)  #Non pesata -> semplice media
      tot_size_test += inputs.size(0)
      modelAcc_acc_test += torch.sum(preds == labels.data).item()
        
    modelLoss_epoch_test = model_loss_test/tot_size_test
    modelAcc_epoch_test = modelAcc_acc_test/tot_size_test

    totPred_test = totPred_test.numpy()
    totLabels_test = totLabels_test.numpy()
    acc_val = np.sum((totPred_test == totLabels_test).astype(int))/tot_size_test
      
    x = totLabels_test[np.where(totLabels_test == 1)]
    y = totPred_test[np.where(totLabels_test == 1)]
    acc_1_test = np.sum((x == y).astype(int))/x.shape[0]
      
    x = totLabels_test[np.where(totLabels_test == 0)]
    y = totPred_test[np.where(totLabels_test == 0)]
    acc_0_test = np.sum((x == y).astype(int))/y.shape[0] 

    
    print('[Epoch %d][TRAIN on %d [Loss: %.4f  ACC: %.4f - ACC_0: %.4f - ACC_1: %.4f]][TEST on %d [Loss: %.4f ][ACC_T: %.4f - ACC_0: %.4f - ACC_1: %.4f]]' 
          %(epochs, totalSize, modelLoss_epoch_train, modelAcc_epoch_train, acc_0_T, acc_1_T,
            tot_size_test, modelLoss_epoch_test, 
            modelAcc_epoch_test, acc_0_test, acc_1_test))
    
    
  return model_conv
  
#Definizione trasformazioni
def definisciTransf(mean, std, tipoNorm):
  if tipoNorm == 'torch_computeMeanAndStd_channnel':
    train_transform_0_cavo, train_transform_1_cavo, None_transform  = NormTransf(mean, std)
  else:
    train_transform_0_cavo, train_transform_1_cavo, None_transform  = NoNormTransform()
  
  return train_transform_0_cavo, train_transform_1_cavo, None_transform 

def NoNormTransform():
  choice = transforms.RandomChoice([Random_Rotation(p=0.5, n=1),
                                    Random_Rotation(p=0.5, n=2), 
                                    Random_Rotation(p=0.5, n=3)])
  
  #----------------------------------------------------------------------------> CONTROLLO SULLA MASCHERA
  train_transform_0_cavo = transforms.Compose([transforms.ToTensor(),
                                               transforms.Resize((64,64)),
                                               transforms.RandomHorizontalFlip(),
                                               transforms.RandomVerticalFlip(),
                                               transforms.RandomRotation(degrees=90),
                                               choice
                                               ])  
  train_transform_1_cavo = transforms.Compose([transforms.ToTensor(),
                                               transforms.Resize((64,64)),
                                               transforms.RandomHorizontalFlip(),
                                               transforms.RandomVerticalFlip(),
                                               transforms.RandomRotation(degrees=90),
                                               choice
                                               ]) 
  None_transform  = transforms.Compose([transforms.ToTensor(),
                                        transforms.Resize((64,64))])
  
  return train_transform_0_cavo, train_transform_1_cavo, None_transform  


def NormTransf(mean, std):
  choice = transforms.RandomChoice([Random_Rotation(p=0.5, n=1),
                                    Random_Rotation(p=0.5, n=2), 
                                    Random_Rotation(p=0.5, n=3)])  
  #----------------------------------------------------------------------------> CONTROLLO SULLA MASCHERA
  train_transform_0_cavo = transforms.Compose([transforms.ToTensor(),
                                               transforms.Normalize(mean = mean, std = std, inplace = True), 
                                               transforms.Resize((64,64)),
                                               transforms.RandomHorizontalFlip(),
                                               transforms.RandomVerticalFlip(),
                                               transforms.RandomRotation(degrees=90),
                                               choice
                                               ]) 
  train_transform_1_cavo = transforms.Compose([transforms.ToTensor(),
                                               transforms.Normalize(mean = mean, std = std, inplace = True),
                                               transforms.Resize((64,64)),
                                               transforms.RandomHorizontalFlip(),
                                               transforms.RandomVerticalFlip(),
                                               transforms.RandomRotation(degrees=90),
                                               choice
                                               ]) 
  None_transform  = transforms.Compose([transforms.ToTensor(),
                                        transforms.Normalize(mean = mean, std = std, inplace = True),
                                        transforms.Resize((64,64))])

  return train_transform_0_cavo, train_transform_1_cavo, None_transform


def statistiche(listFiles):
  mean_n_a, std_n_a = np_computeMeanAndStd_all(listFiles)
  print(mean_n_a)
  print(std_n_a)
  mean_n_c, std_n_c = np_computeMeanAndStd_channnel(listFiles)
  print(mean_n_c)
  print(std_n_c) 
  mean_t_a, std_t_a = torch_computeMeanAndStd_all(listFiles)
  print(mean_t_a)
  print(std_t_a)  
  mean_t_c, std_t_c = torch_computeMeanAndStd_channnel(listFiles)
  print(mean_t_c)
  print(std_t_c)

  return mean_t_a, std_t_a, mean_t_c, std_t_c

# %% [markdown]
# #Network Definition

# %%
#-------------------------------------------------------------------------------> Definizione della rete  
class ReductionCoreBlock(nn.Module):
  def __init__(self, inputChannel, outchannel, ksize, stride, pad):
    super(ReductionCoreBlock, self).__init__()

    self.downsample = nn.Sequential(
        nn.Conv2d(in_channels=inputChannel, out_channels=outchannel, kernel_size = ksize, stride = stride, padding=pad, bias=False),
        nn.BatchNorm2d(outchannel),
        nn.ReLU(inplace=True),
        )
  
  def forward(self, x):
    out = self.downsample(x)
    return out

#160 160 90
#Configurazione D -> potrebbe andare
class My3DNet(nn.Module):
  def __init__(self, nChannel, nfilters,printB):
    super(My3DNet, self).__init__()
    self.printB = printB
    self.reduction_1 =  nn.Sequential(
        #64
        ReductionCoreBlock(inputChannel = nChannel, outchannel=nfilters, ksize=(4,4), stride=(2,2), pad=(1,1)), 
    )

    self.reduction_2 = nn.Sequential(
        #32
        ReductionCoreBlock(inputChannel= nfilters, outchannel=nfilters*2, ksize=(4,4), stride=(2,2), pad=(1,1)), 
    )
    
    self.reduction_3 = nn.Sequential(
        #16
        ReductionCoreBlock(inputChannel= nfilters*2, outchannel=nfilters*4,ksize=(4,4), stride=(2,2),pad=(1,1)),     
        )
    
    self.reduction_4 =  nn.Sequential(   
        #8
        ReductionCoreBlock(inputChannel= nfilters*4, outchannel=nfilters*8, ksize=(4,4), stride=(2,2), pad=(1,1)), 
    )

    self.reduction_5 =  nn.Sequential(  
        #4 
        ReductionCoreBlock(inputChannel= nfilters*8, outchannel=nfilters*16, ksize=(4,4), stride=(2,2), pad=(0,0)), 
    )

  

    self.end = self.end = nn.Sequential(  
        nn.Linear(nfilters*16,nfilters*8),
        nn.ReLU(inplace= True),
        nn.Linear(nfilters*8,2),
        )

  
  def forward(self, x):
    if self.printB:
      print(x.shape)
    x = self.reduction_1(x)

    if self.printB:
      print(x.shape)
    x = self.reduction_2(x)
    
    if self.printB:
      print(x.shape)
    x = self.reduction_3(x)
    if self.printB:
      print(x.shape)
    
    x = self.reduction_4(x)
    if self.printB:
      print(x.shape)
    x = self.reduction_5(x)
    if self.printB:
      print(x.shape)

    x = torch.flatten(x,1)
    if self.printB:
      print(x.shape)
    x = self.end(x)

    return x
'''
def build_model(name, ch_ingresso, num_classi):
  if name == 'alexnet':
    model_conv = torchvision.models.alexnet(pretrained=True)
    model_conv.features[0] = nn.Conv2d(in_channels=ch_ingresso, out_channels=64, kernel_size=(11,11), stride=(4,4), padding=(2,2))
    model_conv.classifier[6] = nn.Linear(4096, num_classi)
  elif name == 'resnet34':
    model_conv = torchvision.models.resnet34(pretrained=True)
    model_conv.conv1 = nn.Conv2d(in_channels=ch_ingresso, out_channels=64, kernel_size=(7,7), stride=(2,2), padding=(3,3), bias=False)
    model_conv.fc =  nn.Linear(model_conv.fc.in_features, num_classi)
  elif name == 'efficientnet-b0':
    model_conv =  EfficientNet.from_pretrained('efficientnet-b0', num_classes=num_classi)
    model_conv._conv_stem =  nn.Conv2d(in_channels=4, out_channels=32, kernel_size=(3,3), stride=(2,2), padding=(1,1), bias=False)

  for param in model_conv.parameters():
    param.requires_grad = True

  return model_conv
'''

def count_parameters(model):
    return sum(p.numel() for p in model.parameters() if p.requires_grad)

# %%
x = torch.rand(3,4,64,64)
net = My3DNet(4,8, True)
print(net(x).shape)
print(count_parameters(net))
print(net.end)
# Out:
# torch.Size([3, 4, 64, 64])
# torch.Size([3, 8, 32, 32])
# torch.Size([3, 16, 16, 16])
# torch.Size([3, 32, 8, 8])
# torch.Size([3, 64, 4, 4])
# torch.Size([3, 128, 1, 1])
# torch.Size([3, 128])
# torch.Size([3, 2])
# 183474
# Sequential(
#   (0): Linear(in_features=128, out_features=64, bias=True)
#   (1): ReLU(inplace=True)
#   (2): Linear(in_features=64, out_features=2, bias=True)
# )

# %% [markdown]
# #Main

# %%
#rendere l'esecuzione deterministica 
torch.manual_seed(0)
np.random.seed(0)
torch.backends.cudnn.deterministic = True
torch.backends.cudnn.benchmark = False

def readVolume(path):
  x = loadmat(path)
  y_new= x['volume'].astype(np.float32)
  mask = x['mask'].astype(np.float32)
  y_new = rangeNormalization(y_new, 1, 0)
  y_new = multiply_mask(y_new, mask)
  return y_new

#-------------------------------------------------------------------------------> DATALOADER PER IL TRAIN
class My_DatasetFolder(Dataset):
  def __init__(self, root,  transform, is_valid_file, list_classes):
    self.root = root 
    self.transform = transform
    self.is_valid_file = is_valid_file
    self.list_classes = list_classes
    self.samples = self.__get_samples()

  def __len__(self):
    return len(self.samples)

  def __get_samples(self):
    ListFiles=[]
    for c in self.list_classes:
      listofFiles = os.listdir(self.root + '/' + c)
      for file in listofFiles:
        if self.is_valid_file(self.root + '/' + c + '/' + file):
          ListFiles.append((self.root + '/' + c + '/' + file, self.list_classes.index(c)))   
    return ListFiles

  def __getitem__(self, index: int):
    path, target = self.samples[index]
    sample = readVolume(path)
    if self.transform is not None:
      sample = self.transform[target](sample)
    return sample, target                                    
	
	

def main_TRAIN(fold,continue_learning, tipoNormalizzazione_str, loss,
        basePath, classes, ch, learningRate, weightDecay, batchSize, num_epoch, 
        vali_set,test_set,
        outputPath, input_ch, name, num_classi):  
  print('---------------------------------> CARICAMENTO DATI')
  include_train_patient = lambda path: (path.split('/')[-1].split('_')[0] not in vali_set + test_set)
                                      
  include_val_patient =  lambda path: (path.split('/')[-1].split('_')[0] in vali_set) 

  include_test_patient =  lambda path: (path.split('/')[-1].split('_')[0] in test_set)


  train_files = getFilesForSubset(basePath, classes, include_train_patient)
  print(len(train_files))

  val_files = getFilesForSubset(basePath, classes, include_val_patient)
  print(len(val_files))

  test_files = getFilesForSubset(basePath, classes, include_test_patient)
  print(len(test_files))

  print(' - - - - - train')
  mean_t_a_train, std_t_a_train, mean_t_c_train, std_t_c_train = statistiche(train_files)

  print(' - - - - - val')
  mean_t_a_val, std_t_a_val, mean_t_c_val, std_t_c_val = statistiche(val_files)

  print(' - - - - - test')
  mean_t_a_test, std_t_a_test, mean_t_c_test, std_t_c_test = statistiche(test_files)


  train_transform_0_cavo, train_transform_1_cavo, None_transform = definisciTransf(mean_t_c_train, std_t_c_train, tipoNormalizzazione_str)                                

  print(train_transform_0_cavo)   
  print(train_transform_1_cavo)     
  print(None_transform) 

  Trainset = [] 
  for c in classes:
    print(' Loading ' + c)
    is_valid_class = lambda path: c == path.split('/')[1]
    check_file = lambda path: include_train_patient(path) and is_valid_class(path)
    Trainset.append(My_DatasetFolder(root = basePath, transform=[train_transform_0_cavo, train_transform_1_cavo], is_valid_file=check_file, list_classes=classes ))


  print('0_cavo elements ', str(len(Trainset[0].samples)))
  print('1_cavo elements ', str(len(Trainset[1].samples)))
  completeTrainSet = BalanceConcatDataset(Trainset)
  print('0_cavo elements ', str(len(completeTrainSet.datasets[0].samples)))
  print('1_cavo elements ', str(len(completeTrainSet.datasets[1].samples)))

  Val  = My_DatasetFolder(root = basePath, transform=[None_transform,None_transform], is_valid_file=include_val_patient, list_classes=classes)
  Test = My_DatasetFolder(root = basePath, transform=[None_transform,None_transform], is_valid_file=include_test_patient, list_classes=classes)
  print('Validation ',str(len(Val.samples)))
  print('Test ', str(len(Test.samples)))
  
  print('---------------------------------> ADDESTRAMENTO')
  
  #definizione del modello
  model_conv = My3DNet(input_ch,ch, False)
  #model_conv = build_model(name, input_ch, num_classi)
  model_conv = model_conv.cuda() 
  print(count_parameters(model_conv))

  optimizer_conv = optim.Adam(model_conv.parameters(), lr=learningRate, weight_decay= weightDecay)
  if loss == 'focal':
    criterionCNN = FocalLoss()
  else:
    criterionCNN = nn.CrossEntropyLoss()

  loader_opts = {'batch_size': batchSize, 'num_workers': 4, 'pin_memory': False}
  print('     Before Training: GPU Memory  %d bytes'%(torch.cuda.memory_allocated()))

  if not continue_learning:
    #inizializzazione senza check point
    best_acc = 0.0   
    best_loss = 0.0 
    best_epoca = 0
    startEpoch = 1
  else:
    print('RELOAD')
    stato = sio.loadmat(outputPath + 'check_point.mat')
    best_acc = stato['best_acc'][0][0]
    best_loss = stato['best_loss'][0][0]
    best_epoca = stato['best_epoca'][0][0]
    startEpoch = stato['last_epoch'][0][0] + 1
    model_conv.load_state_dict(torch.load(outputPath + 'train_weights.pth'))

  model_conv = train_loop_validation(model_conv, 
                                     completeTrainSet, Val, Test, 
                                     startEpoch, num_epoch, 
                                     loader_opts, 
                                     criterionCNN, optimizer_conv, 
                                     best_acc, best_loss, best_epoca, 
                                     outputPath)

  print('     After Training: GPU Memory  %d bytes'%(torch.cuda.memory_allocated()))
  model_conv.cpu()
  del model_conv
  print('     After Training: GPU Memory  %d bytes'%(torch.cuda.memory_allocated()))
  
  print('---------------------------------> BEST MODEL')
  lossModel_Train = []
  lossModel_val = []
  lossModel_val_weighted = []
  
  accModel_Train = []
  accModel_val = []

  Acc_0 = []
  Acc_1 = []

  file = open(outputPath + 'lossTrain.txt', 'r')
  Testo = file.readlines()
  for element in Testo:
    lossModel_Train.append(float(element))

  file = open(outputPath + 'lossVal.txt', 'r')
  Testo = file.readlines()
  for element in Testo:
    lossModel_val.append(float(element))

  plt.figure()
  plt.title("Model: Training Vs Validation Losses")
  plt.xlabel('Epoch')
  plt.ylabel('Loss')
  plt.plot(list(range(1,len(lossModel_Train)+1)), lossModel_Train, color='r', label="Training Loss")  
  plt.plot(list(range(1, len(lossModel_val)+1)), lossModel_val, color='g', label="Validation Loss")
  plt.legend()
  plt.savefig(outputPath + 'LossTrainVal.png')


  file = open(outputPath + 'AccTrain.txt', 'r')
  Testo = file.readlines()
  for element in Testo:
    accModel_Train.append(float(element))

  file = open(outputPath + 'AccVal.txt', 'r')
  Testo = file.readlines()
  for element in Testo:
    accModel_val.append(float(element))

  plt.figure()
  plt.title("Training Vs Validation Accuracies")
  plt.xlabel('Epoch')
  plt.ylabel('Accuracy')
  plt.plot(list(range(1, len(accModel_Train)+1)), accModel_Train, color='r', label="Training Accuracy")
  plt.plot(list(range(1, len(accModel_val)+1)), accModel_val, color='g', label="Validation Accuracy")
  plt.legend()
  plt.savefig(outputPath + 'AccTrainVal.png')
  
  
  file = open(outputPath + 'AccVal_0.txt', 'r')
  Testo = file.readlines()
  for element in Testo:
    Acc_0.append(float(element))

  file = open(outputPath + 'AccVal_1.txt', 'r')
  Testo = file.readlines()
  for element in Testo:
    Acc_1.append(float(element))

  plt.figure()
  plt.title("Validation Accuracies")
  plt.xlabel('Epoch')
  plt.ylabel('Accuracy')
  plt.plot(list(range(1, len(Acc_0)+1)), Acc_0, color='r', label="Val Accuracy class 0")
  plt.plot(list(range(1, len(Acc_1)+1)), Acc_1, color='g', label="Val Accuracy class 1")
  plt.plot(list(range(1, len(accModel_val)+1)), accModel_val, color='b', label="Total Val Accuracy")
  plt.legend()
  plt.savefig(outputPath + 'AccVal.png')
  
  #definizione del modello
  model_conv = My3DNet(input_ch,ch, False)
  print(count_parameters(model_conv))
  model_conv.load_state_dict(torch.load(outputPath + 'best_model_weights.pth'))
  model_conv = model_conv.cuda() 

  model_conv.eval()
  #model_conv, test, transform
  tabella = prediction_on_Test(model_conv, Test, None_transform)
  tabella.to_csv(outputPath + 'TabellaBestModel.csv', sep = ',', index=False)


  accuracy = np.sum(tabella.true_class.values == tabella.predicted.values)/tabella.shape[0]
  t0 = tabella[tabella.true_class == 0]
  t1 = tabella[tabella.true_class == 1]

  accuracy_0 = np.sum(t0.true_class.values == t0.predicted.values)/t0.shape[0]
  accuracy_1 = np.sum(t1.true_class.values == t1.predicted.values)/t1.shape[0]

  print('Accuracy')
  print(accuracy)
  print('Accuracy_0')
  print(accuracy_0)
  print('Accuracy_1')
  print(accuracy_1)

  model_conv.cpu()
  del model_conv
  print('     After Training: GPU Memory  %d bytes'%(torch.cuda.memory_allocated()))
  
     
def main_validation(fold,continue_fine_tuning, tipoNormalizzazione_str, loss,
     basePath, classes, ch, learningRate, weightDecay, batchSize, epocheFineTuning, fattore,
     vali_set, test_set,
     outputPath, input_ch, name, num_classi): 
     
  include_train_patient = lambda path: (path.split('/')[-1].split('_')[0] not in vali_set + test_set) 


  train_files = getFilesForSubset(basePath, classes, include_train_patient)
  print(len(train_files))

  print(' - - - - - train')
  mean_t_a_train, std_t_a_train, mean_t_c_train, std_t_c_train = statistiche(train_files)

  train_transform_0_cavo, train_transform_1_cavo, None_transform = definisciTransf(mean_t_c_train, std_t_c_train, tipoNormalizzazione_str)                                

  print(train_transform_0_cavo)   
  print(train_transform_1_cavo)     
  print(None_transform) 
  #-----------------------------------------------------------------------------> fine tuning finale
  include_train_patient_fine = lambda path: (path.split('/')[-1].split('_')[0] in vali_set) 
  

  include_test_patient =  lambda path: (path.split('/')[-1].split('_')[0] in test_set) 

  Trainset = []   
  for c in classes:
    print(' Loading ' + c)
    is_valid_class = lambda path: c == path.split('/')[1]
    check_file = lambda path: include_train_patient_fine(path) and is_valid_class(path)
    Trainset.append(My_DatasetFolder(root = basePath, transform=[train_transform_0_cavo, train_transform_1_cavo], is_valid_file=check_file, list_classes=classes))
  print('0_cavo elements ', str(len(Trainset[0].samples)))
  print('1_cavo elements ', str(len(Trainset[1].samples)))
  completeTrainSet = BalanceConcatDataset(Trainset)
  print('0_cavo elements ', str(len(completeTrainSet.datasets[0].samples)))
  print('1_cavo elements ', str(len(completeTrainSet.datasets[1].samples)))

  Test = My_DatasetFolder(root = basePath, transform=[None_transform,None_transform], is_valid_file=include_test_patient, list_classes=classes)
  print('Test ', str(len(Test.samples)))

  #-------------------------------------------------------------------------------> Definizione del modello
  #definizione del modello
  model_conv = My3DNet(input_ch,ch, False)
  model_conv.load_state_dict(torch.load(outputPath + 'best_model_weights.pth'))  
  model_conv = model_conv.cuda() 
  print(count_parameters(model_conv))

  optimizer_conv = optim.Adam(model_conv.parameters(), lr=learningRate*fattore, weight_decay= weightDecay)
  if loss == 'focal':
    criterionCNN = FocalLoss()
  else:
    criterionCNN = nn.CrossEntropyLoss()
    
  loader_opts = {'batch_size': batchSize, 'num_workers': 4, 'pin_memory': False}

  print('     Before Training: GPU Memory  %d bytes'%(torch.cuda.memory_allocated()))
  startEpoch = 1

  if continue_fine_tuning:
    print('RELOAD')
    stato = sio.loadmat(outputPath + 'check_point_for_fineTuning.mat')
    startEpoch = stato['last_epoch'][0][0] + 1
    model_conv.load_state_dict(torch.load(outputPath + 'FinalWeightsFineTuning.pth'))

  #------------------------------------------------------------ Addestramento
  model_conv = train_loop(model_conv,
                          completeTrainSet, Test,
                          startEpoch,
                          epocheFineTuning, loader_opts, 
                          criterionCNN, optimizer_conv, outputPath, 'FinalWeightsFineTuning.pth', 'check_point_for_fineTuning.mat')

  model_conv.cpu()
  del model_conv
  print('     After Training: GPU Memory  %d bytes'%(torch.cuda.memory_allocated()))

  #definizione del modello
  model_conv = My3DNet(input_ch,ch, False)
  model_conv.load_state_dict(torch.load(outputPath + 'FinalWeightsFineTuning.pth'))
  model_conv = model_conv.cuda() 
  print(count_parameters(model_conv))


  model_conv.eval()
  tabella = prediction_on_Test(model_conv, Test, None_transform)
  tabella.to_csv(outputPath + 'TabellaFinalModelFineTuning.csv', sep = ',', index=False)


  accuracy = np.sum(tabella.true_class.values == tabella.predicted.values)/tabella.shape[0]
  t0 = tabella[tabella.true_class == 0]
  t1 = tabella[tabella.true_class == 1]

  accuracy_0 = np.sum(t0.true_class.values == t0.predicted.values)/t0.shape[0]
  accuracy_1 = np.sum(t1.true_class.values == t1.predicted.values)/t1.shape[0]

  print('Accuracy')
  print(accuracy)
  print('Accuracy_0')
  print(accuracy_0)
  print('Accuracy_1')
  print(accuracy_1)

  model_conv.cpu()
  del model_conv
  print('     After Training: GPU Memory  %d bytes'%(torch.cuda.memory_allocated()))


def main_final_restrain(fold,continue_learning_retrain, tipoNormalizzazione_str, loss,
     basePath, classes, ch, learningRate, weightDecay, batchSize, 
     vali_set, test_set,
     outputPath, input_ch, name, num_classi): 
     
  include_train_patient_fine = lambda path: (path.split('/')[-1].split('_')[0] not in test_set) 

  train_files = getFilesForSubset(basePath, classes, include_train_patient_fine)
  print(len(train_files))

  print(' - - - - - train')
  mean_t_a_train, std_t_a_train, mean_t_c_train, std_t_c_train = statistiche(train_files)

  train_transform_0_cavo, train_transform_1_cavo, None_transform = definisciTransf(mean_t_c_train, std_t_c_train, tipoNormalizzazione_str)                                

  print(train_transform_0_cavo)   
  print(train_transform_1_cavo)     
  print(None_transform)  
  #-----------------------------------------------------------------------------> fine tuning finale


  include_test_patient =  lambda path: (path.split('/')[-1].split('_')[0] in test_set)

  Trainset = []   
  for c in classes:
    print(' Loading ' + c)
    is_valid_class = lambda path: c == path.split('/')[1]
    check_file = lambda path: include_train_patient_fine(path) and is_valid_class(path)
    Trainset.append(My_DatasetFolder(root = basePath, transform=[train_transform_0_cavo, train_transform_1_cavo], is_valid_file=check_file, list_classes=classes))
  print('0_cavo elements ', str(len(Trainset[0].samples)))
  print('1_cavo elements ', str(len(Trainset[1].samples)))
  completeTrainSet = BalanceConcatDataset(Trainset)
  print('0_cavo elements ', str(len(completeTrainSet.datasets[0].samples)))
  print('1_cavo elements ', str(len(completeTrainSet.datasets[1].samples)))

  Test = My_DatasetFolder(root = basePath, transform=[None_transform,None_transform], is_valid_file=include_test_patient, list_classes=classes)
  print('Test ', str(len(Test.samples)))

  #-------------------------------------------------------------------------------> Definizione del modello
  #definizione del modello
  model_conv = My3DNet(input_ch,ch, False)
  model_conv = model_conv.cuda() 
  print(count_parameters(model_conv))

  optimizer_conv = optim.Adam(model_conv.parameters(), lr=learningRate, weight_decay= weightDecay)

  if loss == 'focal':
    criterionCNN = FocalLoss()
  else:
    criterionCNN = nn.CrossEntropyLoss()

  loader_opts = {'batch_size': batchSize, 'num_workers': 4, 'pin_memory': False}

  print('     Before Training: GPU Memory  %d bytes'%(torch.cuda.memory_allocated()))
  stato = sio.loadmat(outputPath + 'check_point.mat')
  best_epoca_onMinLoss = stato['best_epoca'][0][0]

  accModel_val = []
  file = open(outputPath + 'AccVal.txt', 'r')
  Testo = file.readlines()
  for element in Testo:
    accModel_val.append(float(element))
  
  best_epoca_onMax = np.argmax(accModel_val) +1
  
  print(best_epoca_onMax)
  best_epoca = np.max([best_epoca_onMinLoss, best_epoca_onMax])

  print('Retrain for ' + str(best_epoca) + ' epochs')
  startEpoch = 1

  if continue_learning_retrain:
    print('RELOAD')
    stato = sio.loadmat(outputPath + 'check_point_for_retrain.mat')
    startEpoch = stato['last_epoch'][0][0] + 1
    model_conv.load_state_dict(torch.load(outputPath + 'FinalWeights.pth'))

  #------------------------------------------------------------ Addestramento
  model_conv = train_loop(model_conv,
                        completeTrainSet, Test, 
                        startEpoch, 
                        best_epoca, loader_opts,
                        criterionCNN, optimizer_conv, outputPath, 'FinalWeights.pth', 'check_point_for_retrain.mat')

  model_conv.cpu()
  del model_conv
  print('     After Training: GPU Memory  %d bytes'%(torch.cuda.memory_allocated()))

  #definizione del modello
  model_conv = My3DNet(input_ch,ch, False)
  model_conv.load_state_dict(torch.load(outputPath + 'FinalWeights.pth'))
  model_conv = model_conv.cuda() 
  print(count_parameters(model_conv))


  model_conv.eval()
  tabella = prediction_on_Test(model_conv, Test, None_transform)
  tabella.to_csv(outputPath + 'TabellaFinalModel.csv', sep = ',', index=False)


  accuracy = np.sum(tabella.true_class.values == tabella.predicted.values)/tabella.shape[0]
  t0 = tabella[tabella.true_class == 0]
  t1 = tabella[tabella.true_class == 1]

  accuracy_0 = np.sum(t0.true_class.values == t0.predicted.values)/t0.shape[0]
  accuracy_1 = np.sum(t1.true_class.values == t1.predicted.values)/t1.shape[0]

  print('Accuracy')
  print(accuracy)
  print('Accuracy_0')
  print(accuracy_0)
  print('Accuracy_1')
  print(accuracy_1)

  model_conv.cpu()
  del model_conv
  print('     After Training: GPU Memory  %d bytes'%(torch.cuda.memory_allocated()))

# %% [markdown]
# #Esegui

# %%
tipofunzione = 'train'
fold = 1
continue_learning = 'false'
tipoNormalizzazione_str = 'None'
name = 'MyNet'
loss = 'cross'

print('tipofunzione ' + tipofunzione + ' - ' + 'fold ' + str(fold) +  ' - ' + 'continue_learning ' + continue_learning + ' tipoNormalizzazione_str ' + tipoNormalizzazione_str)
  
if continue_learning == 'true':
  continue_learning = True
else:
  continue_learning = False
  
dfs = pd.read_excel('/content/drive/My Drive/CampusBioMedico/NewFold_10_Confronto.xlsx', sheet_name='Foglio1')
classes = ['0_cavo', '1_cavo']
basePath = 'VolumiDCE_Sub_AllBox_2D'
  
fattore = 0.1
epocheFineTuning = 100
learningRate = 0.00001
weightDecay = 0.0001
batchSize = 64
num_epoch = 600
ch = 8
input_ch = 4
num_classi = 2


test_set = dfs[dfs.FOLD == fold].ID.to_list()
valFold = dfs[dfs.FOLD == fold].Fold_to_use.values[0]
vali_set = dfs[dfs.FOLD == valFold].ID.to_list()
print('Test: fold ' + str(fold))
print(test_set)
print('Val: fold ' + str(valFold))
print(vali_set)
  
if len(list(set(test_set) & set(vali_set)))>0:
  print('errore!!!')
  
outputPath = '/content/drive/My Drive/CampusBioMedico/DCE_2DWITHMASK_'+ loss + '_' + name + '_' + str(ch)+ '/Fold' + str(fold) +'/'
  
try:
  os.makedirs(outputPath)
except OSError:
  pass
    
with open(outputPath + 'InfoAddestramento.txt', "w") as file_object:
  file_object.write('batch_size: '+str(batchSize)+'\n')
  file_object.write('lr: '+str(learningRate)+'\n')
  file_object.write('decay: '+str(weightDecay)+'\n')
  file_object.write('fattore per il fine tuning sul val: '+ str(fattore)+'\n')
  file_object.write('epocheFineTuning: '+ str(epocheFineTuning)+'\n')
  file_object.write('tipoNormalizzazione: '+ tipoNormalizzazione_str +'\n')
  file_object.write('Info: Rete standard piccola si padding, con adaptiveAvgPool, 2 linear \n')
  file_object.write('Range 01')
    

if tipofunzione == 'train':
  main_TRAIN(fold,continue_learning, tipoNormalizzazione_str, loss,
             basePath, classes, ch, learningRate, weightDecay, batchSize, num_epoch, 
             vali_set, test_set,
             outputPath, input_ch, name, num_classi)
  
  main_validation(fold,False, tipoNormalizzazione_str, loss,
                    basePath, classes, ch, learningRate, weightDecay, batchSize, epocheFineTuning, fattore, 
                    vali_set, test_set, 
                    outputPath, input_ch, name, num_classi)
  
  main_final_restrain(fold,False, tipoNormalizzazione_str, loss,
                     basePath, classes, ch, learningRate, weightDecay, batchSize, 
                     vali_set, test_set,
                     outputPath, input_ch, name, num_classi) 
elif tipofunzione == 'val':
  main_validation(fold,continue_learning, tipoNormalizzazione_str, loss,
                  basePath, classes, ch, learningRate, weightDecay, batchSize, epocheFineTuning, fattore,
                  vali_set, test_set, 
                  outputPath, input_ch, name, num_classi)
  
  main_final_restrain(fold,False, tipoNormalizzazione_str, loss,
                     basePath, classes, ch, learningRate, weightDecay, batchSize, 
                     vali_set, test_set,
                     outputPath, input_ch, name, num_classi) 
else:
  main_final_restrain(fold,continue_learning, tipoNormalizzazione_str, loss,
                     basePath, classes, ch, learningRate, weightDecay, batchSize, 
                     vali_set, test_set,
                     outputPath, input_ch, name, num_classi)
# Out:
# tipofunzione train - fold 1 - continue_learning false tipoNormalizzazione_str None
# Test: fold 1
# ['104', '117', '11', '125', '130', '145', '160', '16', '175', '29', '43', '58', '5', '71', '74', '94']
# Val: fold 0
# ['102', '103', '10', '114', '12', '13-14', '13-14', '143', '15', '173', '28', '41', '56', '59', '70', '93']
# ---------------------------------> CARICAMENTO DATI
# 2471
# 331
# 267
#  - - - - - train
# 0.044688118858539946
# 0.15723193676225247
# [0.03340872 0.04525651 0.04984814 0.05023919]
# [0.12019183 0.1576617  0.17178185 0.17288804]
# tensor(0.0447)
# tensor(0.1572)
# tensor([0.0334, 0.0453, 0.0498, 0.0502])
# tensor([0.1202, 0.1577, 0.1718, 0.1729])
#  - - - - - val
# 0.03904359859435716
# 0.14436066812315074
# [0.03069153 0.03948877 0.04277134 0.04322276]
# [0.11638325 0.14508808 0.15553902 0.15643114]
# tensor(0.0390)
# tensor(0.1444)
# tensor([0.0307, 0.0395, 0.0428, 0.0432])
# tensor([0.1164, 0.1451, 0.1555, 0.1564])
#  - - - - - test
# 0.043317881605035025
# 0.14881639195887025
# [0.03330061 0.04362713 0.04820901 0.04813472]
# [0.1161204  0.14830176 0.1628694  0.16258509]
# tensor(0.0433)
# tensor(0.1488)
# tensor([0.0333, 0.0436, 0.0482, 0.0481])
# tensor([0.1161, 0.1483, 0.1629, 0.1626])
# Compose(
#     ToTensor()
#     Resize(size=(64, 64), interpolation=bilinear, max_size=None, antialias=None)
#     RandomHorizontalFlip(p=0.5)
#     RandomVerticalFlip(p=0.5)
#     RandomRotation(degrees=[-90.0, 90.0], interpolation=nearest, expand=False, fill=0)
#     RandomChoice(
#     Random_Rotation(p=0.5, n=1)
#     Random_Rotation(p=0.5, n=2)
#     Random_Rotation(p=0.5, n=3)
# )(p=None)
# )
# Compose(
#     ToTensor()
#     Resize(size=(64, 64), interpolation=bilinear, max_size=None, antialias=None)
#     RandomHorizontalFlip(p=0.5)
#     RandomVerticalFlip(p=0.5)
#     RandomRotation(degrees=[-90.0, 90.0], interpolation=nearest, expand=False, fill=0)
#     RandomChoice(
#     Random_Rotation(p=0.5, n=1)
#     Random_Rotation(p=0.5, n=2)
#     Random_Rotation(p=0.5, n=3)
# )(p=None)
# )
# Compose(
#     ToTensor()
#     Resize(size=(64, 64), interpolation=bilinear, max_size=None, antialias=None)
# )
#  Loading 0_cavo
#  Loading 1_cavo
# 0_cavo elements  1829
# 1_cavo elements  642
# 0_cavo elements  1829
# 1_cavo elements  1829
# Validation  331
# Test  267
# ---------------------------------> ADDESTRAMENTO
# 183474
#      Before Training: GPU Memory  745472 bytes
# /usr/local/lib/python3.7/dist-packages/torch/utils/data/dataloader.py:481: UserWarning: This DataLoader will create 4 worker processes in total. Our suggested max number of worker in current system is 2, which is smaller than what this DataLoader is going to create. Please be aware that excessive worker creation might get DataLoader running slow or even freeze, lower the worker number to avoid potential slowness/freeze if necessary.
#   cpuset_checked))
# [Epoch 1][TRAIN on 3658 [Loss: 0.6917 - ACC_T: 0.5265 - ACC_0: 0.6042 - ACC_1: 0.4489 ]][VAL on 331 [Loss: 0.6727 - ACC_T: 0.5287 - ACC_0: 0.5019 - ACC_1: 0.6364]]
#      .... Saving best weights ....
#       [TEST on 267 [Loss: 0.6794 - ACC_T: 0.5543 - ACC_0: 0.5576 - ACC_1: 0.5400 ]]
# [Epoch 2][TRAIN on 3658 [Loss: 0.6852 - ACC_T: 0.5462 - ACC_0: 0.5768 - ACC_1: 0.5156 ]][VAL on 331 [Loss: 0.6549 - ACC_T: 0.5680 - ACC_0: 0.5547 - ACC_1: 0.6212]]
#      .... Saving best weights ....
#       [TEST on 267 [Loss: 0.6688 - ACC_T: 0.5993 - ACC_0: 0.6452 - ACC_1: 0.4000 ]]
# [Epoch 3][TRAIN on 3658 [Loss: 0.6827 - ACC_T: 0.5577 - ACC_0: 0.5314 - ACC_1: 0.5839 ]][VAL on 331 [Loss: 0.6531 - ACC_T: 0.5498 - ACC_0: 0.5208 - ACC_1: 0.6667]]
#      .... Saving best weights ....
#       [TEST on 267 [Loss: 0.6724 - ACC_T: 0.5581 - ACC_0: 0.5945 - ACC_1: 0.4000 ]]
# [Epoch 4][TRAIN on 3658 [Loss: 0.6793 - ACC_T: 0.5577 - ACC_0: 0.5030 - ACC_1: 0.6124 ]][VAL on 331 [Loss: 0.6473 - ACC_T: 0.5468 - ACC_0: 0.5094 - ACC_1: 0.6970]]
#      .... Saving best weights ....
#       [TEST on 267 [Loss: 0.6767 - ACC_T: 0.5393 - ACC_0: 0.5576 - ACC_1: 0.4600 ]]
# [Epoch 5][TRAIN on 3658 [Loss: 0.6768 - ACC_T: 0.5664 - ACC_0: 0.4828 - ACC_1: 0.6501 ]][VAL on 331 [Loss: 0.6539 - ACC_T: 0.5287 - ACC_0: 0.4642 - ACC_1: 0.7879]]
# [Epoch 6][TRAIN on 3658 [Loss: 0.6742 - ACC_T: 0.5711 - ACC_0: 0.4658 - ACC_1: 0.6763 ]][VAL on 331 [Loss: 0.6397 - ACC_T: 0.5438 - ACC_0: 0.4830 - ACC_1: 0.7879]]
#      .... Saving best weights ....
#       [TEST on 267 [Loss: 0.6863 - ACC_T: 0.4869 - ACC_0: 0.4931 - ACC_1: 0.4600 ]]
# [Epoch 7][TRAIN on 3658 [Loss: 0.6733 - ACC_T: 0.5831 - ACC_0: 0.4647 - ACC_1: 0.7015 ]][VAL on 331 [Loss: 0.6412 - ACC_T: 0.5438 - ACC_0: 0.4755 - ACC_1: 0.8182]]
# [Epoch 8][TRAIN on 3658 [Loss: 0.6704 - ACC_T: 0.5765 - ACC_0: 0.4385 - ACC_1: 0.7146 ]][VAL on 331 [Loss: 0.6471 - ACC_T: 0.5106 - ACC_0: 0.4151 - ACC_1: 0.8939]]
# [Epoch 9][TRAIN on 3658 [Loss: 0.6684 - ACC_T: 0.5826 - ACC_0: 0.4401 - ACC_1: 0.7250 ]][VAL on 331 [Loss: 0.6390 - ACC_T: 0.5287 - ACC_0: 0.4453 - ACC_1: 0.8636]]
#      .... Saving best weights ....
#       [TEST on 267 [Loss: 0.6964 - ACC_T: 0.4232 - ACC_0: 0.4147 - ACC_1: 0.4600 ]]
# [Epoch 10][TRAIN on 3658 [Loss: 0.6678 - ACC_T: 0.5842 - ACC_0: 0.4418 - ACC_1: 0.7266 ]][VAL on 331 [Loss: 0.6289 - ACC_T: 0.5498 - ACC_0: 0.4717 - ACC_1: 0.8636]]
#      .... Saving best weights ....
#       [TEST on 267 [Loss: 0.6923 - ACC_T: 0.4419 - ACC_0: 0.4470 - ACC_1: 0.4200 ]]
# [Epoch 11][TRAIN on 3658 [Loss: 0.6634 - ACC_T: 0.5981 - ACC_0: 0.4451 - ACC_1: 0.7512 ]][VAL on 331 [Loss: 0.6320 - ACC_T: 0.5438 - ACC_0: 0.4604 - ACC_1: 0.8788]]
# [Epoch 12][TRAIN on 3658 [Loss: 0.6651 - ACC_T: 0.5782 - ACC_0: 0.4303 - ACC_1: 0.7261 ]][VAL on 331 [Loss: 0.6288 - ACC_T: 0.5559 - ACC_0: 0.4604 - ACC_1: 0.9394]]
#      .... Saving best weights ....
#       [TEST on 267 [Loss: 0.6989 - ACC_T: 0.4082 - ACC_0: 0.4055 - ACC_1: 0.4200 ]]
# [Epoch 13][TRAIN on 3658 [Loss: 0.6615 - ACC_T: 0.5913 - ACC_0: 0.4286 - ACC_1: 0.7540 ]][VAL on 331 [Loss: 0.6415 - ACC_T: 0.5317 - ACC_0: 0.4226 - ACC_1: 0.9697]]
# [Epoch 14][TRAIN on 3658 [Loss: 0.6589 - ACC_T: 0.5976 - ACC_0: 0.4276 - ACC_1: 0.7676 ]][VAL on 331 [Loss: 0.6337 - ACC_T: 0.5529 - ACC_0: 0.4528 - ACC_1: 0.9545]]
# [Epoch 15][TRAIN on 3658 [Loss: 0.6598 - ACC_T: 0.5919 - ACC_0: 0.4352 - ACC_1: 0.7485 ]][VAL on 331 [Loss: 0.6282 - ACC_T: 0.5529 - ACC_0: 0.4491 - ACC_1: 0.9697]]
#      .... Saving best weights ....
#       [TEST on 267 [Loss: 0.7070 - ACC_T: 0.4045 - ACC_0: 0.4055 - ACC_1: 0.4000 ]]
# [Epoch 16][TRAIN on 3658 [Loss: 0.6573 - ACC_T: 0.6099 - ACC_0: 0.4587 - ACC_1: 0.7611 ]][VAL on 331 [Loss: 0.6241 - ACC_T: 0.5680 - ACC_0: 0.4679 - ACC_1: 0.9697]]
#      .... Saving best weights ....
#       [TEST on 267 [Loss: 0.7110 - ACC_T: 0.4232 - ACC_0: 0.4240 - ACC_1: 0.4200 ]]
# [Epoch 17][TRAIN on 3658 [Loss: 0.6564 - ACC_T: 0.6074 - ACC_0: 0.4418 - ACC_1: 0.7731 ]][VAL on 331 [Loss: 0.6225 - ACC_T: 0.5650 - ACC_0: 0.4717 - ACC_1: 0.9394]]
#      .... Saving best weights ....
#       [TEST on 267 [Loss: 0.7112 - ACC_T: 0.4270 - ACC_0: 0.4332 - ACC_1: 0.4000 ]]
# [Epoch 18][TRAIN on 3658 [Loss: 0.6527 - ACC_T: 0.6167 - ACC_0: 0.4593 - ACC_1: 0.7742 ]][VAL on 331 [Loss: 0.6160 - ACC_T: 0.5650 - ACC_0: 0.4792 - ACC_1: 0.9091]]
#      .... Saving best weights ....
#       [TEST on 267 [Loss: 0.7119 - ACC_T: 0.4419 - ACC_0: 0.4516 - ACC_1: 0.4000 ]]
# [Epoch 19][TRAIN on 3658 [Loss: 0.6535 - ACC_T: 0.6074 - ACC_0: 0.4500 - ACC_1: 0.7649 ]][VAL on 331 [Loss: 0.6123 - ACC_T: 0.5710 - ACC_0: 0.4906 - ACC_1: 0.8939]]
#      .... Saving best weights ....
#       [TEST on 267 [Loss: 0.7117 - ACC_T: 0.4270 - ACC_0: 0.4470 - ACC_1: 0.3400 ]]
# [Epoch 20][TRAIN on 3658 [Loss: 0.6490 - ACC_T: 0.6145 - ACC_0: 0.4598 - ACC_1: 0.7693 ]][VAL on 331 [Loss: 0.6206 - ACC_T: 0.5498 - ACC_0: 0.4642 - ACC_1: 0.8939]]
# [Epoch 21][TRAIN on 3658 [Loss: 0.6495 - ACC_T: 0.6121 - ACC_0: 0.4702 - ACC_1: 0.7540 ]][VAL on 331 [Loss: 0.6198 - ACC_T: 0.5468 - ACC_0: 0.4604 - ACC_1: 0.8939]]
# [Epoch 22][TRAIN on 3658 [Loss: 0.6462 - ACC_T: 0.6200 - ACC_0: 0.4713 - ACC_1: 0.7687 ]][VAL on 331 [Loss: 0.6088 - ACC_T: 0.5801 - ACC_0: 0.5019 - ACC_1: 0.8939]]
#      .... Saving best weights ....
#       [TEST on 267 [Loss: 0.7260 - ACC_T: 0.4195 - ACC_0: 0.4332 - ACC_1: 0.3600 ]]
# [Epoch 23][TRAIN on 3658 [Loss: 0.6440 - ACC_T: 0.6268 - ACC_0: 0.4746 - ACC_1: 0.7791 ]][VAL on 331 [Loss: 0.6186 - ACC_T: 0.5559 - ACC_0: 0.4679 - ACC_1: 0.9091]]
# [Epoch 24][TRAIN on 3658 [Loss: 0.6425 - ACC_T: 0.6326 - ACC_0: 0.4954 - ACC_1: 0.7698 ]][VAL on 331 [Loss: 0.6077 - ACC_T: 0.5861 - ACC_0: 0.5057 - ACC_1: 0.9091]]
#      .... Saving best weights ....
#       [TEST on 267 [Loss: 0.7269 - ACC_T: 0.4419 - ACC_0: 0.4654 - ACC_1: 0.3400 ]]
# [Epoch 25][TRAIN on 3658 [Loss: 0.6406 - ACC_T: 0.6225 - ACC_0: 0.4790 - ACC_1: 0.7660 ]][VAL on 331 [Loss: 0.6099 - ACC_T: 0.5619 - ACC_0: 0.4792 - ACC_1: 0.8939]]
# [Epoch 26][TRAIN on 3658 [Loss: 0.6389 - ACC_T: 0.6359 - ACC_0: 0.5014 - ACC_1: 0.7704 ]][VAL on 331 [Loss: 0.6134 - ACC_T: 0.5710 - ACC_0: 0.4868 - ACC_1: 0.9091]]
# [Epoch 27][TRAIN on 3658 [Loss: 0.6393 - ACC_T: 0.6372 - ACC_0: 0.5101 - ACC_1: 0.7644 ]][VAL on 331 [Loss: 0.6170 - ACC_T: 0.5861 - ACC_0: 0.5094 - ACC_1: 0.8939]]
# [Epoch 28][TRAIN on 3658 [Loss: 0.6358 - ACC_T: 0.6337 - ACC_0: 0.5161 - ACC_1: 0.7512 ]][VAL on 331 [Loss: 0.6079 - ACC_T: 0.5952 - ACC_0: 0.5283 - ACC_1: 0.8636]]
# [Epoch 29][TRAIN on 3658 [Loss: 0.6377 - ACC_T: 0.6337 - ACC_0: 0.5200 - ACC_1: 0.7474 ]][VAL on 331 [Loss: 0.6105 - ACC_T: 0.5861 - ACC_0: 0.5170 - ACC_1: 0.8636]]
# [Epoch 30][TRAIN on 3658 [Loss: 0.6330 - ACC_T: 0.6381 - ACC_0: 0.5200 - ACC_1: 0.7562 ]][VAL on 331 [Loss: 0.6023 - ACC_T: 0.5952 - ACC_0: 0.5321 - ACC_1: 0.8485]]
#      .... Saving best weights ....
#       [TEST on 267 [Loss: 0.7388 - ACC_T: 0.4532 - ACC_0: 0.4793 - ACC_1: 0.3400 ]]
# [Epoch 31][TRAIN on 3658 [Loss: 0.6291 - ACC_T: 0.6471 - ACC_0: 0.5385 - ACC_1: 0.7556 ]][VAL on 331 [Loss: 0.6053 - ACC_T: 0.5921 - ACC_0: 0.5245 - ACC_1: 0.8636]]
# [Epoch 32][TRAIN on 3658 [Loss: 0.6318 - ACC_T: 0.6452 - ACC_0: 0.5303 - ACC_1: 0.7600 ]][VAL on 331 [Loss: 0.5979 - ACC_T: 0.6103 - ACC_0: 0.5434 - ACC_1: 0.8788]]
#      .... Saving best weights ....
#       [TEST on 267 [Loss: 0.7446 - ACC_T: 0.4569 - ACC_0: 0.4839 - ACC_1: 0.3400 ]]
# [Epoch 33][TRAIN on 3658 [Loss: 0.6300 - ACC_T: 0.6441 - ACC_0: 0.5462 - ACC_1: 0.7419 ]][VAL on 331 [Loss: 0.5994 - ACC_T: 0.5982 - ACC_0: 0.5283 - ACC_1: 0.8788]]
# [Epoch 34][TRAIN on 3658 [Loss: 0.6213 - ACC_T: 0.6591 - ACC_0: 0.5642 - ACC_1: 0.7540 ]][VAL on 331 [Loss: 0.5785 - ACC_T: 0.6405 - ACC_0: 0.5811 - ACC_1: 0.8788]]
#      .... Saving best weights ....
#       [TEST on 267 [Loss: 0.7386 - ACC_T: 0.4869 - ACC_0: 0.5253 - ACC_1: 0.3200 ]]
# [Epoch 35][TRAIN on 3658 [Loss: 0.6210 - ACC_T: 0.6610 - ACC_0: 0.5637 - ACC_1: 0.7583 ]][VAL on 331 [Loss: 0.5700 - ACC_T: 0.6526 - ACC_0: 0.6000 - ACC_1: 0.8636]]
#      .... Saving best weights ....
#       [TEST on 267 [Loss: 0.7433 - ACC_T: 0.4981 - ACC_0: 0.5392 - ACC_1: 0.3200 ]]
# [Epoch 36][TRAIN on 3658 [Loss: 0.6221 - ACC_T: 0.6536 - ACC_0: 0.5593 - ACC_1: 0.7479 ]][VAL on 331 [Loss: 0.5646 - ACC_T: 0.6586 - ACC_0: 0.6113 - ACC_1: 0.8485]]
#      .... Saving best weights ....
#       [TEST on 267 [Loss: 0.7385 - ACC_T: 0.5094 - ACC_0: 0.5622 - ACC_1: 0.2800 ]]
# [Epoch 37][TRAIN on 3658 [Loss: 0.6183 - ACC_T: 0.6687 - ACC_0: 0.5779 - ACC_1: 0.7594 ]][VAL on 331 [Loss: 0.5538 - ACC_T: 0.6677 - ACC_0: 0.6226 - ACC_1: 0.8485]]
#      .... Saving best weights ....
#       [TEST on 267 [Loss: 0.7379 - ACC_T: 0.5281 - ACC_0: 0.5899 - ACC_1: 0.2600 ]]
# [Epoch 38][TRAIN on 3658 [Loss: 0.6167 - ACC_T: 0.6588 - ACC_0: 0.5735 - ACC_1: 0.7441 ]][VAL on 331 [Loss: 0.5666 - ACC_T: 0.6586 - ACC_0: 0.6075 - ACC_1: 0.8636]]
# [Epoch 39][TRAIN on 3658 [Loss: 0.6171 - ACC_T: 0.6594 - ACC_0: 0.5746 - ACC_1: 0.7441 ]][VAL on 331 [Loss: 0.5697 - ACC_T: 0.6495 - ACC_0: 0.5962 - ACC_1: 0.8636]]
# [Epoch 40][TRAIN on 3658 [Loss: 0.6165 - ACC_T: 0.6572 - ACC_0: 0.5708 - ACC_1: 0.7436 ]][VAL on 331 [Loss: 0.5646 - ACC_T: 0.6616 - ACC_0: 0.6113 - ACC_1: 0.8636]]
# [Epoch 41][TRAIN on 3658 [Loss: 0.6112 - ACC_T: 0.6700 - ACC_0: 0.5970 - ACC_1: 0.7430 ]][VAL on 331 [Loss: 0.5387 - ACC_T: 0.6888 - ACC_0: 0.6566 - ACC_1: 0.8182]]
#      .... Saving best weights ....
#       [TEST on 267 [Loss: 0.7349 - ACC_T: 0.5431 - ACC_0: 0.6129 - ACC_1: 0.2400 ]]
# [Epoch 42][TRAIN on 3658 [Loss: 0.6090 - ACC_T: 0.6752 - ACC_0: 0.5861 - ACC_1: 0.7644 ]][VAL on 331 [Loss: 0.5587 - ACC_T: 0.6616 - ACC_0: 0.6075 - ACC_1: 0.8788]]
# [Epoch 43][TRAIN on 3658 [Loss: 0.6101 - ACC_T: 0.6654 - ACC_0: 0.5828 - ACC_1: 0.7479 ]][VAL on 331 [Loss: 0.5552 - ACC_T: 0.6616 - ACC_0: 0.6113 - ACC_1: 0.8636]]
# [Epoch 44][TRAIN on 3658 [Loss: 0.6079 - ACC_T: 0.6733 - ACC_0: 0.5998 - ACC_1: 0.7469 ]][VAL on 331 [Loss: 0.5374 - ACC_T: 0.6737 - ACC_0: 0.6302 - ACC_1: 0.8485]]
#      .... Saving best weights ....
#       [TEST on 267 [Loss: 0.7420 - ACC_T: 0.5356 - ACC_0: 0.5991 - ACC_1: 0.2600 ]]
# [Epoch 45][TRAIN on 3658 [Loss: 0.6077 - ACC_T: 0.6668 - ACC_0: 0.5867 - ACC_1: 0.7469 ]][VAL on 331 [Loss: 0.5458 - ACC_T: 0.6647 - ACC_0: 0.6189 - ACC_1: 0.8485]]
# [Epoch 46][TRAIN on 3658 [Loss: 0.6087 - ACC_T: 0.6668 - ACC_0: 0.5932 - ACC_1: 0.7403 ]][VAL on 331 [Loss: 0.5444 - ACC_T: 0.6707 - ACC_0: 0.6302 - ACC_1: 0.8333]]
# [Epoch 47][TRAIN on 3658 [Loss: 0.6057 - ACC_T: 0.6747 - ACC_0: 0.5949 - ACC_1: 0.7545 ]][VAL on 331 [Loss: 0.5465 - ACC_T: 0.6707 - ACC_0: 0.6264 - ACC_1: 0.8485]]
# [Epoch 48][TRAIN on 3658 [Loss: 0.6035 - ACC_T: 0.6796 - ACC_0: 0.6178 - ACC_1: 0.7414 ]][VAL on 331 [Loss: 0.5522 - ACC_T: 0.6647 - ACC_0: 0.6151 - ACC_1: 0.8636]]
# [Epoch 49][TRAIN on 3658 [Loss: 0.6006 - ACC_T: 0.6717 - ACC_0: 0.6003 - ACC_1: 0.7430 ]][VAL on 331 [Loss: 0.5535 - ACC_T: 0.6647 - ACC_0: 0.6151 - ACC_1: 0.8636]]
# [Epoch 50][TRAIN on 3658 [Loss: 0.6020 - ACC_T: 0.6755 - ACC_0: 0.6014 - ACC_1: 0.7496 ]][VAL on 331 [Loss: 0.5342 - ACC_T: 0.6828 - ACC_0: 0.6377 - ACC_1: 0.8636]]
#      .... Saving best weights ....
#       [TEST on 267 [Loss: 0.7391 - ACC_T: 0.5356 - ACC_0: 0.5991 - ACC_1: 0.2600 ]]
# [Epoch 51][TRAIN on 3658 [Loss: 0.5996 - ACC_T: 0.6747 - ACC_0: 0.6020 - ACC_1: 0.7474 ]][VAL on 331 [Loss: 0.5438 - ACC_T: 0.6798 - ACC_0: 0.6340 - ACC_1: 0.8636]]
# [Epoch 52][TRAIN on 3658 [Loss: 0.5988 - ACC_T: 0.6821 - ACC_0: 0.6145 - ACC_1: 0.7496 ]][VAL on 331 [Loss: 0.5412 - ACC_T: 0.6707 - ACC_0: 0.6226 - ACC_1: 0.8636]]
# [Epoch 53][TRAIN on 3658 [Loss: 0.5999 - ACC_T: 0.6763 - ACC_0: 0.6167 - ACC_1: 0.7359 ]][VAL on 331 [Loss: 0.5370 - ACC_T: 0.6767 - ACC_0: 0.6377 - ACC_1: 0.8333]]
# [Epoch 54][TRAIN on 3658 [Loss: 0.5947 - ACC_T: 0.6807 - ACC_0: 0.6233 - ACC_1: 0.7381 ]][VAL on 331 [Loss: 0.5322 - ACC_T: 0.6737 - ACC_0: 0.6340 - ACC_1: 0.8333]]
#      .... Saving best weights ....
#       [TEST on 267 [Loss: 0.7440 - ACC_T: 0.5356 - ACC_0: 0.5991 - ACC_1: 0.2600 ]]
# [Epoch 55][TRAIN on 3658 [Loss: 0.5921 - ACC_T: 0.6897 - ACC_0: 0.6277 - ACC_1: 0.7518 ]][VAL on 331 [Loss: 0.5316 - ACC_T: 0.6767 - ACC_0: 0.6377 - ACC_1: 0.8333]]
#      .... Saving best weights ....
#       [TEST on 267 [Loss: 0.7465 - ACC_T: 0.5356 - ACC_0: 0.5991 - ACC_1: 0.2600 ]]
# [Epoch 56][TRAIN on 3658 [Loss: 0.5935 - ACC_T: 0.6777 - ACC_0: 0.6036 - ACC_1: 0.7518 ]][VAL on 331 [Loss: 0.5492 - ACC_T: 0.6647 - ACC_0: 0.6226 - ACC_1: 0.8333]]
# [Epoch 57][TRAIN on 3658 [Loss: 0.5927 - ACC_T: 0.6821 - ACC_0: 0.6337 - ACC_1: 0.7305 ]][VAL on 331 [Loss: 0.5344 - ACC_T: 0.6737 - ACC_0: 0.6340 - ACC_1: 0.8333]]
# [Epoch 58][TRAIN on 3658 [Loss: 0.5872 - ACC_T: 0.6897 - ACC_0: 0.6391 - ACC_1: 0.7403 ]][VAL on 331 [Loss: 0.5520 - ACC_T: 0.6526 - ACC_0: 0.5962 - ACC_1: 0.8788]]
# [Epoch 59][TRAIN on 3658 [Loss: 0.5872 - ACC_T: 0.6821 - ACC_0: 0.6255 - ACC_1: 0.7387 ]][VAL on 331 [Loss: 0.5223 - ACC_T: 0.6858 - ACC_0: 0.6453 - ACC_1: 0.8485]]
#      .... Saving best weights ....
#       [TEST on 267 [Loss: 0.7406 - ACC_T: 0.5468 - ACC_0: 0.6129 - ACC_1: 0.2600 ]]
# [Epoch 60][TRAIN on 3658 [Loss: 0.5842 - ACC_T: 0.6864 - ACC_0: 0.6326 - ACC_1: 0.7403 ]][VAL on 331 [Loss: 0.5287 - ACC_T: 0.6798 - ACC_0: 0.6377 - ACC_1: 0.8485]]
# [Epoch 61][TRAIN on 3658 [Loss: 0.5843 - ACC_T: 0.6903 - ACC_0: 0.6320 - ACC_1: 0.7485 ]][VAL on 331 [Loss: 0.5283 - ACC_T: 0.6798 - ACC_0: 0.6377 - ACC_1: 0.8485]]
# [Epoch 62][TRAIN on 3658 [Loss: 0.5818 - ACC_T: 0.6930 - ACC_0: 0.6402 - ACC_1: 0.7458 ]][VAL on 331 [Loss: 0.5276 - ACC_T: 0.6767 - ACC_0: 0.6377 - ACC_1: 0.8333]]
# [Epoch 63][TRAIN on 3658 [Loss: 0.5839 - ACC_T: 0.6935 - ACC_0: 0.6402 - ACC_1: 0.7469 ]][VAL on 331 [Loss: 0.5230 - ACC_T: 0.6798 - ACC_0: 0.6415 - ACC_1: 0.8333]]
# [Epoch 64][TRAIN on 3658 [Loss: 0.5848 - ACC_T: 0.6870 - ACC_0: 0.6413 - ACC_1: 0.7326 ]][VAL on 331 [Loss: 0.5322 - ACC_T: 0.6677 - ACC_0: 0.6189 - ACC_1: 0.8636]]
# [Epoch 65][TRAIN on 3658 [Loss: 0.5782 - ACC_T: 0.6976 - ACC_0: 0.6501 - ACC_1: 0.7452 ]][VAL on 331 [Loss: 0.5136 - ACC_T: 0.6858 - ACC_0: 0.6528 - ACC_1: 0.8182]]
#      .... Saving best weights ....
#       [TEST on 267 [Loss: 0.7400 - ACC_T: 0.5468 - ACC_0: 0.6221 - ACC_1: 0.2200 ]]
# [Epoch 66][TRAIN on 3658 [Loss: 0.5766 - ACC_T: 0.6919 - ACC_0: 0.6391 - ACC_1: 0.7447 ]][VAL on 331 [Loss: 0.5363 - ACC_T: 0.6707 - ACC_0: 0.6226 - ACC_1: 0.8636]]
# [Epoch 67][TRAIN on 3658 [Loss: 0.5781 - ACC_T: 0.6941 - ACC_0: 0.6484 - ACC_1: 0.7397 ]][VAL on 331 [Loss: 0.5193 - ACC_T: 0.6737 - ACC_0: 0.6340 - ACC_1: 0.8333]]
# [Epoch 68][TRAIN on 3658 [Loss: 0.5759 - ACC_T: 0.6952 - ACC_0: 0.6468 - ACC_1: 0.7436 ]][VAL on 331 [Loss: 0.5374 - ACC_T: 0.6647 - ACC_0: 0.6151 - ACC_1: 0.8636]]
# [Epoch 69][TRAIN on 3658 [Loss: 0.5766 - ACC_T: 0.6925 - ACC_0: 0.6408 - ACC_1: 0.7441 ]][VAL on 331 [Loss: 0.5346 - ACC_T: 0.6586 - ACC_0: 0.6151 - ACC_1: 0.8333]]
# [Epoch 70][TRAIN on 3658 [Loss: 0.5715 - ACC_T: 0.7023 - ACC_0: 0.6457 - ACC_1: 0.7589 ]][VAL on 331 [Loss: 0.5209 - ACC_T: 0.6737 - ACC_0: 0.6340 - ACC_1: 0.8333]]
# [Epoch 71][TRAIN on 3658 [Loss: 0.5711 - ACC_T: 0.6990 - ACC_0: 0.6468 - ACC_1: 0.7512 ]][VAL on 331 [Loss: 0.5133 - ACC_T: 0.6949 - ACC_0: 0.6604 - ACC_1: 0.8333]]
#      .... Saving best weights ....
#       [TEST on 267 [Loss: 0.7541 - ACC_T: 0.5581 - ACC_0: 0.6406 - ACC_1: 0.2000 ]]
# [Epoch 72][TRAIN on 3658 [Loss: 0.5692 - ACC_T: 0.7009 - ACC_0: 0.6583 - ACC_1: 0.7436 ]][VAL on 331 [Loss: 0.5234 - ACC_T: 0.6737 - ACC_0: 0.6302 - ACC_1: 0.8485]]
# [Epoch 73][TRAIN on 3658 [Loss: 0.5727 - ACC_T: 0.6985 - ACC_0: 0.6495 - ACC_1: 0.7474 ]][VAL on 331 [Loss: 0.5289 - ACC_T: 0.6737 - ACC_0: 0.6302 - ACC_1: 0.8485]]
# [Epoch 74][TRAIN on 3658 [Loss: 0.5676 - ACC_T: 0.7059 - ACC_0: 0.6687 - ACC_1: 0.7430 ]][VAL on 331 [Loss: 0.5284 - ACC_T: 0.6647 - ACC_0: 0.6189 - ACC_1: 0.8485]]
# [Epoch 75][TRAIN on 3658 [Loss: 0.5699 - ACC_T: 0.7009 - ACC_0: 0.6583 - ACC_1: 0.7436 ]][VAL on 331 [Loss: 0.5183 - ACC_T: 0.6737 - ACC_0: 0.6302 - ACC_1: 0.8485]]
# [Epoch 76][TRAIN on 3658 [Loss: 0.5720 - ACC_T: 0.6976 - ACC_0: 0.6577 - ACC_1: 0.7376 ]][VAL on 331 [Loss: 0.5254 - ACC_T: 0.6737 - ACC_0: 0.6302 - ACC_1: 0.8485]]
# [Epoch 77][TRAIN on 3658 [Loss: 0.5659 - ACC_T: 0.7048 - ACC_0: 0.6616 - ACC_1: 0.7479 ]][VAL on 331 [Loss: 0.5103 - ACC_T: 0.6888 - ACC_0: 0.6491 - ACC_1: 0.8485]]
#      .... Saving best weights ....
#       [TEST on 267 [Loss: 0.7804 - ACC_T: 0.5543 - ACC_0: 0.6359 - ACC_1: 0.2000 ]]
# [Epoch 78][TRAIN on 3658 [Loss: 0.5613 - ACC_T: 0.7154 - ACC_0: 0.6643 - ACC_1: 0.7665 ]][VAL on 331 [Loss: 0.5221 - ACC_T: 0.6888 - ACC_0: 0.6491 - ACC_1: 0.8485]]
# [Epoch 79][TRAIN on 3658 [Loss: 0.5627 - ACC_T: 0.7091 - ACC_0: 0.6725 - ACC_1: 0.7458 ]][VAL on 331 [Loss: 0.5304 - ACC_T: 0.6767 - ACC_0: 0.6340 - ACC_1: 0.8485]]
# [Epoch 80][TRAIN on 3658 [Loss: 0.5639 - ACC_T: 0.6998 - ACC_0: 0.6599 - ACC_1: 0.7397 ]][VAL on 331 [Loss: 0.5158 - ACC_T: 0.7009 - ACC_0: 0.6642 - ACC_1: 0.8485]]
# [Epoch 81][TRAIN on 3658 [Loss: 0.5608 - ACC_T: 0.7072 - ACC_0: 0.6610 - ACC_1: 0.7534 ]][VAL on 331 [Loss: 0.5227 - ACC_T: 0.6888 - ACC_0: 0.6491 - ACC_1: 0.8485]]
# [Epoch 82][TRAIN on 3658 [Loss: 0.5595 - ACC_T: 0.7105 - ACC_0: 0.6741 - ACC_1: 0.7469 ]][VAL on 331 [Loss: 0.5174 - ACC_T: 0.6918 - ACC_0: 0.6528 - ACC_1: 0.8485]]
# [Epoch 83][TRAIN on 3658 [Loss: 0.5612 - ACC_T: 0.7056 - ACC_0: 0.6659 - ACC_1: 0.7452 ]][VAL on 331 [Loss: 0.5090 - ACC_T: 0.7009 - ACC_0: 0.6679 - ACC_1: 0.8333]]
#      .... Saving best weights ....
#       [TEST on 267 [Loss: 0.7926 - ACC_T: 0.5543 - ACC_0: 0.6452 - ACC_1: 0.1600 ]]
# [Epoch 84][TRAIN on 3658 [Loss: 0.5568 - ACC_T: 0.7143 - ACC_0: 0.6730 - ACC_1: 0.7556 ]][VAL on 331 [Loss: 0.5007 - ACC_T: 0.7100 - ACC_0: 0.6830 - ACC_1: 0.8182]]
#      .... Saving best weights ....
#       [TEST on 267 [Loss: 0.7896 - ACC_T: 0.5543 - ACC_0: 0.6452 - ACC_1: 0.1600 ]]
# [Epoch 85][TRAIN on 3658 [Loss: 0.5575 - ACC_T: 0.7086 - ACC_0: 0.6616 - ACC_1: 0.7556 ]][VAL on 331 [Loss: 0.5151 - ACC_T: 0.6888 - ACC_0: 0.6528 - ACC_1: 0.8333]]
# [Epoch 86][TRAIN on 3658 [Loss: 0.5530 - ACC_T: 0.7108 - ACC_0: 0.6692 - ACC_1: 0.7523 ]][VAL on 331 [Loss: 0.5091 - ACC_T: 0.7100 - ACC_0: 0.6792 - ACC_1: 0.8333]]
# [Epoch 87][TRAIN on 3658 [Loss: 0.5519 - ACC_T: 0.7162 - ACC_0: 0.6730 - ACC_1: 0.7594 ]][VAL on 331 [Loss: 0.5269 - ACC_T: 0.6798 - ACC_0: 0.6377 - ACC_1: 0.8485]]
# [Epoch 88][TRAIN on 3658 [Loss: 0.5525 - ACC_T: 0.7173 - ACC_0: 0.6758 - ACC_1: 0.7589 ]][VAL on 331 [Loss: 0.5016 - ACC_T: 0.7100 - ACC_0: 0.6792 - ACC_1: 0.8333]]
# [Epoch 89][TRAIN on 3658 [Loss: 0.5560 - ACC_T: 0.7064 - ACC_0: 0.6791 - ACC_1: 0.7337 ]][VAL on 331 [Loss: 0.5113 - ACC_T: 0.7009 - ACC_0: 0.6642 - ACC_1: 0.8485]]
# [Epoch 90][TRAIN on 3658 [Loss: 0.5523 - ACC_T: 0.7078 - ACC_0: 0.6720 - ACC_1: 0.7436 ]][VAL on 331 [Loss: 0.5177 - ACC_T: 0.6979 - ACC_0: 0.6604 - ACC_1: 0.8485]]
# [Epoch 91][TRAIN on 3658 [Loss: 0.5473 - ACC_T: 0.7141 - ACC_0: 0.6818 - ACC_1: 0.7463 ]][VAL on 331 [Loss: 0.5191 - ACC_T: 0.7039 - ACC_0: 0.6679 - ACC_1: 0.8485]]
# [Epoch 92][TRAIN on 3658 [Loss: 0.5502 - ACC_T: 0.7179 - ACC_0: 0.6818 - ACC_1: 0.7540 ]][VAL on 331 [Loss: 0.5227 - ACC_T: 0.6918 - ACC_0: 0.6528 - ACC_1: 0.8485]]
# [Epoch 93][TRAIN on 3658 [Loss: 0.5468 - ACC_T: 0.7141 - ACC_0: 0.6791 - ACC_1: 0.7490 ]][VAL on 331 [Loss: 0.5035 - ACC_T: 0.7100 - ACC_0: 0.6755 - ACC_1: 0.8485]]
# [Epoch 94][TRAIN on 3658 [Loss: 0.5461 - ACC_T: 0.7195 - ACC_0: 0.6944 - ACC_1: 0.7447 ]][VAL on 331 [Loss: 0.5193 - ACC_T: 0.7009 - ACC_0: 0.6642 - ACC_1: 0.8485]]
# [Epoch 95][TRAIN on 3658 [Loss: 0.5403 - ACC_T: 0.7228 - ACC_0: 0.6894 - ACC_1: 0.7562 ]][VAL on 331 [Loss: 0.5284 - ACC_T: 0.6798 - ACC_0: 0.6377 - ACC_1: 0.8485]]
# [Epoch 96][TRAIN on 3658 [Loss: 0.5507 - ACC_T: 0.7080 - ACC_0: 0.6752 - ACC_1: 0.7408 ]][VAL on 331 [Loss: 0.5148 - ACC_T: 0.6949 - ACC_0: 0.6566 - ACC_1: 0.8485]]
# [Epoch 97][TRAIN on 3658 [Loss: 0.5474 - ACC_T: 0.7141 - ACC_0: 0.6796 - ACC_1: 0.7485 ]][VAL on 331 [Loss: 0.5059 - ACC_T: 0.7009 - ACC_0: 0.6679 - ACC_1: 0.8333]]
# [Epoch 98][TRAIN on 3658 [Loss: 0.5433 - ACC_T: 0.7176 - ACC_0: 0.6834 - ACC_1: 0.7518 ]][VAL on 331 [Loss: 0.5283 - ACC_T: 0.6888 - ACC_0: 0.6491 - ACC_1: 0.8485]]
# [Epoch 99][TRAIN on 3658 [Loss: 0.5455 - ACC_T: 0.7192 - ACC_0: 0.6900 - ACC_1: 0.7485 ]][VAL on 331 [Loss: 0.5288 - ACC_T: 0.6888 - ACC_0: 0.6528 - ACC_1: 0.8333]]
# [Epoch 100][TRAIN on 3658 [Loss: 0.5417 - ACC_T: 0.7176 - ACC_0: 0.6998 - ACC_1: 0.7354 ]][VAL on 331 [Loss: 0.5308 - ACC_T: 0.6798 - ACC_0: 0.6377 - ACC_1: 0.8485]]
# [Epoch 101][TRAIN on 3658 [Loss: 0.5445 - ACC_T: 0.7138 - ACC_0: 0.6802 - ACC_1: 0.7474 ]][VAL on 331 [Loss: 0.5351 - ACC_T: 0.6767 - ACC_0: 0.6302 - ACC_1: 0.8636]]
# [Epoch 102][TRAIN on 3658 [Loss: 0.5398 - ACC_T: 0.7233 - ACC_0: 0.6955 - ACC_1: 0.7512 ]][VAL on 331 [Loss: 0.5166 - ACC_T: 0.6918 - ACC_0: 0.6566 - ACC_1: 0.8333]]
# [Epoch 103][TRAIN on 3658 [Loss: 0.5402 - ACC_T: 0.7206 - ACC_0: 0.6960 - ACC_1: 0.7452 ]][VAL on 331 [Loss: 0.5118 - ACC_T: 0.6949 - ACC_0: 0.6604 - ACC_1: 0.8333]]
# [Epoch 104][TRAIN on 3658 [Loss: 0.5410 - ACC_T: 0.7242 - ACC_0: 0.7004 - ACC_1: 0.7479 ]][VAL on 331 [Loss: 0.4932 - ACC_T: 0.7100 - ACC_0: 0.6830 - ACC_1: 0.8182]]
#      .... Saving best weights ....
#       [TEST on 267 [Loss: 0.8597 - ACC_T: 0.5581 - ACC_0: 0.6498 - ACC_1: 0.1600 ]]
# [Epoch 105][TRAIN on 3658 [Loss: 0.5365 - ACC_T: 0.7288 - ACC_0: 0.7020 - ACC_1: 0.7556 ]][VAL on 331 [Loss: 0.5111 - ACC_T: 0.7039 - ACC_0: 0.6755 - ACC_1: 0.8182]]
# [Epoch 106][TRAIN on 3658 [Loss: 0.5337 - ACC_T: 0.7198 - ACC_0: 0.6851 - ACC_1: 0.7545 ]][VAL on 331 [Loss: 0.5297 - ACC_T: 0.6888 - ACC_0: 0.6566 - ACC_1: 0.8182]]
# [Epoch 107][TRAIN on 3658 [Loss: 0.5312 - ACC_T: 0.7294 - ACC_0: 0.7113 - ACC_1: 0.7474 ]][VAL on 331 [Loss: 0.5243 - ACC_T: 0.6828 - ACC_0: 0.6453 - ACC_1: 0.8333]]
# [Epoch 108][TRAIN on 3658 [Loss: 0.5300 - ACC_T: 0.7389 - ACC_0: 0.7173 - ACC_1: 0.7605 ]][VAL on 331 [Loss: 0.5218 - ACC_T: 0.6767 - ACC_0: 0.6415 - ACC_1: 0.8182]]
# [Epoch 109][TRAIN on 3658 [Loss: 0.5328 - ACC_T: 0.7277 - ACC_0: 0.7031 - ACC_1: 0.7523 ]][VAL on 331 [Loss: 0.5175 - ACC_T: 0.6798 - ACC_0: 0.6453 - ACC_1: 0.8182]]
# [Epoch 110][TRAIN on 3658 [Loss: 0.5288 - ACC_T: 0.7296 - ACC_0: 0.6971 - ACC_1: 0.7622 ]][VAL on 331 [Loss: 0.5349 - ACC_T: 0.6677 - ACC_0: 0.6226 - ACC_1: 0.8485]]
# [Epoch 111][TRAIN on 3658 [Loss: 0.5231 - ACC_T: 0.7389 - ACC_0: 0.7108 - ACC_1: 0.7671 ]][VAL on 331 [Loss: 0.5381 - ACC_T: 0.6798 - ACC_0: 0.6377 - ACC_1: 0.8485]]
# [Epoch 112][TRAIN on 3658 [Loss: 0.5251 - ACC_T: 0.7356 - ACC_0: 0.7059 - ACC_1: 0.7654 ]][VAL on 331 [Loss: 0.5116 - ACC_T: 0.7069 - ACC_0: 0.6792 - ACC_1: 0.8182]]
# [Epoch 113][TRAIN on 3658 [Loss: 0.5283 - ACC_T: 0.7244 - ACC_0: 0.7091 - ACC_1: 0.7397 ]][VAL on 331 [Loss: 0.4974 - ACC_T: 0.7221 - ACC_0: 0.6981 - ACC_1: 0.8182]]
# [Epoch 114][TRAIN on 3658 [Loss: 0.5332 - ACC_T: 0.7228 - ACC_0: 0.6960 - ACC_1: 0.7496 ]][VAL on 331 [Loss: 0.5081 - ACC_T: 0.7039 - ACC_0: 0.6755 - ACC_1: 0.8182]]
# [Epoch 115][TRAIN on 3658 [Loss: 0.5239 - ACC_T: 0.7315 - ACC_0: 0.7069 - ACC_1: 0.7562 ]][VAL on 331 [Loss: 0.5151 - ACC_T: 0.6888 - ACC_0: 0.6604 - ACC_1: 0.8030]]
# [Epoch 116][TRAIN on 3658 [Loss: 0.5234 - ACC_T: 0.7395 - ACC_0: 0.7233 - ACC_1: 0.7556 ]][VAL on 331 [Loss: 0.5025 - ACC_T: 0.7160 - ACC_0: 0.6943 - ACC_1: 0.8030]]
# [Epoch 117][TRAIN on 3658 [Loss: 0.5269 - ACC_T: 0.7294 - ACC_0: 0.6987 - ACC_1: 0.7600 ]][VAL on 331 [Loss: 0.5100 - ACC_T: 0.7130 - ACC_0: 0.6906 - ACC_1: 0.8030]]
# [Epoch 118][TRAIN on 3658 [Loss: 0.5193 - ACC_T: 0.7318 - ACC_0: 0.7069 - ACC_1: 0.7567 ]][VAL on 331 [Loss: 0.5089 - ACC_T: 0.7160 - ACC_0: 0.6906 - ACC_1: 0.8182]]
# [Epoch 119][TRAIN on 3658 [Loss: 0.5268 - ACC_T: 0.7315 - ACC_0: 0.7162 - ACC_1: 0.7469 ]][VAL on 331 [Loss: 0.5469 - ACC_T: 0.6677 - ACC_0: 0.6264 - ACC_1: 0.8333]]
# [Epoch 120][TRAIN on 3658 [Loss: 0.5189 - ACC_T: 0.7392 - ACC_0: 0.7272 - ACC_1: 0.7512 ]][VAL on 331 [Loss: 0.5082 - ACC_T: 0.7069 - ACC_0: 0.6792 - ACC_1: 0.8182]]
# [Epoch 121][TRAIN on 3658 [Loss: 0.5229 - ACC_T: 0.7258 - ACC_0: 0.6987 - ACC_1: 0.7529 ]][VAL on 331 [Loss: 0.5328 - ACC_T: 0.6798 - ACC_0: 0.6377 - ACC_1: 0.8485]]
# [Epoch 122][TRAIN on 3658 [Loss: 0.5175 - ACC_T: 0.7425 - ACC_0: 0.7157 - ACC_1: 0.7693 ]][VAL on 331 [Loss: 0.5316 - ACC_T: 0.6707 - ACC_0: 0.6264 - ACC_1: 0.8485]]
# [Epoch 123][TRAIN on 3658 [Loss: 0.5230 - ACC_T: 0.7346 - ACC_0: 0.7294 - ACC_1: 0.7397 ]][VAL on 331 [Loss: 0.5060 - ACC_T: 0.7069 - ACC_0: 0.6792 - ACC_1: 0.8182]]
# [Epoch 124][TRAIN on 3658 [Loss: 0.5237 - ACC_T: 0.7384 - ACC_0: 0.7201 - ACC_1: 0.7567 ]][VAL on 331 [Loss: 0.5166 - ACC_T: 0.7069 - ACC_0: 0.6755 - ACC_1: 0.8333]]
# [Epoch 125][TRAIN on 3658 [Loss: 0.5166 - ACC_T: 0.7381 - ACC_0: 0.7113 - ACC_1: 0.7649 ]][VAL on 331 [Loss: 0.5170 - ACC_T: 0.7009 - ACC_0: 0.6717 - ACC_1: 0.8182]]
# [Epoch 126][TRAIN on 3658 [Loss: 0.5127 - ACC_T: 0.7381 - ACC_0: 0.7086 - ACC_1: 0.7676 ]][VAL on 331 [Loss: 0.5224 - ACC_T: 0.7009 - ACC_0: 0.6717 - ACC_1: 0.8182]]
# [Epoch 127][TRAIN on 3658 [Loss: 0.5224 - ACC_T: 0.7332 - ACC_0: 0.7239 - ACC_1: 0.7425 ]][VAL on 331 [Loss: 0.5258 - ACC_T: 0.7009 - ACC_0: 0.6717 - ACC_1: 0.8182]]
# [Epoch 128][TRAIN on 3658 [Loss: 0.5130 - ACC_T: 0.7384 - ACC_0: 0.7179 - ACC_1: 0.7589 ]][VAL on 331 [Loss: 0.5240 - ACC_T: 0.6979 - ACC_0: 0.6642 - ACC_1: 0.8333]]
# [Epoch 129][TRAIN on 3658 [Loss: 0.5149 - ACC_T: 0.7395 - ACC_0: 0.7091 - ACC_1: 0.7698 ]][VAL on 331 [Loss: 0.5114 - ACC_T: 0.7069 - ACC_0: 0.6830 - ACC_1: 0.8030]]
# [Epoch 130][TRAIN on 3658 [Loss: 0.5138 - ACC_T: 0.7370 - ACC_0: 0.7037 - ACC_1: 0.7704 ]][VAL on 331 [Loss: 0.5428 - ACC_T: 0.6858 - ACC_0: 0.6491 - ACC_1: 0.8333]]
# [Epoch 131][TRAIN on 3658 [Loss: 0.5163 - ACC_T: 0.7384 - ACC_0: 0.7173 - ACC_1: 0.7594 ]][VAL on 331 [Loss: 0.5271 - ACC_T: 0.6918 - ACC_0: 0.6566 - ACC_1: 0.8333]]
# [Epoch 132][TRAIN on 3658 [Loss: 0.5105 - ACC_T: 0.7359 - ACC_0: 0.7217 - ACC_1: 0.7501 ]][VAL on 331 [Loss: 0.5549 - ACC_T: 0.6586 - ACC_0: 0.6113 - ACC_1: 0.8485]]
# [Epoch 133][TRAIN on 3658 [Loss: 0.5107 - ACC_T: 0.7444 - ACC_0: 0.7157 - ACC_1: 0.7731 ]][VAL on 331 [Loss: 0.5367 - ACC_T: 0.6949 - ACC_0: 0.6604 - ACC_1: 0.8333]]
# [Epoch 134][TRAIN on 3658 [Loss: 0.5082 - ACC_T: 0.7460 - ACC_0: 0.7244 - ACC_1: 0.7676 ]][VAL on 331 [Loss: 0.5391 - ACC_T: 0.6918 - ACC_0: 0.6566 - ACC_1: 0.8333]]
# [Epoch 135][TRAIN on 3658 [Loss: 0.5113 - ACC_T: 0.7444 - ACC_0: 0.7321 - ACC_1: 0.7567 ]][VAL on 331 [Loss: 0.5018 - ACC_T: 0.7221 - ACC_0: 0.6981 - ACC_1: 0.8182]]
# [Epoch 136][TRAIN on 3658 [Loss: 0.5071 - ACC_T: 0.7422 - ACC_0: 0.7255 - ACC_1: 0.7589 ]][VAL on 331 [Loss: 0.5243 - ACC_T: 0.6979 - ACC_0: 0.6642 - ACC_1: 0.8333]]
# [Epoch 137][TRAIN on 3658 [Loss: 0.5113 - ACC_T: 0.7474 - ACC_0: 0.7233 - ACC_1: 0.7715 ]][VAL on 331 [Loss: 0.5239 - ACC_T: 0.7039 - ACC_0: 0.6717 - ACC_1: 0.8333]]
# [Epoch 138][TRAIN on 3658 [Loss: 0.5030 - ACC_T: 0.7455 - ACC_0: 0.7201 - ACC_1: 0.7709 ]][VAL on 331 [Loss: 0.5014 - ACC_T: 0.7190 - ACC_0: 0.7057 - ACC_1: 0.7727]]
# [Epoch 139][TRAIN on 3658 [Loss: 0.5003 - ACC_T: 0.7493 - ACC_0: 0.7387 - ACC_1: 0.7600 ]][VAL on 331 [Loss: 0.5223 - ACC_T: 0.6949 - ACC_0: 0.6642 - ACC_1: 0.8182]]
# [Epoch 140][TRAIN on 3658 [Loss: 0.5075 - ACC_T: 0.7400 - ACC_0: 0.7288 - ACC_1: 0.7512 ]][VAL on 331 [Loss: 0.5235 - ACC_T: 0.6979 - ACC_0: 0.6642 - ACC_1: 0.8333]]
# [Epoch 141][TRAIN on 3658 [Loss: 0.5013 - ACC_T: 0.7419 - ACC_0: 0.7294 - ACC_1: 0.7545 ]][VAL on 331 [Loss: 0.5125 - ACC_T: 0.7009 - ACC_0: 0.6717 - ACC_1: 0.8182]]
# [Epoch 142][TRAIN on 3658 [Loss: 0.5050 - ACC_T: 0.7425 - ACC_0: 0.7272 - ACC_1: 0.7578 ]][VAL on 331 [Loss: 0.5250 - ACC_T: 0.6888 - ACC_0: 0.6528 - ACC_1: 0.8333]]
# [Epoch 143][TRAIN on 3658 [Loss: 0.5053 - ACC_T: 0.7422 - ACC_0: 0.7233 - ACC_1: 0.7611 ]][VAL on 331 [Loss: 0.5082 - ACC_T: 0.7100 - ACC_0: 0.6868 - ACC_1: 0.8030]]
# [Epoch 144][TRAIN on 3658 [Loss: 0.5053 - ACC_T: 0.7403 - ACC_0: 0.7212 - ACC_1: 0.7594 ]][VAL on 331 [Loss: 0.5454 - ACC_T: 0.6737 - ACC_0: 0.6340 - ACC_1: 0.8333]]
# [Epoch 145][TRAIN on 3658 [Loss: 0.5019 - ACC_T: 0.7411 - ACC_0: 0.7233 - ACC_1: 0.7589 ]][VAL on 331 [Loss: 0.5369 - ACC_T: 0.6888 - ACC_0: 0.6528 - ACC_1: 0.8333]]
# [Epoch 146][TRAIN on 3658 [Loss: 0.5057 - ACC_T: 0.7406 - ACC_0: 0.7272 - ACC_1: 0.7540 ]][VAL on 331 [Loss: 0.5469 - ACC_T: 0.6888 - ACC_0: 0.6528 - ACC_1: 0.8333]]
# [Epoch 147][TRAIN on 3658 [Loss: 0.5016 - ACC_T: 0.7485 - ACC_0: 0.7376 - ACC_1: 0.7594 ]][VAL on 331 [Loss: 0.5171 - ACC_T: 0.7130 - ACC_0: 0.6868 - ACC_1: 0.8182]]
# [Epoch 148][TRAIN on 3658 [Loss: 0.4980 - ACC_T: 0.7512 - ACC_0: 0.7288 - ACC_1: 0.7736 ]][VAL on 331 [Loss: 0.5275 - ACC_T: 0.7039 - ACC_0: 0.6755 - ACC_1: 0.8182]]
# [Epoch 149][TRAIN on 3658 [Loss: 0.5079 - ACC_T: 0.7376 - ACC_0: 0.7173 - ACC_1: 0.7578 ]][VAL on 331 [Loss: 0.5344 - ACC_T: 0.6949 - ACC_0: 0.6604 - ACC_1: 0.8333]]
# [Epoch 150][TRAIN on 3658 [Loss: 0.4896 - ACC_T: 0.7559 - ACC_0: 0.7365 - ACC_1: 0.7753 ]][VAL on 331 [Loss: 0.5053 - ACC_T: 0.7251 - ACC_0: 0.7057 - ACC_1: 0.8030]]
# [Epoch 151][TRAIN on 3658 [Loss: 0.4953 - ACC_T: 0.7488 - ACC_0: 0.7294 - ACC_1: 0.7682 ]][VAL on 331 [Loss: 0.5152 - ACC_T: 0.7160 - ACC_0: 0.6868 - ACC_1: 0.8333]]
# [Epoch 152][TRAIN on 3658 [Loss: 0.4948 - ACC_T: 0.7512 - ACC_0: 0.7299 - ACC_1: 0.7726 ]][VAL on 331 [Loss: 0.5304 - ACC_T: 0.6918 - ACC_0: 0.6566 - ACC_1: 0.8333]]
# [Epoch 153][TRAIN on 3658 [Loss: 0.4957 - ACC_T: 0.7534 - ACC_0: 0.7463 - ACC_1: 0.7605 ]][VAL on 331 [Loss: 0.5181 - ACC_T: 0.7130 - ACC_0: 0.6830 - ACC_1: 0.8333]]
# [Epoch 154][TRAIN on 3658 [Loss: 0.4964 - ACC_T: 0.7537 - ACC_0: 0.7387 - ACC_1: 0.7687 ]][VAL on 331 [Loss: 0.5181 - ACC_T: 0.7130 - ACC_0: 0.6830 - ACC_1: 0.8333]]
# [Epoch 155][TRAIN on 3658 [Loss: 0.4864 - ACC_T: 0.7592 - ACC_0: 0.7452 - ACC_1: 0.7731 ]][VAL on 331 [Loss: 0.5386 - ACC_T: 0.6918 - ACC_0: 0.6566 - ACC_1: 0.8333]]
# [Epoch 156][TRAIN on 3658 [Loss: 0.4931 - ACC_T: 0.7510 - ACC_0: 0.7408 - ACC_1: 0.7611 ]][VAL on 331 [Loss: 0.5369 - ACC_T: 0.6918 - ACC_0: 0.6566 - ACC_1: 0.8333]]
# [Epoch 157][TRAIN on 3658 [Loss: 0.4956 - ACC_T: 0.7411 - ACC_0: 0.7233 - ACC_1: 0.7589 ]][VAL on 331 [Loss: 0.5312 - ACC_T: 0.7009 - ACC_0: 0.6792 - ACC_1: 0.7879]]
# [Epoch 158][TRAIN on 3658 [Loss: 0.4900 - ACC_T: 0.7534 - ACC_0: 0.7315 - ACC_1: 0.7753 ]][VAL on 331 [Loss: 0.5561 - ACC_T: 0.6647 - ACC_0: 0.6226 - ACC_1: 0.8333]]
# [Epoch 159][TRAIN on 3658 [Loss: 0.4888 - ACC_T: 0.7466 - ACC_0: 0.7354 - ACC_1: 0.7578 ]][VAL on 331 [Loss: 0.5432 - ACC_T: 0.6858 - ACC_0: 0.6528 - ACC_1: 0.8182]]
# [Epoch 160][TRAIN on 3658 [Loss: 0.4874 - ACC_T: 0.7518 - ACC_0: 0.7370 - ACC_1: 0.7665 ]][VAL on 331 [Loss: 0.5151 - ACC_T: 0.7069 - ACC_0: 0.6906 - ACC_1: 0.7727]]
# [Epoch 161][TRAIN on 3658 [Loss: 0.4830 - ACC_T: 0.7646 - ACC_0: 0.7507 - ACC_1: 0.7786 ]][VAL on 331 [Loss: 0.5335 - ACC_T: 0.6979 - ACC_0: 0.6792 - ACC_1: 0.7727]]
# [Epoch 162][TRAIN on 3658 [Loss: 0.4959 - ACC_T: 0.7471 - ACC_0: 0.7288 - ACC_1: 0.7654 ]][VAL on 331 [Loss: 0.5397 - ACC_T: 0.6798 - ACC_0: 0.6491 - ACC_1: 0.8030]]
# [Epoch 163][TRAIN on 3658 [Loss: 0.4928 - ACC_T: 0.7466 - ACC_0: 0.7310 - ACC_1: 0.7622 ]][VAL on 331 [Loss: 0.4997 - ACC_T: 0.7341 - ACC_0: 0.7208 - ACC_1: 0.7879]]
# [Epoch 164][TRAIN on 3658 [Loss: 0.4892 - ACC_T: 0.7501 - ACC_0: 0.7359 - ACC_1: 0.7644 ]][VAL on 331 [Loss: 0.5561 - ACC_T: 0.6828 - ACC_0: 0.6453 - ACC_1: 0.8333]]
# [Epoch 165][TRAIN on 3658 [Loss: 0.4900 - ACC_T: 0.7567 - ACC_0: 0.7507 - ACC_1: 0.7627 ]][VAL on 331 [Loss: 0.5163 - ACC_T: 0.7100 - ACC_0: 0.6868 - ACC_1: 0.8030]]
# [Epoch 166][TRAIN on 3658 [Loss: 0.4810 - ACC_T: 0.7622 - ACC_0: 0.7425 - ACC_1: 0.7818 ]][VAL on 331 [Loss: 0.5062 - ACC_T: 0.7190 - ACC_0: 0.7019 - ACC_1: 0.7879]]
# [Epoch 167][TRAIN on 3658 [Loss: 0.4841 - ACC_T: 0.7542 - ACC_0: 0.7425 - ACC_1: 0.7660 ]][VAL on 331 [Loss: 0.5362 - ACC_T: 0.6918 - ACC_0: 0.6679 - ACC_1: 0.7879]]
# [Epoch 168][TRAIN on 3658 [Loss: 0.4808 - ACC_T: 0.7534 - ACC_0: 0.7326 - ACC_1: 0.7742 ]][VAL on 331 [Loss: 0.5412 - ACC_T: 0.7009 - ACC_0: 0.6717 - ACC_1: 0.8182]]
# [Epoch 169][TRAIN on 3658 [Loss: 0.4860 - ACC_T: 0.7594 - ACC_0: 0.7458 - ACC_1: 0.7731 ]][VAL on 331 [Loss: 0.5529 - ACC_T: 0.6737 - ACC_0: 0.6377 - ACC_1: 0.8182]]
# [Epoch 170][TRAIN on 3658 [Loss: 0.4838 - ACC_T: 0.7592 - ACC_0: 0.7419 - ACC_1: 0.7764 ]][VAL on 331 [Loss: 0.5375 - ACC_T: 0.6888 - ACC_0: 0.6604 - ACC_1: 0.8030]]
# [Epoch 171][TRAIN on 3658 [Loss: 0.4853 - ACC_T: 0.7575 - ACC_0: 0.7370 - ACC_1: 0.7780 ]][VAL on 331 [Loss: 0.5262 - ACC_T: 0.7069 - ACC_0: 0.6792 - ACC_1: 0.8182]]
# [Epoch 172][TRAIN on 3658 [Loss: 0.4792 - ACC_T: 0.7572 - ACC_0: 0.7447 - ACC_1: 0.7698 ]][VAL on 331 [Loss: 0.5392 - ACC_T: 0.7009 - ACC_0: 0.6717 - ACC_1: 0.8182]]
# [Epoch 173][TRAIN on 3658 [Loss: 0.4804 - ACC_T: 0.7510 - ACC_0: 0.7359 - ACC_1: 0.7660 ]][VAL on 331 [Loss: 0.5611 - ACC_T: 0.6767 - ACC_0: 0.6491 - ACC_1: 0.7879]]
# [Epoch 174][TRAIN on 3658 [Loss: 0.4852 - ACC_T: 0.7578 - ACC_0: 0.7387 - ACC_1: 0.7769 ]][VAL on 331 [Loss: 0.5471 - ACC_T: 0.6858 - ACC_0: 0.6642 - ACC_1: 0.7727]]
# [Epoch 175][TRAIN on 3658 [Loss: 0.4837 - ACC_T: 0.7630 - ACC_0: 0.7436 - ACC_1: 0.7824 ]][VAL on 331 [Loss: 0.5506 - ACC_T: 0.6828 - ACC_0: 0.6566 - ACC_1: 0.7879]]
# [Epoch 176][TRAIN on 3658 [Loss: 0.4743 - ACC_T: 0.7720 - ACC_0: 0.7622 - ACC_1: 0.7818 ]][VAL on 331 [Loss: 0.5262 - ACC_T: 0.7009 - ACC_0: 0.6830 - ACC_1: 0.7727]]
# [Epoch 177][TRAIN on 3658 [Loss: 0.4842 - ACC_T: 0.7581 - ACC_0: 0.7354 - ACC_1: 0.7808 ]][VAL on 331 [Loss: 0.5485 - ACC_T: 0.6949 - ACC_0: 0.6717 - ACC_1: 0.7879]]
# [Epoch 178][TRAIN on 3658 [Loss: 0.4787 - ACC_T: 0.7589 - ACC_0: 0.7529 - ACC_1: 0.7649 ]][VAL on 331 [Loss: 0.5377 - ACC_T: 0.6979 - ACC_0: 0.6792 - ACC_1: 0.7727]]
# [Epoch 179][TRAIN on 3658 [Loss: 0.4821 - ACC_T: 0.7556 - ACC_0: 0.7337 - ACC_1: 0.7775 ]][VAL on 331 [Loss: 0.5389 - ACC_T: 0.6918 - ACC_0: 0.6717 - ACC_1: 0.7727]]
# [Epoch 180][TRAIN on 3658 [Loss: 0.4751 - ACC_T: 0.7682 - ACC_0: 0.7458 - ACC_1: 0.7906 ]][VAL on 331 [Loss: 0.5822 - ACC_T: 0.6586 - ACC_0: 0.6151 - ACC_1: 0.8333]]
# [Epoch 181][TRAIN on 3658 [Loss: 0.4719 - ACC_T: 0.7665 - ACC_0: 0.7534 - ACC_1: 0.7797 ]][VAL on 331 [Loss: 0.5373 - ACC_T: 0.6949 - ACC_0: 0.6792 - ACC_1: 0.7576]]
# [Epoch 182][TRAIN on 3658 [Loss: 0.4793 - ACC_T: 0.7646 - ACC_0: 0.7501 - ACC_1: 0.7791 ]][VAL on 331 [Loss: 0.5609 - ACC_T: 0.6677 - ACC_0: 0.6415 - ACC_1: 0.7727]]
# [Epoch 183][TRAIN on 3658 [Loss: 0.4841 - ACC_T: 0.7518 - ACC_0: 0.7397 - ACC_1: 0.7638 ]][VAL on 331 [Loss: 0.5331 - ACC_T: 0.6888 - ACC_0: 0.6792 - ACC_1: 0.7273]]
# [Epoch 184][TRAIN on 3658 [Loss: 0.4724 - ACC_T: 0.7630 - ACC_0: 0.7490 - ACC_1: 0.7769 ]][VAL on 331 [Loss: 0.5782 - ACC_T: 0.6647 - ACC_0: 0.6302 - ACC_1: 0.8030]]
# [Epoch 185][TRAIN on 3658 [Loss: 0.4754 - ACC_T: 0.7575 - ACC_0: 0.7414 - ACC_1: 0.7736 ]][VAL on 331 [Loss: 0.5367 - ACC_T: 0.6949 - ACC_0: 0.6792 - ACC_1: 0.7576]]
# [Epoch 186][TRAIN on 3658 [Loss: 0.4743 - ACC_T: 0.7600 - ACC_0: 0.7463 - ACC_1: 0.7736 ]][VAL on 331 [Loss: 0.5310 - ACC_T: 0.6979 - ACC_0: 0.6906 - ACC_1: 0.7273]]
# [Epoch 187][TRAIN on 3658 [Loss: 0.4782 - ACC_T: 0.7542 - ACC_0: 0.7376 - ACC_1: 0.7709 ]][VAL on 331 [Loss: 0.5431 - ACC_T: 0.6979 - ACC_0: 0.6717 - ACC_1: 0.8030]]
# [Epoch 188][TRAIN on 3658 [Loss: 0.4748 - ACC_T: 0.7619 - ACC_0: 0.7512 - ACC_1: 0.7726 ]][VAL on 331 [Loss: 0.5369 - ACC_T: 0.6888 - ACC_0: 0.6755 - ACC_1: 0.7424]]
# [Epoch 189][TRAIN on 3658 [Loss: 0.4732 - ACC_T: 0.7635 - ACC_0: 0.7485 - ACC_1: 0.7786 ]][VAL on 331 [Loss: 0.5530 - ACC_T: 0.6707 - ACC_0: 0.6415 - ACC_1: 0.7879]]
# [Epoch 190][TRAIN on 3658 [Loss: 0.4735 - ACC_T: 0.7665 - ACC_0: 0.7507 - ACC_1: 0.7824 ]][VAL on 331 [Loss: 0.5152 - ACC_T: 0.7100 - ACC_0: 0.7057 - ACC_1: 0.7273]]
# [Epoch 191][TRAIN on 3658 [Loss: 0.4741 - ACC_T: 0.7611 - ACC_0: 0.7485 - ACC_1: 0.7736 ]][VAL on 331 [Loss: 0.5548 - ACC_T: 0.6767 - ACC_0: 0.6491 - ACC_1: 0.7879]]
# [Epoch 192][TRAIN on 3658 [Loss: 0.4693 - ACC_T: 0.7682 - ACC_0: 0.7572 - ACC_1: 0.7791 ]][VAL on 331 [Loss: 0.5410 - ACC_T: 0.6888 - ACC_0: 0.6642 - ACC_1: 0.7879]]
# [Epoch 193][TRAIN on 3658 [Loss: 0.4727 - ACC_T: 0.7649 - ACC_0: 0.7551 - ACC_1: 0.7747 ]][VAL on 331 [Loss: 0.5565 - ACC_T: 0.6828 - ACC_0: 0.6566 - ACC_1: 0.7879]]
# [Epoch 194][TRAIN on 3658 [Loss: 0.4731 - ACC_T: 0.7717 - ACC_0: 0.7501 - ACC_1: 0.7933 ]][VAL on 331 [Loss: 0.5442 - ACC_T: 0.6888 - ACC_0: 0.6717 - ACC_1: 0.7576]]
# [Epoch 195][TRAIN on 3658 [Loss: 0.4843 - ACC_T: 0.7477 - ACC_0: 0.7359 - ACC_1: 0.7594 ]][VAL on 331 [Loss: 0.5486 - ACC_T: 0.6918 - ACC_0: 0.6792 - ACC_1: 0.7424]]
# [Epoch 196][TRAIN on 3658 [Loss: 0.4640 - ACC_T: 0.7747 - ACC_0: 0.7567 - ACC_1: 0.7928 ]][VAL on 331 [Loss: 0.5354 - ACC_T: 0.6888 - ACC_0: 0.6792 - ACC_1: 0.7273]]
# [Epoch 197][TRAIN on 3658 [Loss: 0.4675 - ACC_T: 0.7706 - ACC_0: 0.7496 - ACC_1: 0.7917 ]][VAL on 331 [Loss: 0.5408 - ACC_T: 0.6949 - ACC_0: 0.6830 - ACC_1: 0.7424]]
# [Epoch 198][TRAIN on 3658 [Loss: 0.4605 - ACC_T: 0.7717 - ACC_0: 0.7496 - ACC_1: 0.7939 ]][VAL on 331 [Loss: 0.5580 - ACC_T: 0.6858 - ACC_0: 0.6604 - ACC_1: 0.7879]]
# [Epoch 199][TRAIN on 3658 [Loss: 0.4635 - ACC_T: 0.7701 - ACC_0: 0.7518 - ACC_1: 0.7884 ]][VAL on 331 [Loss: 0.5458 - ACC_T: 0.6767 - ACC_0: 0.6604 - ACC_1: 0.7424]]
# [Epoch 200][TRAIN on 3658 [Loss: 0.4690 - ACC_T: 0.7709 - ACC_0: 0.7529 - ACC_1: 0.7890 ]][VAL on 331 [Loss: 0.5612 - ACC_T: 0.6798 - ACC_0: 0.6453 - ACC_1: 0.8182]]
# [Epoch 201][TRAIN on 3658 [Loss: 0.4655 - ACC_T: 0.7575 - ACC_0: 0.7430 - ACC_1: 0.7720 ]][VAL on 331 [Loss: 0.5456 - ACC_T: 0.6888 - ACC_0: 0.6604 - ACC_1: 0.8030]]
# [Epoch 202][TRAIN on 3658 [Loss: 0.4691 - ACC_T: 0.7622 - ACC_0: 0.7578 - ACC_1: 0.7665 ]][VAL on 331 [Loss: 0.5564 - ACC_T: 0.6737 - ACC_0: 0.6566 - ACC_1: 0.7424]]
# [Epoch 203][TRAIN on 3658 [Loss: 0.4666 - ACC_T: 0.7649 - ACC_0: 0.7408 - ACC_1: 0.7890 ]][VAL on 331 [Loss: 0.5344 - ACC_T: 0.6979 - ACC_0: 0.6906 - ACC_1: 0.7273]]
# [Epoch 204][TRAIN on 3658 [Loss: 0.4685 - ACC_T: 0.7657 - ACC_0: 0.7589 - ACC_1: 0.7726 ]][VAL on 331 [Loss: 0.5437 - ACC_T: 0.6979 - ACC_0: 0.6830 - ACC_1: 0.7576]]
# [Epoch 205][TRAIN on 3658 [Loss: 0.4630 - ACC_T: 0.7712 - ACC_0: 0.7600 - ACC_1: 0.7824 ]][VAL on 331 [Loss: 0.5361 - ACC_T: 0.6979 - ACC_0: 0.6906 - ACC_1: 0.7273]]
# [Epoch 206][TRAIN on 3658 [Loss: 0.4607 - ACC_T: 0.7690 - ACC_0: 0.7578 - ACC_1: 0.7802 ]][VAL on 331 [Loss: 0.5315 - ACC_T: 0.7039 - ACC_0: 0.6906 - ACC_1: 0.7576]]
# [Epoch 207][TRAIN on 3658 [Loss: 0.4698 - ACC_T: 0.7611 - ACC_0: 0.7458 - ACC_1: 0.7764 ]][VAL on 331 [Loss: 0.5466 - ACC_T: 0.6888 - ACC_0: 0.6792 - ACC_1: 0.7273]]
# [Epoch 208][TRAIN on 3658 [Loss: 0.4623 - ACC_T: 0.7693 - ACC_0: 0.7654 - ACC_1: 0.7731 ]][VAL on 331 [Loss: 0.5838 - ACC_T: 0.6616 - ACC_0: 0.6264 - ACC_1: 0.8030]]
# [Epoch 209][TRAIN on 3658 [Loss: 0.4621 - ACC_T: 0.7723 - ACC_0: 0.7627 - ACC_1: 0.7818 ]][VAL on 331 [Loss: 0.5380 - ACC_T: 0.7009 - ACC_0: 0.6868 - ACC_1: 0.7576]]
# [Epoch 210][TRAIN on 3658 [Loss: 0.4688 - ACC_T: 0.7619 - ACC_0: 0.7501 - ACC_1: 0.7736 ]][VAL on 331 [Loss: 0.5484 - ACC_T: 0.6949 - ACC_0: 0.6755 - ACC_1: 0.7727]]
# [Epoch 211][TRAIN on 3658 [Loss: 0.4611 - ACC_T: 0.7767 - ACC_0: 0.7644 - ACC_1: 0.7890 ]][VAL on 331 [Loss: 0.5427 - ACC_T: 0.6949 - ACC_0: 0.6792 - ACC_1: 0.7576]]
# [Epoch 212][TRAIN on 3658 [Loss: 0.4686 - ACC_T: 0.7641 - ACC_0: 0.7479 - ACC_1: 0.7802 ]][VAL on 331 [Loss: 0.5466 - ACC_T: 0.6979 - ACC_0: 0.6830 - ACC_1: 0.7576]]
# [Epoch 213][TRAIN on 3658 [Loss: 0.4575 - ACC_T: 0.7750 - ACC_0: 0.7676 - ACC_1: 0.7824 ]][VAL on 331 [Loss: 0.5168 - ACC_T: 0.7100 - ACC_0: 0.7019 - ACC_1: 0.7424]]
# [Epoch 214][TRAIN on 3658 [Loss: 0.4581 - ACC_T: 0.7794 - ACC_0: 0.7594 - ACC_1: 0.7993 ]][VAL on 331 [Loss: 0.5619 - ACC_T: 0.6767 - ACC_0: 0.6566 - ACC_1: 0.7576]]
# [Epoch 215][TRAIN on 3658 [Loss: 0.4618 - ACC_T: 0.7646 - ACC_0: 0.7397 - ACC_1: 0.7895 ]][VAL on 331 [Loss: 0.5573 - ACC_T: 0.6858 - ACC_0: 0.6642 - ACC_1: 0.7727]]
# [Epoch 216][TRAIN on 3658 [Loss: 0.4589 - ACC_T: 0.7701 - ACC_0: 0.7654 - ACC_1: 0.7747 ]][VAL on 331 [Loss: 0.5375 - ACC_T: 0.7009 - ACC_0: 0.6943 - ACC_1: 0.7273]]
# [Epoch 217][TRAIN on 3658 [Loss: 0.4660 - ACC_T: 0.7646 - ACC_0: 0.7496 - ACC_1: 0.7797 ]][VAL on 331 [Loss: 0.5316 - ACC_T: 0.7039 - ACC_0: 0.6943 - ACC_1: 0.7424]]
# [Epoch 218][TRAIN on 3658 [Loss: 0.4596 - ACC_T: 0.7646 - ACC_0: 0.7529 - ACC_1: 0.7764 ]][VAL on 331 [Loss: 0.5424 - ACC_T: 0.7009 - ACC_0: 0.6868 - ACC_1: 0.7576]]
# [Epoch 219][TRAIN on 3658 [Loss: 0.4556 - ACC_T: 0.7767 - ACC_0: 0.7649 - ACC_1: 0.7884 ]][VAL on 331 [Loss: 0.5632 - ACC_T: 0.6707 - ACC_0: 0.6491 - ACC_1: 0.7576]]
# [Epoch 220][TRAIN on 3658 [Loss: 0.4548 - ACC_T: 0.7717 - ACC_0: 0.7534 - ACC_1: 0.7900 ]][VAL on 331 [Loss: 0.5541 - ACC_T: 0.6798 - ACC_0: 0.6566 - ACC_1: 0.7727]]
# [Epoch 221][TRAIN on 3658 [Loss: 0.4595 - ACC_T: 0.7682 - ACC_0: 0.7452 - ACC_1: 0.7911 ]][VAL on 331 [Loss: 0.5429 - ACC_T: 0.7009 - ACC_0: 0.6906 - ACC_1: 0.7424]]
# [Epoch 222][TRAIN on 3658 [Loss: 0.4584 - ACC_T: 0.7701 - ACC_0: 0.7556 - ACC_1: 0.7846 ]][VAL on 331 [Loss: 0.5528 - ACC_T: 0.6918 - ACC_0: 0.6717 - ACC_1: 0.7727]]
# [Epoch 223][TRAIN on 3658 [Loss: 0.4495 - ACC_T: 0.7797 - ACC_0: 0.7545 - ACC_1: 0.8048 ]][VAL on 331 [Loss: 0.5355 - ACC_T: 0.7039 - ACC_0: 0.6906 - ACC_1: 0.7576]]
# [Epoch 224][TRAIN on 3658 [Loss: 0.4590 - ACC_T: 0.7668 - ACC_0: 0.7551 - ACC_1: 0.7786 ]][VAL on 331 [Loss: 0.5288 - ACC_T: 0.7069 - ACC_0: 0.6981 - ACC_1: 0.7424]]
# [Epoch 225][TRAIN on 3658 [Loss: 0.4498 - ACC_T: 0.7810 - ACC_0: 0.7485 - ACC_1: 0.8136 ]][VAL on 331 [Loss: 0.5608 - ACC_T: 0.6918 - ACC_0: 0.6792 - ACC_1: 0.7424]]
# [Epoch 226][TRAIN on 3658 [Loss: 0.4539 - ACC_T: 0.7731 - ACC_0: 0.7654 - ACC_1: 0.7808 ]][VAL on 331 [Loss: 0.5246 - ACC_T: 0.7069 - ACC_0: 0.6981 - ACC_1: 0.7424]]
# [Epoch 227][TRAIN on 3658 [Loss: 0.4544 - ACC_T: 0.7734 - ACC_0: 0.7523 - ACC_1: 0.7944 ]][VAL on 331 [Loss: 0.5525 - ACC_T: 0.6737 - ACC_0: 0.6566 - ACC_1: 0.7424]]
# [Epoch 228][TRAIN on 3658 [Loss: 0.4549 - ACC_T: 0.7747 - ACC_0: 0.7518 - ACC_1: 0.7977 ]][VAL on 331 [Loss: 0.5736 - ACC_T: 0.6616 - ACC_0: 0.6415 - ACC_1: 0.7424]]
# [Epoch 229][TRAIN on 3658 [Loss: 0.4563 - ACC_T: 0.7816 - ACC_0: 0.7665 - ACC_1: 0.7966 ]][VAL on 331 [Loss: 0.5389 - ACC_T: 0.7009 - ACC_0: 0.6906 - ACC_1: 0.7424]]
# [Epoch 230][TRAIN on 3658 [Loss: 0.4525 - ACC_T: 0.7736 - ACC_0: 0.7567 - ACC_1: 0.7906 ]][VAL on 331 [Loss: 0.5354 - ACC_T: 0.7069 - ACC_0: 0.6943 - ACC_1: 0.7576]]
# [Epoch 231][TRAIN on 3658 [Loss: 0.4498 - ACC_T: 0.7808 - ACC_0: 0.7671 - ACC_1: 0.7944 ]][VAL on 331 [Loss: 0.5642 - ACC_T: 0.6798 - ACC_0: 0.6604 - ACC_1: 0.7576]]
# [Epoch 232][TRAIN on 3658 [Loss: 0.4530 - ACC_T: 0.7742 - ACC_0: 0.7534 - ACC_1: 0.7950 ]][VAL on 331 [Loss: 0.5709 - ACC_T: 0.6677 - ACC_0: 0.6491 - ACC_1: 0.7424]]
# [Epoch 233][TRAIN on 3658 [Loss: 0.4550 - ACC_T: 0.7715 - ACC_0: 0.7556 - ACC_1: 0.7873 ]][VAL on 331 [Loss: 0.5534 - ACC_T: 0.6888 - ACC_0: 0.6792 - ACC_1: 0.7273]]
# [Epoch 234][TRAIN on 3658 [Loss: 0.4594 - ACC_T: 0.7646 - ACC_0: 0.7430 - ACC_1: 0.7862 ]][VAL on 331 [Loss: 0.5497 - ACC_T: 0.6798 - ACC_0: 0.6679 - ACC_1: 0.7273]]
# [Epoch 235][TRAIN on 3658 [Loss: 0.4444 - ACC_T: 0.7797 - ACC_0: 0.7671 - ACC_1: 0.7922 ]][VAL on 331 [Loss: 0.5649 - ACC_T: 0.6767 - ACC_0: 0.6642 - ACC_1: 0.7273]]
# [Epoch 236][TRAIN on 3658 [Loss: 0.4467 - ACC_T: 0.7824 - ACC_0: 0.7687 - ACC_1: 0.7961 ]][VAL on 331 [Loss: 0.5532 - ACC_T: 0.6888 - ACC_0: 0.6755 - ACC_1: 0.7424]]
# [Epoch 237][TRAIN on 3658 [Loss: 0.4386 - ACC_T: 0.7816 - ACC_0: 0.7753 - ACC_1: 0.7879 ]][VAL on 331 [Loss: 0.5778 - ACC_T: 0.6495 - ACC_0: 0.6302 - ACC_1: 0.7273]]
# [Epoch 238][TRAIN on 3658 [Loss: 0.4522 - ACC_T: 0.7799 - ACC_0: 0.7715 - ACC_1: 0.7884 ]][VAL on 331 [Loss: 0.5339 - ACC_T: 0.7039 - ACC_0: 0.6981 - ACC_1: 0.7273]]
# [Epoch 239][TRAIN on 3658 [Loss: 0.4484 - ACC_T: 0.7794 - ACC_0: 0.7578 - ACC_1: 0.8010 ]][VAL on 331 [Loss: 0.5780 - ACC_T: 0.6767 - ACC_0: 0.6566 - ACC_1: 0.7576]]
# [Epoch 240][TRAIN on 3658 [Loss: 0.4450 - ACC_T: 0.7859 - ACC_0: 0.7753 - ACC_1: 0.7966 ]][VAL on 331 [Loss: 0.5550 - ACC_T: 0.6918 - ACC_0: 0.6792 - ACC_1: 0.7424]]
# [Epoch 241][TRAIN on 3658 [Loss: 0.4490 - ACC_T: 0.7797 - ACC_0: 0.7660 - ACC_1: 0.7933 ]][VAL on 331 [Loss: 0.5795 - ACC_T: 0.6556 - ACC_0: 0.6340 - ACC_1: 0.7424]]
# [Epoch 242][TRAIN on 3658 [Loss: 0.4414 - ACC_T: 0.7797 - ACC_0: 0.7551 - ACC_1: 0.8043 ]][VAL on 331 [Loss: 0.5749 - ACC_T: 0.6586 - ACC_0: 0.6340 - ACC_1: 0.7576]]
# [Epoch 243][TRAIN on 3658 [Loss: 0.4455 - ACC_T: 0.7813 - ACC_0: 0.7660 - ACC_1: 0.7966 ]][VAL on 331 [Loss: 0.5652 - ACC_T: 0.6677 - ACC_0: 0.6453 - ACC_1: 0.7576]]
# [Epoch 244][TRAIN on 3658 [Loss: 0.4433 - ACC_T: 0.7824 - ACC_0: 0.7633 - ACC_1: 0.8015 ]][VAL on 331 [Loss: 0.5506 - ACC_T: 0.6918 - ACC_0: 0.6792 - ACC_1: 0.7424]]
# [Epoch 245][TRAIN on 3658 [Loss: 0.4442 - ACC_T: 0.7783 - ACC_0: 0.7649 - ACC_1: 0.7917 ]][VAL on 331 [Loss: 0.5592 - ACC_T: 0.6677 - ACC_0: 0.6491 - ACC_1: 0.7424]]
# [Epoch 246][TRAIN on 3658 [Loss: 0.4405 - ACC_T: 0.7788 - ACC_0: 0.7567 - ACC_1: 0.8010 ]][VAL on 331 [Loss: 0.5771 - ACC_T: 0.6586 - ACC_0: 0.6264 - ACC_1: 0.7879]]
# [Epoch 247][TRAIN on 3658 [Loss: 0.4499 - ACC_T: 0.7788 - ACC_0: 0.7622 - ACC_1: 0.7955 ]][VAL on 331 [Loss: 0.5445 - ACC_T: 0.6918 - ACC_0: 0.6792 - ACC_1: 0.7424]]
# [Epoch 248][TRAIN on 3658 [Loss: 0.4425 - ACC_T: 0.7892 - ACC_0: 0.7769 - ACC_1: 0.8015 ]][VAL on 331 [Loss: 0.5635 - ACC_T: 0.6858 - ACC_0: 0.6679 - ACC_1: 0.7576]]
# [Epoch 249][TRAIN on 3658 [Loss: 0.4435 - ACC_T: 0.7715 - ACC_0: 0.7567 - ACC_1: 0.7862 ]][VAL on 331 [Loss: 0.5726 - ACC_T: 0.6707 - ACC_0: 0.6528 - ACC_1: 0.7424]]
# ...
# [Epoch 306][TRAIN on 4188 [Loss: 0.4374  ACC: 0.7899 - ACC_0: 0.7832 - ACC_1: 0.7966]][TEST on 267 [Loss: 0.7249 ][ACC_T: 0.6367 - ACC_0: 0.7327 - ACC_1: 0.2200]]
# [Epoch 307][TRAIN on 4188 [Loss: 0.4316  ACC: 0.7932 - ACC_0: 0.7674 - ACC_1: 0.8190]][TEST on 267 [Loss: 0.7485 ][ACC_T: 0.6180 - ACC_0: 0.7097 - ACC_1: 0.2200]]
# [Epoch 308][TRAIN on 4188 [Loss: 0.4349  ACC: 0.7913 - ACC_0: 0.7708 - ACC_1: 0.8118]][TEST on 267 [Loss: 0.7200 ][ACC_T: 0.6180 - ACC_0: 0.7051 - ACC_1: 0.2400]]
# [Epoch 309][TRAIN on 4188 [Loss: 0.4332  ACC: 0.7923 - ACC_0: 0.7760 - ACC_1: 0.8085]][TEST on 267 [Loss: 0.7617 ][ACC_T: 0.5955 - ACC_0: 0.6774 - ACC_1: 0.2400]]
# [Epoch 310][TRAIN on 4188 [Loss: 0.4377  ACC: 0.7868 - ACC_0: 0.7641 - ACC_1: 0.8095]][TEST on 267 [Loss: 0.7510 ][ACC_T: 0.6067 - ACC_0: 0.6912 - ACC_1: 0.2400]]
# [Epoch 311][TRAIN on 4188 [Loss: 0.4464  ACC: 0.7808 - ACC_0: 0.7607 - ACC_1: 0.8009]][TEST on 267 [Loss: 0.7372 ][ACC_T: 0.6255 - ACC_0: 0.7143 - ACC_1: 0.2400]]
# [Epoch 312][TRAIN on 4188 [Loss: 0.4368  ACC: 0.7911 - ACC_0: 0.7693 - ACC_1: 0.8128]][TEST on 267 [Loss: 0.7251 ][ACC_T: 0.6292 - ACC_0: 0.7235 - ACC_1: 0.2200]]
# [Epoch 313][TRAIN on 4188 [Loss: 0.4339  ACC: 0.7815 - ACC_0: 0.7622 - ACC_1: 0.8009]][TEST on 267 [Loss: 0.7206 ][ACC_T: 0.6255 - ACC_0: 0.7143 - ACC_1: 0.2400]]
# [Epoch 314][TRAIN on 4188 [Loss: 0.4354  ACC: 0.7868 - ACC_0: 0.7650 - ACC_1: 0.8085]][TEST on 267 [Loss: 0.7378 ][ACC_T: 0.6180 - ACC_0: 0.7051 - ACC_1: 0.2400]]
# [Epoch 315][TRAIN on 4188 [Loss: 0.4287  ACC: 0.7951 - ACC_0: 0.7784 - ACC_1: 0.8118]][TEST on 267 [Loss: 0.7131 ][ACC_T: 0.6404 - ACC_0: 0.7373 - ACC_1: 0.2200]]
# [Epoch 316][TRAIN on 4188 [Loss: 0.4369  ACC: 0.7868 - ACC_0: 0.7693 - ACC_1: 0.8042]][TEST on 267 [Loss: 0.7276 ][ACC_T: 0.6255 - ACC_0: 0.7189 - ACC_1: 0.2200]]
# [Epoch 317][TRAIN on 4188 [Loss: 0.4380  ACC: 0.7820 - ACC_0: 0.7607 - ACC_1: 0.8032]][TEST on 267 [Loss: 0.7195 ][ACC_T: 0.6292 - ACC_0: 0.7189 - ACC_1: 0.2400]]
# [Epoch 318][TRAIN on 4188 [Loss: 0.4313  ACC: 0.7861 - ACC_0: 0.7751 - ACC_1: 0.7970]][TEST on 267 [Loss: 0.7036 ][ACC_T: 0.6330 - ACC_0: 0.7327 - ACC_1: 0.2000]]
# [Epoch 319][TRAIN on 4188 [Loss: 0.4303  ACC: 0.7892 - ACC_0: 0.7679 - ACC_1: 0.8104]][TEST on 267 [Loss: 0.7237 ][ACC_T: 0.6255 - ACC_0: 0.7235 - ACC_1: 0.2000]]
# [Epoch 320][TRAIN on 4188 [Loss: 0.4385  ACC: 0.7875 - ACC_0: 0.7689 - ACC_1: 0.8061]][TEST on 267 [Loss: 0.7249 ][ACC_T: 0.6217 - ACC_0: 0.7189 - ACC_1: 0.2000]]
# [Epoch 321][TRAIN on 4188 [Loss: 0.4358  ACC: 0.7863 - ACC_0: 0.7746 - ACC_1: 0.7980]][TEST on 267 [Loss: 0.6948 ][ACC_T: 0.6330 - ACC_0: 0.7327 - ACC_1: 0.2000]]
# [Epoch 322][TRAIN on 4188 [Loss: 0.4248  ACC: 0.7956 - ACC_0: 0.7746 - ACC_1: 0.8166]][TEST on 267 [Loss: 0.7119 ][ACC_T: 0.6180 - ACC_0: 0.7005 - ACC_1: 0.2600]]
# [Epoch 323][TRAIN on 4188 [Loss: 0.4323  ACC: 0.7889 - ACC_0: 0.7717 - ACC_1: 0.8061]][TEST on 267 [Loss: 0.6831 ][ACC_T: 0.6367 - ACC_0: 0.7419 - ACC_1: 0.1800]]
# [Epoch 324][TRAIN on 4188 [Loss: 0.4330  ACC: 0.7875 - ACC_0: 0.7627 - ACC_1: 0.8123]][TEST on 267 [Loss: 0.7017 ][ACC_T: 0.6292 - ACC_0: 0.7235 - ACC_1: 0.2200]]
# [Epoch 325][TRAIN on 4188 [Loss: 0.4328  ACC: 0.7958 - ACC_0: 0.7770 - ACC_1: 0.8147]][TEST on 267 [Loss: 0.7168 ][ACC_T: 0.6180 - ACC_0: 0.7051 - ACC_1: 0.2400]]
# [Epoch 326][TRAIN on 4188 [Loss: 0.4366  ACC: 0.7853 - ACC_0: 0.7708 - ACC_1: 0.7999]][TEST on 267 [Loss: 0.7051 ][ACC_T: 0.6217 - ACC_0: 0.7235 - ACC_1: 0.1800]]
# [Epoch 327][TRAIN on 4188 [Loss: 0.4349  ACC: 0.7899 - ACC_0: 0.7670 - ACC_1: 0.8128]][TEST on 267 [Loss: 0.7312 ][ACC_T: 0.6142 - ACC_0: 0.7097 - ACC_1: 0.2000]]
# [Epoch 328][TRAIN on 4188 [Loss: 0.4300  ACC: 0.7906 - ACC_0: 0.7751 - ACC_1: 0.8061]][TEST on 267 [Loss: 0.7283 ][ACC_T: 0.6255 - ACC_0: 0.7235 - ACC_1: 0.2000]]
# [Epoch 329][TRAIN on 4188 [Loss: 0.4297  ACC: 0.7872 - ACC_0: 0.7698 - ACC_1: 0.8047]][TEST on 267 [Loss: 0.7315 ][ACC_T: 0.6330 - ACC_0: 0.7327 - ACC_1: 0.2000]]
# [Epoch 330][TRAIN on 4188 [Loss: 0.4301  ACC: 0.7870 - ACC_0: 0.7607 - ACC_1: 0.8133]][TEST on 267 [Loss: 0.7187 ][ACC_T: 0.6255 - ACC_0: 0.7235 - ACC_1: 0.2000]]
# [Epoch 331][TRAIN on 4188 [Loss: 0.4319  ACC: 0.7939 - ACC_0: 0.7684 - ACC_1: 0.8195]][TEST on 267 [Loss: 0.7376 ][ACC_T: 0.6142 - ACC_0: 0.7097 - ACC_1: 0.2000]]
# [Epoch 332][TRAIN on 4188 [Loss: 0.4252  ACC: 0.7942 - ACC_0: 0.7679 - ACC_1: 0.8204]][TEST on 267 [Loss: 0.7443 ][ACC_T: 0.6217 - ACC_0: 0.7143 - ACC_1: 0.2200]]
# [Epoch 333][TRAIN on 4188 [Loss: 0.4203  ACC: 0.8009 - ACC_0: 0.7818 - ACC_1: 0.8200]][TEST on 267 [Loss: 0.7429 ][ACC_T: 0.6067 - ACC_0: 0.6959 - ACC_1: 0.2200]]
# [Epoch 334][TRAIN on 4188 [Loss: 0.4300  ACC: 0.7954 - ACC_0: 0.7779 - ACC_1: 0.8128]][TEST on 267 [Loss: 0.7039 ][ACC_T: 0.6330 - ACC_0: 0.7281 - ACC_1: 0.2200]]
# [Epoch 335][TRAIN on 4188 [Loss: 0.4318  ACC: 0.7861 - ACC_0: 0.7650 - ACC_1: 0.8071]][TEST on 267 [Loss: 0.7292 ][ACC_T: 0.6217 - ACC_0: 0.7189 - ACC_1: 0.2000]]
# [Epoch 336][TRAIN on 4188 [Loss: 0.4264  ACC: 0.7932 - ACC_0: 0.7755 - ACC_1: 0.8109]][TEST on 267 [Loss: 0.7406 ][ACC_T: 0.6330 - ACC_0: 0.7281 - ACC_1: 0.2200]]
# [Epoch 337][TRAIN on 4188 [Loss: 0.4265  ACC: 0.7947 - ACC_0: 0.7803 - ACC_1: 0.8090]][TEST on 267 [Loss: 0.7528 ][ACC_T: 0.6255 - ACC_0: 0.7189 - ACC_1: 0.2200]]
# [Epoch 338][TRAIN on 4188 [Loss: 0.4254  ACC: 0.7915 - ACC_0: 0.7693 - ACC_1: 0.8138]][TEST on 267 [Loss: 0.7335 ][ACC_T: 0.6255 - ACC_0: 0.7281 - ACC_1: 0.1800]]
# [Epoch 339][TRAIN on 4188 [Loss: 0.4243  ACC: 0.7966 - ACC_0: 0.7832 - ACC_1: 0.8099]][TEST on 267 [Loss: 0.7349 ][ACC_T: 0.6255 - ACC_0: 0.7281 - ACC_1: 0.1800]]
# [Epoch 340][TRAIN on 4188 [Loss: 0.4331  ACC: 0.7963 - ACC_0: 0.7741 - ACC_1: 0.8185]][TEST on 267 [Loss: 0.7334 ][ACC_T: 0.6217 - ACC_0: 0.7189 - ACC_1: 0.2000]]
# [Epoch 341][TRAIN on 4188 [Loss: 0.4218  ACC: 0.7896 - ACC_0: 0.7660 - ACC_1: 0.8133]][TEST on 267 [Loss: 0.7459 ][ACC_T: 0.6217 - ACC_0: 0.7097 - ACC_1: 0.2400]]
# [Epoch 342][TRAIN on 4188 [Loss: 0.4251  ACC: 0.7978 - ACC_0: 0.7856 - ACC_1: 0.8099]][TEST on 267 [Loss: 0.7153 ][ACC_T: 0.6292 - ACC_0: 0.7235 - ACC_1: 0.2200]]
# [Epoch 343][TRAIN on 4188 [Loss: 0.4264  ACC: 0.7968 - ACC_0: 0.7775 - ACC_1: 0.8161]][TEST on 267 [Loss: 0.7294 ][ACC_T: 0.6217 - ACC_0: 0.7189 - ACC_1: 0.2000]]
# [Epoch 344][TRAIN on 4188 [Loss: 0.4276  ACC: 0.7918 - ACC_0: 0.7760 - ACC_1: 0.8075]][TEST on 267 [Loss: 0.7287 ][ACC_T: 0.6330 - ACC_0: 0.7281 - ACC_1: 0.2200]]
# [Epoch 345][TRAIN on 4188 [Loss: 0.4157  ACC: 0.8025 - ACC_0: 0.7899 - ACC_1: 0.8152]][TEST on 267 [Loss: 0.7313 ][ACC_T: 0.6217 - ACC_0: 0.7235 - ACC_1: 0.1800]]
# [Epoch 346][TRAIN on 4188 [Loss: 0.4257  ACC: 0.7951 - ACC_0: 0.7808 - ACC_1: 0.8095]][TEST on 267 [Loss: 0.7211 ][ACC_T: 0.6330 - ACC_0: 0.7235 - ACC_1: 0.2400]]
# [Epoch 347][TRAIN on 4188 [Loss: 0.4264  ACC: 0.7901 - ACC_0: 0.7665 - ACC_1: 0.8138]][TEST on 267 [Loss: 0.7349 ][ACC_T: 0.6255 - ACC_0: 0.7189 - ACC_1: 0.2200]]
# [Epoch 348][TRAIN on 4188 [Loss: 0.4194  ACC: 0.7966 - ACC_0: 0.7808 - ACC_1: 0.8123]][TEST on 267 [Loss: 0.7175 ][ACC_T: 0.6217 - ACC_0: 0.7235 - ACC_1: 0.1800]]
# [Epoch 349][TRAIN on 4188 [Loss: 0.4189  ACC: 0.8023 - ACC_0: 0.7784 - ACC_1: 0.8262]][TEST on 267 [Loss: 0.7311 ][ACC_T: 0.6180 - ACC_0: 0.7189 - ACC_1: 0.1800]]
# [Epoch 350][TRAIN on 4188 [Loss: 0.4148  ACC: 0.8032 - ACC_0: 0.7841 - ACC_1: 0.8223]][TEST on 267 [Loss: 0.7225 ][ACC_T: 0.6180 - ACC_0: 0.7189 - ACC_1: 0.1800]]
# [Epoch 351][TRAIN on 4188 [Loss: 0.4200  ACC: 0.7939 - ACC_0: 0.7751 - ACC_1: 0.8128]][TEST on 267 [Loss: 0.7083 ][ACC_T: 0.6292 - ACC_0: 0.7327 - ACC_1: 0.1800]]
# [Epoch 352][TRAIN on 4188 [Loss: 0.4168  ACC: 0.7980 - ACC_0: 0.7717 - ACC_1: 0.8243]][TEST on 267 [Loss: 0.7576 ][ACC_T: 0.6255 - ACC_0: 0.7235 - ACC_1: 0.2000]]
# [Epoch 353][TRAIN on 4188 [Loss: 0.4205  ACC: 0.8023 - ACC_0: 0.7822 - ACC_1: 0.8223]][TEST on 267 [Loss: 0.7607 ][ACC_T: 0.6217 - ACC_0: 0.7189 - ACC_1: 0.2000]]
# [Epoch 354][TRAIN on 4188 [Loss: 0.4206  ACC: 0.8035 - ACC_0: 0.7827 - ACC_1: 0.8243]][TEST on 267 [Loss: 0.7348 ][ACC_T: 0.6330 - ACC_0: 0.7281 - ACC_1: 0.2200]]
# [Epoch 355][TRAIN on 4188 [Loss: 0.4161  ACC: 0.8025 - ACC_0: 0.7846 - ACC_1: 0.8204]][TEST on 267 [Loss: 0.7432 ][ACC_T: 0.6180 - ACC_0: 0.7143 - ACC_1: 0.2000]]
# [Epoch 356][TRAIN on 4188 [Loss: 0.4203  ACC: 0.7975 - ACC_0: 0.7904 - ACC_1: 0.8047]][TEST on 267 [Loss: 0.7313 ][ACC_T: 0.6367 - ACC_0: 0.7373 - ACC_1: 0.2000]]
# [Epoch 357][TRAIN on 4188 [Loss: 0.4176  ACC: 0.8037 - ACC_0: 0.7818 - ACC_1: 0.8257]][TEST on 267 [Loss: 0.7320 ][ACC_T: 0.6255 - ACC_0: 0.7235 - ACC_1: 0.2000]]
# [Epoch 358][TRAIN on 4188 [Loss: 0.4176  ACC: 0.8054 - ACC_0: 0.7841 - ACC_1: 0.8266]][TEST on 267 [Loss: 0.7337 ][ACC_T: 0.6255 - ACC_0: 0.7189 - ACC_1: 0.2200]]
# [Epoch 359][TRAIN on 4188 [Loss: 0.4197  ACC: 0.8006 - ACC_0: 0.7827 - ACC_1: 0.8185]][TEST on 267 [Loss: 0.7657 ][ACC_T: 0.6180 - ACC_0: 0.7143 - ACC_1: 0.2000]]
# [Epoch 360][TRAIN on 4188 [Loss: 0.4242  ACC: 0.7942 - ACC_0: 0.7775 - ACC_1: 0.8109]][TEST on 267 [Loss: 0.7356 ][ACC_T: 0.6180 - ACC_0: 0.7189 - ACC_1: 0.1800]]
# [Epoch 361][TRAIN on 4188 [Loss: 0.4204  ACC: 0.7978 - ACC_0: 0.7827 - ACC_1: 0.8128]][TEST on 267 [Loss: 0.7225 ][ACC_T: 0.6292 - ACC_0: 0.7235 - ACC_1: 0.2200]]
# [Epoch 362][TRAIN on 4188 [Loss: 0.4144  ACC: 0.8035 - ACC_0: 0.7803 - ACC_1: 0.8266]][TEST on 267 [Loss: 0.7555 ][ACC_T: 0.6180 - ACC_0: 0.7143 - ACC_1: 0.2000]]
# [Epoch 363][TRAIN on 4188 [Loss: 0.4225  ACC: 0.8013 - ACC_0: 0.7856 - ACC_1: 0.8171]][TEST on 267 [Loss: 0.7580 ][ACC_T: 0.6217 - ACC_0: 0.7281 - ACC_1: 0.1600]]
# [Epoch 364][TRAIN on 4188 [Loss: 0.4198  ACC: 0.8037 - ACC_0: 0.7880 - ACC_1: 0.8195]][TEST on 267 [Loss: 0.7369 ][ACC_T: 0.6217 - ACC_0: 0.7051 - ACC_1: 0.2600]]
# [Epoch 365][TRAIN on 4188 [Loss: 0.4203  ACC: 0.8011 - ACC_0: 0.7851 - ACC_1: 0.8171]][TEST on 267 [Loss: 0.7493 ][ACC_T: 0.6142 - ACC_0: 0.7189 - ACC_1: 0.1600]]
# [Epoch 366][TRAIN on 4188 [Loss: 0.4196  ACC: 0.8004 - ACC_0: 0.7841 - ACC_1: 0.8166]][TEST on 267 [Loss: 0.7685 ][ACC_T: 0.6217 - ACC_0: 0.7143 - ACC_1: 0.2200]]
# [Epoch 367][TRAIN on 4188 [Loss: 0.4091  ACC: 0.8097 - ACC_0: 0.7947 - ACC_1: 0.8247]][TEST on 267 [Loss: 0.7520 ][ACC_T: 0.6255 - ACC_0: 0.7281 - ACC_1: 0.1800]]
# [Epoch 368][TRAIN on 4188 [Loss: 0.4136  ACC: 0.8032 - ACC_0: 0.7884 - ACC_1: 0.8181]][TEST on 267 [Loss: 0.7684 ][ACC_T: 0.6180 - ACC_0: 0.7097 - ACC_1: 0.2200]]
# [Epoch 369][TRAIN on 4188 [Loss: 0.4152  ACC: 0.7920 - ACC_0: 0.7813 - ACC_1: 0.8028]][TEST on 267 [Loss: 0.7663 ][ACC_T: 0.6217 - ACC_0: 0.7143 - ACC_1: 0.2200]]
# [Epoch 370][TRAIN on 4188 [Loss: 0.4169  ACC: 0.7951 - ACC_0: 0.7751 - ACC_1: 0.8152]][TEST on 267 [Loss: 0.7569 ][ACC_T: 0.6142 - ACC_0: 0.7097 - ACC_1: 0.2000]]
# [Epoch 371][TRAIN on 4188 [Loss: 0.4138  ACC: 0.8004 - ACC_0: 0.7841 - ACC_1: 0.8166]][TEST on 267 [Loss: 0.7526 ][ACC_T: 0.6217 - ACC_0: 0.7097 - ACC_1: 0.2400]]
# [Epoch 372][TRAIN on 4188 [Loss: 0.4025  ACC: 0.8097 - ACC_0: 0.7937 - ACC_1: 0.8257]][TEST on 267 [Loss: 0.7821 ][ACC_T: 0.6142 - ACC_0: 0.7051 - ACC_1: 0.2200]]
# [Epoch 373][TRAIN on 4188 [Loss: 0.4134  ACC: 0.7999 - ACC_0: 0.7904 - ACC_1: 0.8095]][TEST on 267 [Loss: 0.7485 ][ACC_T: 0.6292 - ACC_0: 0.7143 - ACC_1: 0.2600]]
# [Epoch 374][TRAIN on 4188 [Loss: 0.4159  ACC: 0.8001 - ACC_0: 0.7837 - ACC_1: 0.8166]][TEST on 267 [Loss: 0.7260 ][ACC_T: 0.6367 - ACC_0: 0.7281 - ACC_1: 0.2400]]
# [Epoch 375][TRAIN on 4188 [Loss: 0.4210  ACC: 0.7968 - ACC_0: 0.7717 - ACC_1: 0.8219]][TEST on 267 [Loss: 0.7591 ][ACC_T: 0.6105 - ACC_0: 0.7051 - ACC_1: 0.2000]]
# [Epoch 376][TRAIN on 4188 [Loss: 0.4174  ACC: 0.8009 - ACC_0: 0.7889 - ACC_1: 0.8128]][TEST on 267 [Loss: 0.7564 ][ACC_T: 0.6255 - ACC_0: 0.7235 - ACC_1: 0.2000]]
# [Epoch 377][TRAIN on 4188 [Loss: 0.4153  ACC: 0.8025 - ACC_0: 0.7880 - ACC_1: 0.8171]][TEST on 267 [Loss: 0.7386 ][ACC_T: 0.6255 - ACC_0: 0.7189 - ACC_1: 0.2200]]
# [Epoch 378][TRAIN on 4188 [Loss: 0.4108  ACC: 0.8009 - ACC_0: 0.7851 - ACC_1: 0.8166]][TEST on 267 [Loss: 0.7546 ][ACC_T: 0.6180 - ACC_0: 0.7005 - ACC_1: 0.2600]]
# [Epoch 379][TRAIN on 4188 [Loss: 0.4102  ACC: 0.8023 - ACC_0: 0.7918 - ACC_1: 0.8128]][TEST on 267 [Loss: 0.7644 ][ACC_T: 0.6142 - ACC_0: 0.7097 - ACC_1: 0.2000]]
# [Epoch 380][TRAIN on 4188 [Loss: 0.4106  ACC: 0.8052 - ACC_0: 0.7918 - ACC_1: 0.8185]][TEST on 267 [Loss: 0.7432 ][ACC_T: 0.6217 - ACC_0: 0.7189 - ACC_1: 0.2000]]
# [Epoch 381][TRAIN on 4188 [Loss: 0.4164  ACC: 0.7992 - ACC_0: 0.7832 - ACC_1: 0.8152]][TEST on 267 [Loss: 0.7418 ][ACC_T: 0.6292 - ACC_0: 0.7281 - ACC_1: 0.2000]]
# [Epoch 382][TRAIN on 4188 [Loss: 0.4064  ACC: 0.8052 - ACC_0: 0.7822 - ACC_1: 0.8281]][TEST on 267 [Loss: 0.7657 ][ACC_T: 0.6105 - ACC_0: 0.7051 - ACC_1: 0.2000]]
# [Epoch 383][TRAIN on 4188 [Loss: 0.4113  ACC: 0.8040 - ACC_0: 0.7861 - ACC_1: 0.8219]][TEST on 267 [Loss: 0.7667 ][ACC_T: 0.6067 - ACC_0: 0.7005 - ACC_1: 0.2000]]
# [Epoch 384][TRAIN on 4188 [Loss: 0.4106  ACC: 0.8037 - ACC_0: 0.7889 - ACC_1: 0.8185]][TEST on 267 [Loss: 0.7710 ][ACC_T: 0.6217 - ACC_0: 0.7235 - ACC_1: 0.1800]]
# [Epoch 385][TRAIN on 4188 [Loss: 0.4137  ACC: 0.7997 - ACC_0: 0.7894 - ACC_1: 0.8099]][TEST on 267 [Loss: 0.7584 ][ACC_T: 0.6105 - ACC_0: 0.7097 - ACC_1: 0.1800]]
# [Epoch 386][TRAIN on 4188 [Loss: 0.4046  ACC: 0.8097 - ACC_0: 0.7942 - ACC_1: 0.8252]][TEST on 267 [Loss: 0.7325 ][ACC_T: 0.6255 - ACC_0: 0.7051 - ACC_1: 0.2800]]
# [Epoch 387][TRAIN on 4188 [Loss: 0.4041  ACC: 0.8133 - ACC_0: 0.8023 - ACC_1: 0.8243]][TEST on 267 [Loss: 0.7600 ][ACC_T: 0.6217 - ACC_0: 0.7235 - ACC_1: 0.1800]]
# [Epoch 388][TRAIN on 4188 [Loss: 0.4053  ACC: 0.8087 - ACC_0: 0.7956 - ACC_1: 0.8219]][TEST on 267 [Loss: 0.7302 ][ACC_T: 0.6217 - ACC_0: 0.7235 - ACC_1: 0.1800]]
# [Epoch 389][TRAIN on 4188 [Loss: 0.4063  ACC: 0.8145 - ACC_0: 0.7951 - ACC_1: 0.8338]][TEST on 267 [Loss: 0.7520 ][ACC_T: 0.6180 - ACC_0: 0.7143 - ACC_1: 0.2000]]
# [Epoch 390][TRAIN on 4188 [Loss: 0.4082  ACC: 0.8016 - ACC_0: 0.7913 - ACC_1: 0.8118]][TEST on 267 [Loss: 0.7630 ][ACC_T: 0.6217 - ACC_0: 0.7097 - ACC_1: 0.2400]]
# [Epoch 391][TRAIN on 4188 [Loss: 0.4091  ACC: 0.8047 - ACC_0: 0.7846 - ACC_1: 0.8247]][TEST on 267 [Loss: 0.7617 ][ACC_T: 0.6217 - ACC_0: 0.7235 - ACC_1: 0.1800]]
# [Epoch 392][TRAIN on 4188 [Loss: 0.4032  ACC: 0.8123 - ACC_0: 0.7923 - ACC_1: 0.8324]][TEST on 267 [Loss: 0.7624 ][ACC_T: 0.6142 - ACC_0: 0.6959 - ACC_1: 0.2600]]
# [Epoch 393][TRAIN on 4188 [Loss: 0.4081  ACC: 0.8035 - ACC_0: 0.7841 - ACC_1: 0.8228]][TEST on 267 [Loss: 0.7592 ][ACC_T: 0.6255 - ACC_0: 0.7143 - ACC_1: 0.2400]]
# [Epoch 394][TRAIN on 4188 [Loss: 0.4067  ACC: 0.8087 - ACC_0: 0.7884 - ACC_1: 0.8290]][TEST on 267 [Loss: 0.7828 ][ACC_T: 0.6030 - ACC_0: 0.7005 - ACC_1: 0.1800]]
# [Epoch 395][TRAIN on 4188 [Loss: 0.4030  ACC: 0.8054 - ACC_0: 0.7927 - ACC_1: 0.8181]][TEST on 267 [Loss: 0.7699 ][ACC_T: 0.6142 - ACC_0: 0.7097 - ACC_1: 0.2000]]
# [Epoch 396][TRAIN on 4188 [Loss: 0.4060  ACC: 0.8044 - ACC_0: 0.7875 - ACC_1: 0.8214]][TEST on 267 [Loss: 0.7654 ][ACC_T: 0.6067 - ACC_0: 0.7005 - ACC_1: 0.2000]]
# [Epoch 397][TRAIN on 4188 [Loss: 0.4013  ACC: 0.8080 - ACC_0: 0.7913 - ACC_1: 0.8247]][TEST on 267 [Loss: 0.7631 ][ACC_T: 0.6292 - ACC_0: 0.7235 - ACC_1: 0.2200]]
# [Epoch 398][TRAIN on 4188 [Loss: 0.4113  ACC: 0.8097 - ACC_0: 0.7927 - ACC_1: 0.8266]][TEST on 267 [Loss: 0.7789 ][ACC_T: 0.6217 - ACC_0: 0.7051 - ACC_1: 0.2600]]
# [Epoch 399][TRAIN on 4188 [Loss: 0.4096  ACC: 0.8023 - ACC_0: 0.7803 - ACC_1: 0.8243]][TEST on 267 [Loss: 0.7781 ][ACC_T: 0.6217 - ACC_0: 0.7143 - ACC_1: 0.2200]]
# [Epoch 400][TRAIN on 4188 [Loss: 0.4023  ACC: 0.8102 - ACC_0: 0.7913 - ACC_1: 0.8290]][TEST on 267 [Loss: 0.7485 ][ACC_T: 0.6217 - ACC_0: 0.7189 - ACC_1: 0.2000]]
# [Epoch 401][TRAIN on 4188 [Loss: 0.3988  ACC: 0.8092 - ACC_0: 0.7875 - ACC_1: 0.8309]][TEST on 267 [Loss: 0.7556 ][ACC_T: 0.6255 - ACC_0: 0.7189 - ACC_1: 0.2200]]
# [Epoch 402][TRAIN on 4188 [Loss: 0.4091  ACC: 0.8052 - ACC_0: 0.7927 - ACC_1: 0.8176]][TEST on 267 [Loss: 0.7654 ][ACC_T: 0.6292 - ACC_0: 0.7281 - ACC_1: 0.2000]]
#      After Training: GPU Memory  1475584 bytes
# 183474
# Accuracy
# 0.6292134831460674
# Accuracy_0
# 0.728110599078341
# Accuracy_1
# 0.2
#      After Training: GPU Memory  1475584 bytes
